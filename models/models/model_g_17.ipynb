# %% [markdown]
# # Модель 17 (упрощенный GoogLeNet)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/YaMlProject/models/models
# Out:
# /content/drive/MyDrive/YaMlProject/models/models

# %% [markdown]
# #### Импорт необходимых библиотек

# %%
# !pip install tensorflow-addons
# !pip install livelossplot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.20.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (591 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.0/591.0 kB 30.2 MB/s eta 0:00:00
# Collecting typeguard<3.0.0,>=2.7
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow-addons) (23.0)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.20.0 typeguard-2.13.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting livelossplot
#   Downloading livelossplot-0.5.5-py3-none-any.whl (22 kB)
# Requirement already satisfied: bokeh in /usr/local/lib/python3.9/dist-packages (from livelossplot) (2.4.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from livelossplot) (3.7.1)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (1.22.4)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (6.0)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (8.4.0)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (3.1.2)
# Requirement already satisfied: typing-extensions>=3.10.0 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (4.5.0)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (6.2)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (23.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (4.39.3)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->livelossplot) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from Jinja2>=2.9->bokeh->livelossplot) (2.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->livelossplot) (1.16.0)
# Installing collected packages: livelossplot
# Successfully installed livelossplot-0.5.5

# %%
import sys

import numpy as np
import pandas as pd
from PIL import Image
import tensorflow as tf
import torchvision as tv
import matplotlib.pyplot as plt
import tensorflow_addons as tfa
from livelossplot import PlotLossesKeras

sys.path.append('../../')

from core.datasets import get_ds
from core.make_answer import make_ans_file
# Out:
# /usr/local/lib/python3.9/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
num_model = '_g_17'

# %% [markdown]
# #### Аугментация (4)

# %%
transformer = tv.transforms.Compose([
    tv.transforms.ColorJitter(brightness=.2, hue=0.2, contrast=0.5),
    tv.transforms.RandomAffine(degrees=(-10, 10), translate=(0, 0.1), scale=(0.85, 1)),
    tv.transforms.RandomPerspective(distortion_scale=0.2, p=0.7),
])

# %% [markdown]
# #### Скачиваем датасеты

# %%
train_ds, val_ds, test_ds = get_ds(
    'smote_data_train_7000', 'repaired_data_test',
    transform=transformer, one_hot=True, back=2, batch_size=100
)

# %% [markdown]
# Для дальнейшей проверки метрик разделяем валидационный датасет на x и y

# %%
val_ds_x = np.array([i[0] for i in val_ds.unbatch().as_numpy_iterator()])
val_ds_y = np.array([i[1] for i in val_ds.unbatch().as_numpy_iterator()])

# %% [markdown]
# Смотрим на получившуюся агументацию.

# %%
plt.figure(figsize=(12, 15))
train_ds_visualization = train_ds[0]
for i in range(20):
    plt.subplot(5, 4, i + 1)
    img = np.array(Image.fromarray((train_ds_visualization[0][i] * 255).astype(np.uint8), 'RGB'))
    plt.imshow(img / 255, cmap=plt.cm.binary)
    plt.title(np.argmax(train_ds_visualization[1][i]))
    plt.axis('off')
plt.show()

# %% [markdown]
# #### Пишем модель
# ![-](https://media.geeksforgeeks.org/wp-content/uploads/20200429201549/Inceptionv1_architecture.png)
# [![-](https://media.geeksforgeeks.org/wp-content/uploads/20200429201304/Incepption-module.PNG)](https://machinelearningknowledge.ai/googlenet-architecture-implementation-in-keras-with-cifar-10-dataset/) <-- ссылка

# %%
def tree(x, filters, kernel_size, strides=1, padding='same'):
    x = tf.keras.layers.Conv2D(filters, kernel_size, strides=strides, padding=padding)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    return tf.keras.layers.ReLU()(x)

# %%
inputs = tf.keras.layers.Input(shape=(32, 32, 3))
x = tf.keras.layers.Conv2D(32, (5, 5), padding='same')(inputs)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.ReLU()(x)
fork = tf.keras.layers.MaxPool2D(3, strides=2, padding='same')(x)
fork.shape
# Out:
# TensorShape([None, 16, 16, 32])

# %%
tree1 = tree(fork, 32, 1, strides=1)
tree2 = tree(fork, 32, 3, strides=1)
tree3 = tree(fork, 32, 5, strides=1)
tree4 = tf.keras.layers.MaxPooling2D(3, strides=1, padding='same')(fork)
tree4 = tf.keras.layers.Conv2D(32, 1, padding='same', activation='relu')(tree4)

fork = tf.keras.layers.add([tree1, tree2, tree3, tree4])
fork.shape
# Out:
# TensorShape([None, 16, 16, 32])

# %%
tree1 = tree(fork, 32, 3, 2, padding='valid')
tree2 = tf.keras.layers.MaxPooling2D(3, strides=2)(fork)
fork = tf.keras.layers.add([tree1, tree2])
fork.shape
# Out:
# TensorShape([None, 7, 7, 32])

# %%
tree1 = tree(fork, 64, 1, strides=1)
tree2 = tree(fork, 64, 3, strides=1)
tree3 = tree(fork, 64, 5, strides=1)
tree4 = tf.keras.layers.MaxPooling2D(3, strides=1, padding='same')(fork)
tree4 = tf.keras.layers.Conv2D(64, 1, padding='same', activation='relu')(tree4)

fork = tf.keras.layers.add([tree1, tree2, tree3, tree4])

tree1 = tree(fork, 64, 1, strides=1)
tree2 = tree(fork, 64, 3, strides=1)
tree3 = tree(fork, 64, 5, strides=1)
tree4 = tf.keras.layers.MaxPooling2D(3, strides=1, padding='same')(fork)
tree4 = tf.keras.layers.Conv2D(64, 1, padding='same', activation='relu')(tree4)

fork = tf.keras.layers.add([tree1, tree2, tree3, tree4])
fork.shape
# Out:
# TensorShape([None, 7, 7, 64])

# %%
tree1 = tree(fork, 64, 3, 2, padding='valid')
tree2 = tf.keras.layers.MaxPooling2D(2)(fork)
fork = tf.keras.layers.add([tree1, tree2])
fork.shape
# Out:
# TensorShape([None, 3, 3, 64])

# %%
x = tf.keras.layers.GlobalMaxPool2D()(fork)
x = tf.keras.layers.Dropout(0.3)(x)
x = tf.keras.layers.Flatten()(x)
outputs = tf.keras.layers.Dense(10)(x)
model = tf.keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 32)   2432        ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 32)  128         ['conv2d[0][0]']
#  alization)
#
#  re_lu (ReLU)                   (None, 32, 32, 32)   0           ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 16, 16, 32)   0           ['re_lu[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 16, 16, 32)   1056        ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 16, 16, 32)   9248        ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 16, 16, 32)   25632       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 16, 16, 32)  128         ['conv2d_1[0][0]']
#  rmalization)
#
#  batch_normalization_2 (BatchNo  (None, 16, 16, 32)  128         ['conv2d_2[0][0]']
#  rmalization)
#
#  batch_normalization_3 (BatchNo  (None, 16, 16, 32)  128         ['conv2d_3[0][0]']
#  rmalization)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 32)  0           ['max_pooling2d[0][0]']
#
#  re_lu_1 (ReLU)                 (None, 16, 16, 32)   0           ['batch_normalization_1[0][0]']
#
#  re_lu_2 (ReLU)                 (None, 16, 16, 32)   0           ['batch_normalization_2[0][0]']
#
#  re_lu_3 (ReLU)                 (None, 16, 16, 32)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 32)   1056        ['max_pooling2d_1[0][0]']
#
#  add (Add)                      (None, 16, 16, 32)   0           ['re_lu_1[0][0]',
#                                                                   're_lu_2[0][0]',
#                                                                   're_lu_3[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 7, 7, 32)     9248        ['add[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 7, 7, 32)    128         ['conv2d_5[0][0]']
#  rmalization)
#
#  re_lu_4 (ReLU)                 (None, 7, 7, 32)     0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 32)    0           ['add[0][0]']
#
#  add_1 (Add)                    (None, 7, 7, 32)     0           ['re_lu_4[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 7, 7, 64)     2112        ['add_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 7, 7, 64)     18496       ['add_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 7, 7, 64)     51264       ['add_1[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 7, 7, 64)    256         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_6 (BatchNo  (None, 7, 7, 64)    256         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 7, 7, 64)    256         ['conv2d_8[0][0]']
#  rmalization)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 32)    0           ['add_1[0][0]']
#
#  re_lu_5 (ReLU)                 (None, 7, 7, 64)     0           ['batch_normalization_5[0][0]']
#
#  re_lu_6 (ReLU)                 (None, 7, 7, 64)     0           ['batch_normalization_6[0][0]']
#
#  re_lu_7 (ReLU)                 (None, 7, 7, 64)     0           ['batch_normalization_7[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 7, 7, 64)     2112        ['max_pooling2d_3[0][0]']
#
#  add_2 (Add)                    (None, 7, 7, 64)     0           ['re_lu_5[0][0]',
#                                                                   're_lu_6[0][0]',
#                                                                   're_lu_7[0][0]',
#                                                                   'conv2d_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 7, 7, 64)     4160        ['add_2[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 7, 7, 64)     36928       ['add_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 7, 7, 64)     102464      ['add_2[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 7, 7, 64)    256         ['conv2d_10[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 7, 7, 64)    256         ['conv2d_11[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 7, 7, 64)    256         ['conv2d_12[0][0]']
#  ormalization)
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 7, 7, 64)    0           ['add_2[0][0]']
#
#  re_lu_8 (ReLU)                 (None, 7, 7, 64)     0           ['batch_normalization_8[0][0]']
#
#  re_lu_9 (ReLU)                 (None, 7, 7, 64)     0           ['batch_normalization_9[0][0]']
#
#  re_lu_10 (ReLU)                (None, 7, 7, 64)     0           ['batch_normalization_10[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 7, 7, 64)     4160        ['max_pooling2d_4[0][0]']
#
#  add_3 (Add)                    (None, 7, 7, 64)     0           ['re_lu_8[0][0]',
#                                                                   're_lu_9[0][0]',
#                                                                   're_lu_10[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 3, 3, 64)     36928       ['add_3[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 3, 3, 64)    256         ['conv2d_14[0][0]']
#  ormalization)
#
#  re_lu_11 (ReLU)                (None, 3, 3, 64)     0           ['batch_normalization_11[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 3, 3, 64)    0           ['add_3[0][0]']
#
#  add_4 (Add)                    (None, 3, 3, 64)     0           ['re_lu_11[0][0]',
#                                                                   'max_pooling2d_5[0][0]']
#
#  global_max_pooling2d (GlobalMa  (None, 64)          0           ['add_4[0][0]']
#  xPooling2D)
#
#  dropout (Dropout)              (None, 64)           0           ['global_max_pooling2d[0][0]']
#
#  flatten (Flatten)              (None, 64)           0           ['dropout[0][0]']
#
#  dense (Dense)                  (None, 10)           650         ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 310,378
# Trainable params: 309,162
# Non-trainable params: 1,216
# __________________________________________________________________________________________________

# %% [markdown]
# #### Создаем чекпоинты

# %%
metrics = ['categorical_accuracy',
           tfa.metrics.F1Score(num_classes=10, average='macro', name='f1_score')]
callbacks = [
    PlotLossesKeras(),
    tf.keras.callbacks.ModelCheckpoint(
        filepath=f'../checkpoints/model{num_model}_categorical_accuracy.h5',
        monitor='val_categorical_accuracy',
        mode='max',
        save_best_only=True,
    ),
    tf.keras.callbacks.ModelCheckpoint(
        filepath=f'../checkpoints/model{num_model}_loss.h5',
        monitor='val_loss',
        mode='min',
        save_best_only=True,
    ),
    tf.keras.callbacks.ModelCheckpoint(
        filepath=f'../checkpoints/model{num_model}_f1_score.h5',
        monitor='val_f1_score',
        mode='max',
        save_best_only=True,
    ),

    tfa.callbacks.AverageModelCheckpoint(
        update_weights=False,
        filepath=f'../checkpoints/model{num_model}_avg_categorical_accuracy.h5',
        monitor='val_categorical_accuracy',
        mode='max',
        save_best_only=True,
    ),
    tfa.callbacks.AverageModelCheckpoint(
        update_weights=False,
        filepath=f'../checkpoints/model{num_model}_avg_loss.h5',
        monitor='val_loss',
        mode='min',
        save_best_only=True,
    ),
    tfa.callbacks.AverageModelCheckpoint(
        update_weights=False,
        filepath=f'../checkpoints/model{num_model}_avg_f1_score.h5',
        monitor='val_f1_score',
        mode='max',
        save_best_only=True,
    )
]

# %% [markdown]
# #### Компиляция модели

# %% [markdown]
# ## Обучение на колабе прервалось, поэтому я подкачаю чекпоинт и продолжу обучение
#
# ### вот график обучения до остановки колаба
#
# ![photo_2023-04-14_10-48-28.jpg](data:image/jpeg;base64,...)
#
# categorical_accuracy
#
#   training            (min:    0.203, max:    0.946, cur:    0.946)
#
#   validation          (min:    0.469, max:    0.950, cur:    0.948)
#
# f1_score
#
#   training            (min:    0.202, max:    0.946, cur:    0.946)
#
#   validation          (min:    0.413, max:    0.949, cur:    0.948)
#
# Loss
#
#   training            (min:    0.186, max:    2.597, cur:    0.186)
#
#   validation          (min:    0.182, max:    1.564, cur:    0.186)

# %%
model = tf.keras.models.load_model(f'../checkpoints/model{num_model}_avg_categorical_accuracy.h5')

# %%
model.compile(
    optimizer=tfa.optimizers.MovingAverage(tf.keras.optimizers.legacy.Adam()),
    metrics=metrics,
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
)

# %% [markdown]
# #### Обучаем модель

# %%
model.fit(train_ds, validation_data=val_ds,
          epochs=100, callbacks=callbacks, verbose=1)
# Out:
# categorical_accuracy
# 	training         	 (min:    0.942, max:    0.980, cur:    0.980)
# 	validation       	 (min:    0.920, max:    0.974, cur:    0.968)
# f1_score
# 	training         	 (min:    0.942, max:    0.980, cur:    0.980)
# 	validation       	 (min:    0.921, max:    0.974, cur:    0.967)
# Loss
# 	training         	 (min:    0.065, max:    0.200, cur:    0.065)
# 	validation       	 (min:    0.120, max:    0.267, cur:    0.166)
# 651/651 [==============================] - 90s 139ms/step - loss: 0.0647 - categorical_accuracy: 0.9799 - f1_score: 0.9799 - val_loss: 0.1656 - val_categorical_accuracy: 0.9676 - val_f1_score: 0.9672

# %% [markdown]
# Подгружаем все чекпоинты

# %%
model_categorical_acc = tf.keras.models.load_model(f'../checkpoints/model{num_model}_categorical_accuracy.h5')
model_f1_score = tf.keras.models.load_model(f'../checkpoints/model{num_model}_f1_score.h5')
model_loss = tf.keras.models.load_model(f'../checkpoints/model{num_model}_loss.h5')
model_avg_categorical_acc = tf.keras.models.load_model(f'../checkpoints/model{num_model}_avg_categorical_accuracy.h5')
model_avg_f1_score = tf.keras.models.load_model(f'../checkpoints/model{num_model}_avg_f1_score.h5')
model_avg_loss = tf.keras.models.load_model(f'../checkpoints/model{num_model}_avg_loss.h5')

# %% [markdown]
# У нас поличилось шесть чекпоинта (шесть моделей). Ниже указан код для получения ответов для всех чекпоинтов по валидационному датасету.

# %%
ans_val_categorical_accuracy = make_ans_file(model_categorical_acc, val_ds_x)
ans_val_f1_score = make_ans_file(model_f1_score, val_ds_x)
ans_val_loss = make_ans_file(model_loss, val_ds_x)
ans_val_avg_categorical_accuracy = make_ans_file(model_avg_categorical_acc, val_ds_x)
ans_val_avg_f1_score = make_ans_file(model_avg_f1_score, val_ds_x)
ans_val_avg_loss = make_ans_file(model_avg_loss, val_ds_x)
anss = [ans_val_categorical_accuracy, ans_val_f1_score, ans_val_loss, ans_val_avg_categorical_accuracy, ans_val_avg_f1_score, ans_val_avg_loss]

# %% [markdown]
# Формируем валидационные ответы.

# %%
val_ds_y = np.argmax(val_ds_y, axis=1)

# %% [markdown]
# Сравниваем валидационные предикты каждого чекпоинта

# %%
for i in range(len(anss) - 1):
    for j in range(i + 1, len(anss)):
        if np.all(anss[i] == anss[j]):
            print(f'чекпоинты {i + 1} и {j + 1} одинаковые')
# Out:
# чекпоинты 1 и 2 одинаковые
# чекпоинты 4 и 5 одинаковые

# %% [markdown]
# Рассмотрим только 1, 3, 4, 6

# %% [markdown]
# ## ВЫВОД:

# %%
class MulticlassClassificationMetrics:
    def __init__(self, y_true, y_pred):
        self.y_true = np.array(y_true)
        self.y_pred = np.array(y_pred)
        self.matrix_error = self.get_matrix_error()

    def get_matrix_error(self):
        self.class_types = np.unique([self.y_true, self.y_pred])
        TP, FN, FP, TN = [], [], [], []
        for class_type in self.class_types:
            TP.append(np.sum(np.logical_and(self.y_true == self.y_pred, self.y_true == class_type)))
            FN.append(np.sum(np.logical_and(self.y_true == class_type, self.y_pred != class_type)))
            FP.append(np.sum(np.logical_and(self.y_pred == class_type, self.y_true != class_type)))
            TN.append(np.sum(np.logical_and(self.y_pred != class_type, self.y_true != class_type)))
        return pd.DataFrame({
            'class_type': self.class_types,
            'TP': TP, 'TN': TN, 'FP': FP, 'FN': FN,
        }).set_index('class_type')

    def accuracy(self):
        return np.sum(self.y_true == self.y_pred) / self.y_true.shape[0]

    def precision(self, averaging='macro'):
        if averaging == 'macro':
            precisions = self.matrix_error['TP'] / (self.matrix_error['TP'] + self.matrix_error['FP'])
            return np.mean(precisions.replace(np.nan, 0))
        elif averaging == 'micro':
            mean_val = self.matrix_error.mean()
            return mean_val['TP'] / (mean_val['TP'] + mean_val['FP'])

    def recall(self, averaging='macro'):
        if averaging == 'macro':
            recalls = self.matrix_error['TP'] / (self.matrix_error['TP'] + self.matrix_error['FN'])
            return np.mean(recalls.replace(np.nan, 0))
        elif averaging == 'micro':
            mean_val = self.matrix_error.mean()
            return mean_val['TP'] / (mean_val['TP'] + mean_val['FN'])

    def f1_score(self, averaging='macro'):
        if averaging == 'macro':
            reverse_r = (self.matrix_error['TP'] + self.matrix_error['FN']) / self.matrix_error['TP']
            reverse_p = (self.matrix_error['TP'] + self.matrix_error['FP']) / self.matrix_error['TP']
            f1_scores = 2 / (reverse_r + reverse_p)
            return np.mean(f1_scores.replace(np.nan, 0))
        elif averaging == 'micro':
            p = self.precision(averaging)
            r = self.recall(averaging)
            return 2 * p * r / (p + r)

    def metrics(self, averaging='macro'):
        return {
            'accuracy': self.accuracy(),
            'precision': self.precision(averaging),
            'recall': self.recall(averaging),
            'f1_score': self.f1_score(averaging),
        }

    def __str__(self):
        headers = {
            'selector': '*',
            'props': 'background-color: darkgreen; color: white; font-size: 12pt;',
        }
        che_super_mega_puper_visualization_of_cell = { 
            'selector': 'td:hover',
            'props': 'background-color: green; color: white;',
        }
        display(
            self.matrix_error
            .style
            .set_table_styles([
                headers,
                che_super_mega_puper_visualization_of_cell,
            ])
            .set_properties(**{'background-color': 'lightgreen',
                           'color': 'black', 'font-size': '12pt'})
        )
        return ''

    def __repr__(self):
        return (
            f'MulticlassClassificationMetrics(class_types={self.class_types})'
            .replace("'", '').replace(',', ';'))

# %% [markdown]
# ### Accuracy чекпоинт

# %%
metrics = MulticlassClassificationMetrics(val_ds_y, ans_val_categorical_accuracy)
print(metrics)
metrics.metrics()
# Out:
# <style type="text/css">
# #T_4db80 * {
#   background-color: darkgreen;
#   color: white;
#   font-size: 12pt;
# }
# #T_4db80 td:hover {
#   background-color: green;
#   color: white;
# }
# #T_4db80_row0_col0, #T_4db80_row0_col1, #T_4db80_row0_col2, #T_4db80_row0_col3, #T_4db80_row1_col0, #T_4db80_row1_col1, #T_4db80_row1_col2, #T_4db80_row1_col3, #T_4db80_row2_col0, #T_4db80_row2_col1, #T_4db80_row2_col2, #T_4db80_row2_col3, #T_4db80_row3_col0, #T_4db80_row3_col1, #T_4db80_row3_col2, #T_4db80_row3_col3, #T_4db80_row4_col0, #T_4db80_row4_col1, #T_4db80_row4_col2, #T_4db80_row4_col3, #T_4db80_row5_col0, #T_4db80_row5_col1, #T_4db80_row5_col2, #T_4db80_row5_col3, #T_4db80_row6_col0, #T_4db80_row6_col1, #T_4db80_row6_col2, #T_4db80_row6_col3, #T_4db80_row7_col0, #T_4db80_row7_col1, #T_4db80_row7_col2, #T_4db80_row7_col3, #T_4db80_row8_col0, #T_4db80_row8_col1, #T_4db80_row8_col2, #T_4db80_row8_col3, #T_4db80_row9_col0, #T_4db80_row9_col1, #T_4db80_row9_col2, #T_4db80_row9_col3 {
#   background-color: lightgreen;
#   color: black;
#   font-size: 12pt;
# }
# </style>
# <table id="T_4db80" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4db80_level0_col0" class="col_heading level0 col0" >TP</th>
#       <th id="T_4db80_level0_col1" class="col_heading level0 col1" >TN</th>
#       <th id="T_4db80_level0_col2" class="col_heading level0 col2" >FP</th>
#       <th id="T_4db80_level0_col3" class="col_heading level0 col3" >FN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4db80_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4db80_row0_col0" class="data row0 col0" >536</td>
#       <td id="T_4db80_row0_col1" class="data row0 col1" >4351</td>
#       <td id="T_4db80_row0_col2" class="data row0 col2" >12</td>
#       <td id="T_4db80_row0_col3" class="data row0 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_4db80_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4db80_row1_col0" class="data row1 col0" >439</td>
#       <td id="T_4db80_row1_col1" class="data row1 col1" >4424</td>
#       <td id="T_4db80_row1_col2" class="data row1 col2" >22</td>
#       <td id="T_4db80_row1_col3" class="data row1 col3" >16</td>
#     </tr>
#     <tr>
#       <th id="T_4db80_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4db80_row2_col0" class="data row2 col0" >508</td>
#       <td id="T_4db80_row2_col1" class="data row2 col1" >4365</td>
#       <td id="T_4db80_row2_col2" class="data row2 col2" >9</td>
#       <td id="T_4db80_row2_col3" class="data row2 col3" >19</td>
#     </tr>
#     <tr>
#       <th id="T_4db80_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4db80_row3_col0" class="data row3 col0" >450</td>
#       <td id="T_4db80_row3_col1" class="data row3 col1" >4417</td>
#       <td id="T_4db80_row3_col2" class="data row3 col2" >18</td>
#       <td id="T_4db80_row3_col3" class="data row3 col3" >16</td>
#     </tr>
#     <tr>
#       <th id="T_4db80_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4db80_row4_col0" class="data row4 col0" >476</td>
#       <td id="T_4db80_row4_col1" class="data row4 col1" >4413</td>
#       <td id="T_4db80_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_4db80_row4_col3" class="data row4 col3" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4db80_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4db80_row5_col0" class="data row5 col0" >481</td>
#       <td id="T_4db80_row5_col1" class="data row5 col1" >4398</td>
#       <td id="T_4db80_row5_col2" class="data row5 col2" >9</td>
#       <td id="T_4db80_row5_col3" class="data row5 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_4db80_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4db80_row6_col0" class="data row6 col0" >449</td>
#       <td id="T_4db80_row6_col1" class="data row6 col1" >4422</td>
#       <td id="T_4db80_row6_col2" class="data row6 col2" >16</td>
#       <td id="T_4db80_row6_col3" class="data row6 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_4db80_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4db80_row7_col0" class="data row7 col0" >478</td>
#       <td id="T_4db80_row7_col1" class="data row7 col1" >4404</td>
#       <td id="T_4db80_row7_col2" class="data row7 col2" >10</td>
#       <td id="T_4db80_row7_col3" class="data row7 col3" >9</td>
#     </tr>
#     <tr>
#       <th id="T_4db80_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4db80_row8_col0" class="data row8 col0" >456</td>
#       <td id="T_4db80_row8_col1" class="data row8 col1" >4412</td>
#       <td id="T_4db80_row8_col2" class="data row8 col2" >14</td>
#       <td id="T_4db80_row8_col3" class="data row8 col3" >19</td>
#     </tr>
#     <tr>
#       <th id="T_4db80_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4db80_row9_col0" class="data row9 col0" >502</td>
#       <td id="T_4db80_row9_col1" class="data row9 col1" >4377</td>
#       <td id="T_4db80_row9_col2" class="data row9 col2" >14</td>
#       <td id="T_4db80_row9_col3" class="data row9 col3" >8</td>
#     </tr>
#   </tbody>
# </table>
# {'accuracy': 0.9742909610283615,
#  'precision': 0.9740139315020488,
#  'recall': 0.9739433528360525,
#  'f1_score': 0.9739417694396206}

# %% [markdown]
# ## F1-score чекпоинт

# %%
metrics = MulticlassClassificationMetrics(val_ds_y, ans_val_loss)
print(metrics)
metrics.metrics()
# Out:
# <style type="text/css">
# #T_3c48c * {
#   background-color: darkgreen;
#   color: white;
#   font-size: 12pt;
# }
# #T_3c48c td:hover {
#   background-color: green;
#   color: white;
# }
# #T_3c48c_row0_col0, #T_3c48c_row0_col1, #T_3c48c_row0_col2, #T_3c48c_row0_col3, #T_3c48c_row1_col0, #T_3c48c_row1_col1, #T_3c48c_row1_col2, #T_3c48c_row1_col3, #T_3c48c_row2_col0, #T_3c48c_row2_col1, #T_3c48c_row2_col2, #T_3c48c_row2_col3, #T_3c48c_row3_col0, #T_3c48c_row3_col1, #T_3c48c_row3_col2, #T_3c48c_row3_col3, #T_3c48c_row4_col0, #T_3c48c_row4_col1, #T_3c48c_row4_col2, #T_3c48c_row4_col3, #T_3c48c_row5_col0, #T_3c48c_row5_col1, #T_3c48c_row5_col2, #T_3c48c_row5_col3, #T_3c48c_row6_col0, #T_3c48c_row6_col1, #T_3c48c_row6_col2, #T_3c48c_row6_col3, #T_3c48c_row7_col0, #T_3c48c_row7_col1, #T_3c48c_row7_col2, #T_3c48c_row7_col3, #T_3c48c_row8_col0, #T_3c48c_row8_col1, #T_3c48c_row8_col2, #T_3c48c_row8_col3, #T_3c48c_row9_col0, #T_3c48c_row9_col1, #T_3c48c_row9_col2, #T_3c48c_row9_col3 {
#   background-color: lightgreen;
#   color: black;
#   font-size: 12pt;
# }
# </style>
# <table id="T_3c48c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c48c_level0_col0" class="col_heading level0 col0" >TP</th>
#       <th id="T_3c48c_level0_col1" class="col_heading level0 col1" >TN</th>
#       <th id="T_3c48c_level0_col2" class="col_heading level0 col2" >FP</th>
#       <th id="T_3c48c_level0_col3" class="col_heading level0 col3" >FN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c48c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3c48c_row0_col0" class="data row0 col0" >530</td>
#       <td id="T_3c48c_row0_col1" class="data row0 col1" >4361</td>
#       <td id="T_3c48c_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_3c48c_row0_col3" class="data row0 col3" >8</td>
#     </tr>
#     <tr>
#       <th id="T_3c48c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3c48c_row1_col0" class="data row1 col0" >431</td>
#       <td id="T_3c48c_row1_col1" class="data row1 col1" >4428</td>
#       <td id="T_3c48c_row1_col2" class="data row1 col2" >18</td>
#       <td id="T_3c48c_row1_col3" class="data row1 col3" >24</td>
#     </tr>
#     <tr>
#       <th id="T_3c48c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3c48c_row2_col0" class="data row2 col0" >513</td>
#       <td id="T_3c48c_row2_col1" class="data row2 col1" >4346</td>
#       <td id="T_3c48c_row2_col2" class="data row2 col2" >28</td>
#       <td id="T_3c48c_row2_col3" class="data row2 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_3c48c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3c48c_row3_col0" class="data row3 col0" >443</td>
#       <td id="T_3c48c_row3_col1" class="data row3 col1" >4426</td>
#       <td id="T_3c48c_row3_col2" class="data row3 col2" >9</td>
#       <td id="T_3c48c_row3_col3" class="data row3 col3" >23</td>
#     </tr>
#     <tr>
#       <th id="T_3c48c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3c48c_row4_col0" class="data row4 col0" >471</td>
#       <td id="T_3c48c_row4_col1" class="data row4 col1" >4413</td>
#       <td id="T_3c48c_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_3c48c_row4_col3" class="data row4 col3" >15</td>
#     </tr>
#     <tr>
#       <th id="T_3c48c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3c48c_row5_col0" class="data row5 col0" >485</td>
#       <td id="T_3c48c_row5_col1" class="data row5 col1" >4391</td>
#       <td id="T_3c48c_row5_col2" class="data row5 col2" >16</td>
#       <td id="T_3c48c_row5_col3" class="data row5 col3" >9</td>
#     </tr>
#     <tr>
#       <th id="T_3c48c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3c48c_row6_col0" class="data row6 col0" >446</td>
#       <td id="T_3c48c_row6_col1" class="data row6 col1" >4425</td>
#       <td id="T_3c48c_row6_col2" class="data row6 col2" >13</td>
#       <td id="T_3c48c_row6_col3" class="data row6 col3" >17</td>
#     </tr>
#     <tr>
#       <th id="T_3c48c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3c48c_row7_col0" class="data row7 col0" >482</td>
#       <td id="T_3c48c_row7_col1" class="data row7 col1" >4390</td>
#       <td id="T_3c48c_row7_col2" class="data row7 col2" >24</td>
#       <td id="T_3c48c_row7_col3" class="data row7 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_3c48c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3c48c_row8_col0" class="data row8 col0" >463</td>
#       <td id="T_3c48c_row8_col1" class="data row8 col1" >4406</td>
#       <td id="T_3c48c_row8_col2" class="data row8 col2" >20</td>
#       <td id="T_3c48c_row8_col3" class="data row8 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_3c48c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3c48c_row9_col0" class="data row9 col0" >495</td>
#       <td id="T_3c48c_row9_col1" class="data row9 col1" >4381</td>
#       <td id="T_3c48c_row9_col2" class="data row9 col2" >10</td>
#       <td id="T_3c48c_row9_col3" class="data row9 col3" >15</td>
#     </tr>
#   </tbody>
# </table>
# {'accuracy': 0.9710263211589472,
#  'precision': 0.9711356427451825,
#  'recall': 0.9705719424005311,
#  'f1_score': 0.9707381514631503}

# %% [markdown]
# ## Скользящее среднее по accuracy чекпоинт

# %%
metrics = MulticlassClassificationMetrics(val_ds_y, ans_val_avg_categorical_accuracy)
print(metrics)
metrics.metrics()
# Out:
# <style type="text/css">
# #T_bce14 * {
#   background-color: darkgreen;
#   color: white;
#   font-size: 12pt;
# }
# #T_bce14 td:hover {
#   background-color: green;
#   color: white;
# }
# #T_bce14_row0_col0, #T_bce14_row0_col1, #T_bce14_row0_col2, #T_bce14_row0_col3, #T_bce14_row1_col0, #T_bce14_row1_col1, #T_bce14_row1_col2, #T_bce14_row1_col3, #T_bce14_row2_col0, #T_bce14_row2_col1, #T_bce14_row2_col2, #T_bce14_row2_col3, #T_bce14_row3_col0, #T_bce14_row3_col1, #T_bce14_row3_col2, #T_bce14_row3_col3, #T_bce14_row4_col0, #T_bce14_row4_col1, #T_bce14_row4_col2, #T_bce14_row4_col3, #T_bce14_row5_col0, #T_bce14_row5_col1, #T_bce14_row5_col2, #T_bce14_row5_col3, #T_bce14_row6_col0, #T_bce14_row6_col1, #T_bce14_row6_col2, #T_bce14_row6_col3, #T_bce14_row7_col0, #T_bce14_row7_col1, #T_bce14_row7_col2, #T_bce14_row7_col3, #T_bce14_row8_col0, #T_bce14_row8_col1, #T_bce14_row8_col2, #T_bce14_row8_col3, #T_bce14_row9_col0, #T_bce14_row9_col1, #T_bce14_row9_col2, #T_bce14_row9_col3 {
#   background-color: lightgreen;
#   color: black;
#   font-size: 12pt;
# }
# </style>
# <table id="T_bce14" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bce14_level0_col0" class="col_heading level0 col0" >TP</th>
#       <th id="T_bce14_level0_col1" class="col_heading level0 col1" >TN</th>
#       <th id="T_bce14_level0_col2" class="col_heading level0 col2" >FP</th>
#       <th id="T_bce14_level0_col3" class="col_heading level0 col3" >FN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bce14_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bce14_row0_col0" class="data row0 col0" >533</td>
#       <td id="T_bce14_row0_col1" class="data row0 col1" >4355</td>
#       <td id="T_bce14_row0_col2" class="data row0 col2" >8</td>
#       <td id="T_bce14_row0_col3" class="data row0 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_bce14_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bce14_row1_col0" class="data row1 col0" >441</td>
#       <td id="T_bce14_row1_col1" class="data row1 col1" >4423</td>
#       <td id="T_bce14_row1_col2" class="data row1 col2" >23</td>
#       <td id="T_bce14_row1_col3" class="data row1 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_bce14_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bce14_row2_col0" class="data row2 col0" >507</td>
#       <td id="T_bce14_row2_col1" class="data row2 col1" >4364</td>
#       <td id="T_bce14_row2_col2" class="data row2 col2" >10</td>
#       <td id="T_bce14_row2_col3" class="data row2 col3" >20</td>
#     </tr>
#     <tr>
#       <th id="T_bce14_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bce14_row3_col0" class="data row3 col0" >450</td>
#       <td id="T_bce14_row3_col1" class="data row3 col1" >4421</td>
#       <td id="T_bce14_row3_col2" class="data row3 col2" >14</td>
#       <td id="T_bce14_row3_col3" class="data row3 col3" >16</td>
#     </tr>
#     <tr>
#       <th id="T_bce14_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bce14_row4_col0" class="data row4 col0" >480</td>
#       <td id="T_bce14_row4_col1" class="data row4 col1" >4409</td>
#       <td id="T_bce14_row4_col2" class="data row4 col2" >6</td>
#       <td id="T_bce14_row4_col3" class="data row4 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_bce14_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bce14_row5_col0" class="data row5 col0" >482</td>
#       <td id="T_bce14_row5_col1" class="data row5 col1" >4397</td>
#       <td id="T_bce14_row5_col2" class="data row5 col2" >10</td>
#       <td id="T_bce14_row5_col3" class="data row5 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_bce14_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bce14_row6_col0" class="data row6 col0" >446</td>
#       <td id="T_bce14_row6_col1" class="data row6 col1" >4428</td>
#       <td id="T_bce14_row6_col2" class="data row6 col2" >10</td>
#       <td id="T_bce14_row6_col3" class="data row6 col3" >17</td>
#     </tr>
#     <tr>
#       <th id="T_bce14_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bce14_row7_col0" class="data row7 col0" >480</td>
#       <td id="T_bce14_row7_col1" class="data row7 col1" >4404</td>
#       <td id="T_bce14_row7_col2" class="data row7 col2" >10</td>
#       <td id="T_bce14_row7_col3" class="data row7 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_bce14_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bce14_row8_col0" class="data row8 col0" >462</td>
#       <td id="T_bce14_row8_col1" class="data row8 col1" >4405</td>
#       <td id="T_bce14_row8_col2" class="data row8 col2" >21</td>
#       <td id="T_bce14_row8_col3" class="data row8 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_bce14_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bce14_row9_col0" class="data row9 col0" >499</td>
#       <td id="T_bce14_row9_col1" class="data row9 col1" >4382</td>
#       <td id="T_bce14_row9_col2" class="data row9 col2" >9</td>
#       <td id="T_bce14_row9_col3" class="data row9 col3" >11</td>
#     </tr>
#   </tbody>
# </table>
# {'accuracy': 0.9753111609875535,
#  'precision': 0.9749925163844122,
#  'recall': 0.9750986656089152,
#  'f1_score': 0.9750121968695723}

# %% [markdown]
# ### Скользящее среднее по F1-score чекпоинт.

# %%
metrics = MulticlassClassificationMetrics(val_ds_y, ans_val_avg_loss)
print(metrics)
metrics.metrics()
# Out:
# <style type="text/css">
# #T_57dd6 * {
#   background-color: darkgreen;
#   color: white;
#   font-size: 12pt;
# }
# #T_57dd6 td:hover {
#   background-color: green;
#   color: white;
# }
# #T_57dd6_row0_col0, #T_57dd6_row0_col1, #T_57dd6_row0_col2, #T_57dd6_row0_col3, #T_57dd6_row1_col0, #T_57dd6_row1_col1, #T_57dd6_row1_col2, #T_57dd6_row1_col3, #T_57dd6_row2_col0, #T_57dd6_row2_col1, #T_57dd6_row2_col2, #T_57dd6_row2_col3, #T_57dd6_row3_col0, #T_57dd6_row3_col1, #T_57dd6_row3_col2, #T_57dd6_row3_col3, #T_57dd6_row4_col0, #T_57dd6_row4_col1, #T_57dd6_row4_col2, #T_57dd6_row4_col3, #T_57dd6_row5_col0, #T_57dd6_row5_col1, #T_57dd6_row5_col2, #T_57dd6_row5_col3, #T_57dd6_row6_col0, #T_57dd6_row6_col1, #T_57dd6_row6_col2, #T_57dd6_row6_col3, #T_57dd6_row7_col0, #T_57dd6_row7_col1, #T_57dd6_row7_col2, #T_57dd6_row7_col3, #T_57dd6_row8_col0, #T_57dd6_row8_col1, #T_57dd6_row8_col2, #T_57dd6_row8_col3, #T_57dd6_row9_col0, #T_57dd6_row9_col1, #T_57dd6_row9_col2, #T_57dd6_row9_col3 {
#   background-color: lightgreen;
#   color: black;
#   font-size: 12pt;
# }
# </style>
# <table id="T_57dd6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_57dd6_level0_col0" class="col_heading level0 col0" >TP</th>
#       <th id="T_57dd6_level0_col1" class="col_heading level0 col1" >TN</th>
#       <th id="T_57dd6_level0_col2" class="col_heading level0 col2" >FP</th>
#       <th id="T_57dd6_level0_col3" class="col_heading level0 col3" >FN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57dd6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_57dd6_row0_col0" class="data row0 col0" >532</td>
#       <td id="T_57dd6_row0_col1" class="data row0 col1" >4351</td>
#       <td id="T_57dd6_row0_col2" class="data row0 col2" >12</td>
#       <td id="T_57dd6_row0_col3" class="data row0 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_57dd6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_57dd6_row1_col0" class="data row1 col0" >444</td>
#       <td id="T_57dd6_row1_col1" class="data row1 col1" >4413</td>
#       <td id="T_57dd6_row1_col2" class="data row1 col2" >33</td>
#       <td id="T_57dd6_row1_col3" class="data row1 col3" >11</td>
#     </tr>
#     <tr>
#       <th id="T_57dd6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_57dd6_row2_col0" class="data row2 col0" >505</td>
#       <td id="T_57dd6_row2_col1" class="data row2 col1" >4366</td>
#       <td id="T_57dd6_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_57dd6_row2_col3" class="data row2 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_57dd6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_57dd6_row3_col0" class="data row3 col0" >445</td>
#       <td id="T_57dd6_row3_col1" class="data row3 col1" >4424</td>
#       <td id="T_57dd6_row3_col2" class="data row3 col2" >11</td>
#       <td id="T_57dd6_row3_col3" class="data row3 col3" >21</td>
#     </tr>
#     <tr>
#       <th id="T_57dd6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_57dd6_row4_col0" class="data row4 col0" >479</td>
#       <td id="T_57dd6_row4_col1" class="data row4 col1" >4408</td>
#       <td id="T_57dd6_row4_col2" class="data row4 col2" >7</td>
#       <td id="T_57dd6_row4_col3" class="data row4 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_57dd6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_57dd6_row5_col0" class="data row5 col0" >486</td>
#       <td id="T_57dd6_row5_col1" class="data row5 col1" >4390</td>
#       <td id="T_57dd6_row5_col2" class="data row5 col2" >17</td>
#       <td id="T_57dd6_row5_col3" class="data row5 col3" >8</td>
#     </tr>
#     <tr>
#       <th id="T_57dd6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_57dd6_row6_col0" class="data row6 col0" >447</td>
#       <td id="T_57dd6_row6_col1" class="data row6 col1" >4430</td>
#       <td id="T_57dd6_row6_col2" class="data row6 col2" >8</td>
#       <td id="T_57dd6_row6_col3" class="data row6 col3" >16</td>
#     </tr>
#     <tr>
#       <th id="T_57dd6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_57dd6_row7_col0" class="data row7 col0" >477</td>
#       <td id="T_57dd6_row7_col1" class="data row7 col1" >4403</td>
#       <td id="T_57dd6_row7_col2" class="data row7 col2" >11</td>
#       <td id="T_57dd6_row7_col3" class="data row7 col3" >10</td>
#     </tr>
#     <tr>
#       <th id="T_57dd6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_57dd6_row8_col0" class="data row8 col0" >461</td>
#       <td id="T_57dd6_row8_col1" class="data row8 col1" >4410</td>
#       <td id="T_57dd6_row8_col2" class="data row8 col2" >16</td>
#       <td id="T_57dd6_row8_col3" class="data row8 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_57dd6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_57dd6_row9_col0" class="data row9 col0" >497</td>
#       <td id="T_57dd6_row9_col1" class="data row9 col1" >4386</td>
#       <td id="T_57dd6_row9_col2" class="data row9 col2" >5</td>
#       <td id="T_57dd6_row9_col3" class="data row9 col3" >13</td>
#     </tr>
#   </tbody>
# </table>
# {'accuracy': 0.9738828810446848,
#  'precision': 0.9737214391234007,
#  'recall': 0.9737209030456121,
#  'f1_score': 0.9736140591300769}

# %% [markdown]
# Метрики хорошие

# %% [markdown]
# - Сохраняем ответы.

# %%
ans_test_categorical_accuracy = make_ans_file(model_categorical_acc, test_ds, f'../answers/model{num_model}_categorical_accuracy.csv')
ans_test_f1_score = make_ans_file(model_f1_score, test_ds, f'../answers/model{num_model}_f1_score.csv')
ans_test_loss = make_ans_file(model_loss, test_ds, f'../answers/model{num_model}_loss.csv')
ans_test_avg_categorical_accuracy = make_ans_file(model_avg_categorical_acc, test_ds, f'../answers/model{num_model}_avg_categorical_accuracy.csv')
ans_test_avg_f1_score = make_ans_file(model_avg_f1_score, test_ds, f'../answers/model{num_model}_avg_f1_score.csv')
ans_test_avg_loss = make_ans_file(model_avg_loss, test_ds, f'../answers/model{num_model}_avg_loss.csv')
anss = [ans_test_categorical_accuracy, ans_test_loss, ans_test_avg_categorical_accuracy, ans_test_avg_loss]

# %% [markdown]
# Проверяем ответы (одинаковые они или нет), чтоб не терять кол-во отправок ответов на kaggle в день.

# %%
for i in range(len(anss) - 1):
    for j in range(i + 1, len(anss)):
        if np.all(anss[i] == anss[j]):
            print(f'чекпоинты {i + 1} и {j + 1} одинаковые')

# %% [markdown]
# Все ответы разные, поэтому отправляем все на kaggle `categorical_accuracy`, `loss`, `avg_categorical_accuracy`, `avg_loss` чекпоинты
