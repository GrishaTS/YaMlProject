# %%
import pickle

# %%
data = pickle.load(open('data_train', 'rb'))
data
# Out:
# {'section': 'train',
#  'labels': array([1, 3, 2, ..., 7, 5, 8], dtype=uint8),
#  'images': array([[[[ 21.,  27.,  49.],
#           [ 18.,  20.,  44.],
#           [ 13.,  13.,  41.],
#           ...,
#           [  0.,   4.,   6.],
#           [  0.,   4.,   4.],
#           [  0.,   4.,   3.]],
#
#          [[ 28.,  36.,  56.],
#           [ 26.,  32.,  56.],
#           [ 21.,  25.,  52.],
#           ...,
#           [  1.,   5.,   8.],
#           [  0.,   4.,   4.],
#           [  0.,   3.,   2.]],
#
#          [[ 55.,  64.,  80.],
#           [ 54.,  61.,  81.],
#           [ 48.,  54.,  77.],
#           ...,
#           [  1.,   5.,   8.],
#           [  0.,   4.,   5.],
#           [  1.,   5.,   4.]],
#
#          ...,
#
#          [[ 55.,  47.,  57.],
#           [ 36.,  31.,  40.],
#           [ 19.,  16.,  24.],
#           ...,
#           [  7.,   8.,   8.],
#           [  7.,   9.,   8.],
#           [  7.,   8.,   8.]],
#
#          [[ 18.,   8.,  22.],
# ...

# %%
protect_ds = {'images': data['images'][124:124+16], 'labels': data['labels'][124:124+16]}

# %%
pickle.dump(protect_ds, open('protect_ds', 'wb'))
