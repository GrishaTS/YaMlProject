# %%
import pandas as pd

import matplotlib.pyplot as plt

import sys

sys.path.append('../../')

from core.datasets import open_f

df = pd.read_csv('model1_categorical_accuracy.csv')
print(len(open_f('repaired_data_test', back=2)['images']))
plt.hist(df['Category'], rwidth=0.9)
# Out:
# 25000
# (array([1706., 4854., 3615., 2951., 2525., 2294., 1941., 1844., 1777.,
#         1493.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <BarContainer object of 10 artists>)
