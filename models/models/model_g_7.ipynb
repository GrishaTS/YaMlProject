# %% [markdown]
# # Модель 7 (DenceNet)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/YaMlProject/models/models
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/YaMlProject/models/models'
# /content

# %%
# %ls
# Out:
# C_EN_model_1.ipynb  model_g_1.ipynb  model_g_4.ipynb  model_g_7.ipynb
# model3.ipynb        model_g_2.ipynb  model_g_5.ipynb  model_s_1.ipynb
# model4.ipynb        model_g_3.ipynb  model_g_6.ipynb

# %% [markdown]
# #### Импорт необходимых библиотек

# %%
# !pip install tensorflow-addons
# !pip install livelossplot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.20.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (591 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.0/591.0 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow-addons) (23.0)
# Collecting typeguard<3.0.0,>=2.7
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.20.0 typeguard-2.13.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting livelossplot
#   Downloading livelossplot-0.5.5-py3-none-any.whl (22 kB)
# Requirement already satisfied: bokeh in /usr/local/lib/python3.9/dist-packages (from livelossplot) (2.4.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from livelossplot) (3.7.1)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (1.22.4)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (6.0)
# Requirement already satisfied: typing-extensions>=3.10.0 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (4.5.0)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (23.0)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (6.2)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (3.1.2)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (4.39.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (1.0.7)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->livelossplot) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from Jinja2>=2.9->bokeh->livelossplot) (2.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->livelossplot) (1.16.0)
# Installing collected packages: livelossplot
# Successfully installed livelossplot-0.5.5

# %%
import sys

import numpy as np
import pandas as pd
from PIL import Image
import tensorflow as tf
import torchvision as tv
import matplotlib.pyplot as plt
import tensorflow_addons as tfa
from livelossplot import PlotLossesKeras

sys.path.append('../../')

from core.datasets import get_ds
from core.make_answer import make_ans_file
# Out:
# c:\Users\Mi\Desktop\ML\.conda\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %% [markdown]
# #### Аугментация (4)

# %%
transformer = tv.transforms.Compose([
    tv.transforms.ColorJitter(brightness=.2, hue=0.2, contrast=0.5),
    tv.transforms.RandomAffine(degrees=(-12, 12), translate=(0, 0.1), scale=(0.85, 1)),
    tv.transforms.RandomPerspective(distortion_scale=0.2, p=0.7),
])

# %% [markdown]
# #### Скачиваем датасеты

# %%
train_ds, val_ds, test_ds = get_ds(
    'repaired_data_train', 'repaired_data_test',
    transform=transformer, one_hot=True, back=2
)

# %% [markdown]
# Для дальнейшей проверки метрик разделяем валидационный датасет на x и y

# %%
val_ds_x = np.array([i[0] for i in val_ds.unbatch().as_numpy_iterator()])
val_ds_y = np.array([i[1] for i in val_ds.unbatch().as_numpy_iterator()])

# %% [markdown]
# Смотрим на получившуюся агументацию.

# %%
plt.figure(figsize=(12, 15))
train_ds_visualization = train_ds[0]
for i in range(20):
    plt.subplot(5, 4, i + 1)
    img = np.array(Image.fromarray((train_ds_visualization[0][i] * 255).astype(np.uint8), 'RGB'))
    plt.imshow(img / 255, cmap=plt.cm.binary)
    plt.title(np.argmax(train_ds_visualization[1][i]))
    plt.axis('off')
plt.show()

# %% [markdown]
# #### Пишем модель

# %% [markdown]
# [![Foo](https://iq.opengenus.org/content/images/2021/08/Capture.JPG)](https://iq.opengenus.org/architecture-of-densenet121/) <- ссылка на сайт

# %% [markdown]
# Вход в нейросеть и свертки

# %%
inputs = tf.keras.Input(shape=(32, 32, 3), batch_size=512)
x = tf.keras.layers.Conv2D(32, 5, padding='same')(inputs)
x = tf.keras.layers.Conv2D(64, 3, padding='same')(x)
x.shape
# Out:
# TensorShape([512, 32, 32, 64])

# %% [markdown]
# Первый Dence блок + MaxPooling2D

# %%
x = tf.keras.layers.Conv2D(64, 1, padding='same')(x)
block1 = tf.keras.layers.Conv2D(64, 3, padding='same')(x)

x = tf.keras.layers.Conv2D(64, 1, padding='same')(block1)
block2 = tf.keras.layers.Conv2D(64, 3, padding='same')(x)

x = tf.keras.layers.add([block1, block2])

x = tf.keras.layers.Conv2D(64, 1, padding='same')(x)
block3 = tf.keras.layers.Conv2D(64, 3, padding='same')(x)

x = tf.keras.layers.add([block1, block2, block3])

x = tf.keras.layers.Conv2D(64, 1, padding='same')(x)
block4 = tf.keras.layers.Conv2D(64, 3, padding='same')(x)

x = tf.keras.layers.add([block1, block2, block3, block4])

x = tf.keras.layers.MaxPool2D(2)(x)
x.shape
# Out:
# TensorShape([512, 16, 16, 64])

# %% [markdown]
# Второй Dence блок + MaxPooling2D

# %%
x = tf.keras.layers.Conv2D(128, 1, padding='same')(x)
block1 = tf.keras.layers.Conv2D(128, 3, padding='same')(x)

x = tf.keras.layers.Conv2D(128, 1, padding='same')(block1)
block2 = tf.keras.layers.Conv2D(128, 3, padding='same')(x)

x = tf.keras.layers.add([block1, block2])

x = tf.keras.layers.Conv2D(128, 1, padding='same')(x)
block3 = tf.keras.layers.Conv2D(128, 3, padding='same')(x)

x = tf.keras.layers.add([block1, block2, block3])

x = tf.keras.layers.Conv2D(128, 1, padding='same')(x)
block4 = tf.keras.layers.Conv2D(128, 3, padding='same')(x)

x = tf.keras.layers.add([block1, block2, block3, block4])

x = tf.keras.layers.MaxPool2D(2)(x)
x.shape
# Out:
# TensorShape([512, 8, 8, 128])

# %% [markdown]
# Третий Dence блок + MaxPooling2D

# %%
x = tf.keras.layers.Conv2D(256, 1, padding='same')(x)
block1 = tf.keras.layers.Conv2D(256, 3, padding='same')(x)

x = tf.keras.layers.Conv2D(256, 1, padding='same')(block1)
block2 = tf.keras.layers.Conv2D(256, 3, padding='same')(x)

x = tf.keras.layers.add([block1, block2])

x = tf.keras.layers.Conv2D(256, 1, padding='same')(x)
block3 = tf.keras.layers.Conv2D(256, 3, padding='same')(x)

x = tf.keras.layers.add([block1, block2, block3])

x = tf.keras.layers.Conv2D(256, 1, padding='same')(x)
block4 = tf.keras.layers.Conv2D(256, 3, padding='same')(x)

x = tf.keras.layers.add([block1, block2, block3, block4])

x = tf.keras.layers.MaxPool2D(2)(x)
x.shape
# Out:
# TensorShape([512, 4, 4, 256])

# %% [markdown]
# Выход

# %%
x = tf.keras.layers.AveragePooling2D()(x)
x = tf.keras.layers.Flatten()(x)
outputs = tf.keras.layers.Dense(10)(x)
model = tf.keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(512, 32, 32, 3)]   0           []
#
#  conv2d (Conv2D)                (512, 32, 32, 32)    2432        ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (512, 32, 32, 64)    18496       ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (512, 32, 32, 64)    4160        ['conv2d_1[0][0]']
#
#  conv2d_3 (Conv2D)              (512, 32, 32, 64)    36928       ['conv2d_2[0][0]']
#
#  conv2d_4 (Conv2D)              (512, 32, 32, 64)    4160        ['conv2d_3[0][0]']
#
#  conv2d_5 (Conv2D)              (512, 32, 32, 64)    36928       ['conv2d_4[0][0]']
#
#  add (Add)                      (512, 32, 32, 64)    0           ['conv2d_3[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (512, 32, 32, 64)    4160        ['add[0][0]']
#
#  conv2d_7 (Conv2D)              (512, 32, 32, 64)    36928       ['conv2d_6[0][0]']
#
#  add_1 (Add)                    (512, 32, 32, 64)    0           ['conv2d_3[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (512, 32, 32, 64)    4160        ['add_1[0][0]']
#
#  conv2d_9 (Conv2D)              (512, 32, 32, 64)    36928       ['conv2d_8[0][0]']
#
#  add_2 (Add)                    (512, 32, 32, 64)    0           ['conv2d_3[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_7[0][0]',
#                                                                   'conv2d_9[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (512, 16, 16, 64)    0           ['add_2[0][0]']
#
#  conv2d_10 (Conv2D)             (512, 16, 16, 128)   8320        ['max_pooling2d[0][0]']
#
#  conv2d_11 (Conv2D)             (512, 16, 16, 128)   147584      ['conv2d_10[0][0]']
#
#  conv2d_12 (Conv2D)             (512, 16, 16, 128)   16512       ['conv2d_11[0][0]']
#
#  conv2d_13 (Conv2D)             (512, 16, 16, 128)   147584      ['conv2d_12[0][0]']
#
#  add_3 (Add)                    (512, 16, 16, 128)   0           ['conv2d_11[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  conv2d_14 (Conv2D)             (512, 16, 16, 128)   16512       ['add_3[0][0]']
#
#  conv2d_15 (Conv2D)             (512, 16, 16, 128)   147584      ['conv2d_14[0][0]']
#
#  add_4 (Add)                    (512, 16, 16, 128)   0           ['conv2d_11[0][0]',
#                                                                   'conv2d_13[0][0]',
#                                                                   'conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (512, 16, 16, 128)   16512       ['add_4[0][0]']
#
#  conv2d_17 (Conv2D)             (512, 16, 16, 128)   147584      ['conv2d_16[0][0]']
#
#  add_5 (Add)                    (512, 16, 16, 128)   0           ['conv2d_11[0][0]',
#                                                                   'conv2d_13[0][0]',
#                                                                   'conv2d_15[0][0]',
#                                                                   'conv2d_17[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (512, 8, 8, 128)    0           ['add_5[0][0]']
#
#  conv2d_18 (Conv2D)             (512, 8, 8, 256)     33024       ['max_pooling2d_1[0][0]']
#
#  conv2d_19 (Conv2D)             (512, 8, 8, 256)     590080      ['conv2d_18[0][0]']
#
#  conv2d_20 (Conv2D)             (512, 8, 8, 256)     65792       ['conv2d_19[0][0]']
#
#  conv2d_21 (Conv2D)             (512, 8, 8, 256)     590080      ['conv2d_20[0][0]']
#
#  add_6 (Add)                    (512, 8, 8, 256)     0           ['conv2d_19[0][0]',
#                                                                   'conv2d_21[0][0]']
#
#  conv2d_22 (Conv2D)             (512, 8, 8, 256)     65792       ['add_6[0][0]']
#
#  conv2d_23 (Conv2D)             (512, 8, 8, 256)     590080      ['conv2d_22[0][0]']
#
#  add_7 (Add)                    (512, 8, 8, 256)     0           ['conv2d_19[0][0]',
#                                                                   'conv2d_21[0][0]',
#                                                                   'conv2d_23[0][0]']
#
#  conv2d_24 (Conv2D)             (512, 8, 8, 256)     65792       ['add_7[0][0]']
#
#  conv2d_25 (Conv2D)             (512, 8, 8, 256)     590080      ['conv2d_24[0][0]']
#
#  add_8 (Add)                    (512, 8, 8, 256)     0           ['conv2d_19[0][0]',
#                                                                   'conv2d_21[0][0]',
#                                                                   'conv2d_23[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (512, 4, 4, 256)    0           ['add_8[0][0]']
#
#  average_pooling2d (AveragePool  (512, 2, 2, 256)    0           ['max_pooling2d_2[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (512, 1024)          0           ['average_pooling2d[0][0]']
#
#  dense (Dense)                  (512, 10)            10250       ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 3,434,442
# Trainable params: 3,434,442
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Создаем чекпоинты

# %%
metrics = ['categorical_accuracy',
           tfa.metrics.F1Score(num_classes=10, average='macro', name='f1_score')]
num_model = '_g_7'
callbacks = [
    PlotLossesKeras(),
    tf.keras.callbacks.ModelCheckpoint(
        filepath=f'../checkpoints/model{num_model}_categorical_accuracy.h5',
        monitor='val_categorical_accuracy',
        mode='max',
        save_best_only=True,
    ),
    tf.keras.callbacks.ModelCheckpoint(
        filepath=f'../checkpoints/model{num_model}_loss.h5',
        monitor='val_loss',
        mode='min',
        save_best_only=True,
    ),
    tf.keras.callbacks.ModelCheckpoint(
        filepath=f'../checkpoints/model{num_model}_f1_score.h5',
        monitor='val_f1_score',
        mode='max',
        save_best_only=True,
    ),

    tfa.callbacks.AverageModelCheckpoint(
        update_weights=False,
        filepath=f'../checkpoints/model{num_model}_avg_categorical_accuracy.h5',
        monitor='val_categorical_accuracy',
        mode='max',
        save_best_only=True,
    ),
    tfa.callbacks.AverageModelCheckpoint(
        update_weights=False,
        filepath=f'../checkpoints/model{num_model}_avg_loss.h5',
        monitor='val_loss',
        mode='min',
        save_best_only=True,
    ),
    tfa.callbacks.AverageModelCheckpoint(
        update_weights=False,
        filepath=f'../checkpoints/model{num_model}_avg_f1_score.h5',
        monitor='val_f1_score',
        mode='max',
        save_best_only=True,
    )
]

# %% [markdown]
# #### Компиляция модели

# %%
model.compile(
    optimizer=tfa.optimizers.MovingAverage(tf.keras.optimizers.legacy.Adam()),
    metrics=metrics,
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
)

# %% [markdown]
# #### Обучаем модель

# %%
history = model.fit(train_ds, validation_data=val_ds,
          epochs=150, callbacks=callbacks, verbose=1)
# Out:
# categorical_accuracy
# 	training         	 (min:    0.110, max:    0.900, cur:    0.894)
# 	validation       	 (min:    0.111, max:    0.931, cur:    0.931)
# f1_score
# 	training         	 (min:    0.090, max:    0.893, cur:    0.888)
# 	validation       	 (min:    0.070, max:    0.927, cur:    0.927)
# Loss
# 	training         	 (min:    0.347, max:  110.728, cur:    0.363)
# 	validation       	 (min:    0.268, max:    2.409, cur:    0.274)
# 91/91 [==============================] - 56s 620ms/step - loss: 0.3627 - categorical_accuracy: 0.8938 - f1_score: 0.8876 - val_loss: 0.2741 - val_categorical_accuracy: 0.9309 - val_f1_score: 0.9268

# %% [markdown]
# Подгружаем все чекпоинты

# %%
model_categorical_acc = tf.keras.models.load_model(f'../checkpoints/model{num_model}_categorical_accuracy.h5')
model_f1_score = tf.keras.models.load_model(f'../checkpoints/model{num_model}_f1_score.h5')
model_loss = tf.keras.models.load_model(f'../checkpoints/model{num_model}_loss.h5')
model_avg_categorical_acc = tf.keras.models.load_model(f'../checkpoints/model{num_model}_avg_categorical_accuracy.h5')
model_avg_f1_score = tf.keras.models.load_model(f'../checkpoints/model{num_model}_avg_f1_score.h5')
model_avg_loss = tf.keras.models.load_model(f'../checkpoints/model{num_model}_avg_loss.h5')

# %% [markdown]
# У нас поличилось три чекпоинта (три модели). Ниже указан код для получения ответов для всех чекпоинтов по валидационному датасету.

# %%
ans_val_categorical_accuracy = make_ans_file(model_categorical_acc, val_ds_x)
ans_val_f1_score = make_ans_file(model_f1_score, val_ds_x)
ans_val_loss = make_ans_file(model_loss, val_ds_x)
ans_val_avg_categorical_accuracy = make_ans_file(model_avg_categorical_acc, val_ds_x)
ans_val_avg_f1_score = make_ans_file(model_avg_f1_score, val_ds_x)
ans_val_avg_loss = make_ans_file(model_avg_loss, val_ds_x)
anss = [ans_val_categorical_accuracy, ans_val_f1_score, ans_val_loss, ans_val_avg_categorical_accuracy, ans_val_avg_f1_score, ans_val_avg_loss]

# %% [markdown]
# Формируем валидационные ответы.

# %%
val_ds_y = np.argmax(val_ds_y, axis=1)

# %% [markdown]
# Сравниваем валидационные предикты каждого чекпоинта

# %%
for i in range(len(anss) - 1):
    for j in range(i + 1, len(anss)):
        if np.all(anss[i] == anss[j]):
            print(f'чекпоинты {i + 1} и {j + 1} одинаковые')
# Out:
# чекпоинты 1 и 2 одинаковые
# чекпоинты 4 и 5 одинаковые

# %% [markdown]
# Рассмотрим 1, 3, 4, 6

# %% [markdown]
# ## ВЫВОД:

# %%
class MulticlassClassificationMetrics:
    def __init__(self, y_true, y_pred):
        self.y_true = np.array(y_true)
        self.y_pred = np.array(y_pred)
        self.matrix_error = self.get_matrix_error()

    def get_matrix_error(self):
        self.class_types = np.unique([self.y_true, self.y_pred])
        TP, FN, FP, TN = [], [], [], []
        for class_type in self.class_types:
            TP.append(np.sum(np.logical_and(self.y_true == self.y_pred, self.y_true == class_type)))
            FN.append(np.sum(np.logical_and(self.y_true == class_type, self.y_pred != class_type)))
            FP.append(np.sum(np.logical_and(self.y_pred == class_type, self.y_true != class_type)))
            TN.append(np.sum(np.logical_and(self.y_pred != class_type, self.y_true != class_type)))
        return pd.DataFrame({
            'class_type': self.class_types,
            'TP': TP, 'TN': TN, 'FP': FP, 'FN': FN,
        }).set_index('class_type')

    def accuracy(self):
        return np.sum(self.y_true == self.y_pred) / self.y_true.shape[0]

    def precision(self, averaging='macro'):
        if averaging == 'macro':
            precisions = self.matrix_error['TP'] / (self.matrix_error['TP'] + self.matrix_error['FP'])
            return np.mean(precisions.replace(np.nan, 0))
        elif averaging == 'micro':
            mean_val = self.matrix_error.mean()
            return mean_val['TP'] / (mean_val['TP'] + mean_val['FP'])

    def recall(self, averaging='macro'):
        if averaging == 'macro':
            recalls = self.matrix_error['TP'] / (self.matrix_error['TP'] + self.matrix_error['FN'])
            return np.mean(recalls.replace(np.nan, 0))
        elif averaging == 'micro':
            mean_val = self.matrix_error.mean()
            return mean_val['TP'] / (mean_val['TP'] + mean_val['FN'])

    def f1_score(self, averaging='macro'):
        if averaging == 'macro':
            reverse_r = (self.matrix_error['TP'] + self.matrix_error['FN']) / self.matrix_error['TP']
            reverse_p = (self.matrix_error['TP'] + self.matrix_error['FP']) / self.matrix_error['TP']
            f1_scores = 2 / (reverse_r + reverse_p)
            return np.mean(f1_scores.replace(np.nan, 0))
        elif averaging == 'micro':
            p = self.precision(averaging)
            r = self.recall(averaging)
            return 2 * p * r / (p + r)

    def metrics(self, averaging='macro'):
        return {
            'accuracy': self.accuracy(),
            'precision': self.precision(averaging),
            'recall': self.recall(averaging),
            'f1_score': self.f1_score(averaging),
        }

    def __str__(self):
        headers = {
            'selector': '*',
            'props': 'background-color: darkgreen; color: white; font-size: 12pt;',
        }
        che_super_mega_puper_visualization_of_cell = { 
            'selector': 'td:hover',
            'props': 'background-color: green; color: white;',
        }
        display(
            self.matrix_error
            .style
            .set_table_styles([
                headers,
                che_super_mega_puper_visualization_of_cell,
            ])
            .set_properties(**{'background-color': 'lightgreen',
                           'color': 'black', 'font-size': '12pt'})
        )
        return ''

    def __repr__(self):
        return (
            f'MulticlassClassificationMetrics(class_types={self.class_types})'
            .replace("'", '').replace(',', ';'))

# %% [markdown]
# ### Accuracy чекпоинт

# %%
metrics = MulticlassClassificationMetrics(val_ds_y, ans_val_categorical_accuracy)
print(metrics)
metrics.metrics()
# Out:
# <style type="text/css">
# #T_fd70f * {
#   background-color: darkgreen;
#   color: white;
#   font-size: 12pt;
# }
# #T_fd70f td:hover {
#   background-color: green;
#   color: white;
# }
# #T_fd70f_row0_col0, #T_fd70f_row0_col1, #T_fd70f_row0_col2, #T_fd70f_row0_col3, #T_fd70f_row1_col0, #T_fd70f_row1_col1, #T_fd70f_row1_col2, #T_fd70f_row1_col3, #T_fd70f_row2_col0, #T_fd70f_row2_col1, #T_fd70f_row2_col2, #T_fd70f_row2_col3, #T_fd70f_row3_col0, #T_fd70f_row3_col1, #T_fd70f_row3_col2, #T_fd70f_row3_col3, #T_fd70f_row4_col0, #T_fd70f_row4_col1, #T_fd70f_row4_col2, #T_fd70f_row4_col3, #T_fd70f_row5_col0, #T_fd70f_row5_col1, #T_fd70f_row5_col2, #T_fd70f_row5_col3, #T_fd70f_row6_col0, #T_fd70f_row6_col1, #T_fd70f_row6_col2, #T_fd70f_row6_col3, #T_fd70f_row7_col0, #T_fd70f_row7_col1, #T_fd70f_row7_col2, #T_fd70f_row7_col3, #T_fd70f_row8_col0, #T_fd70f_row8_col1, #T_fd70f_row8_col2, #T_fd70f_row8_col3, #T_fd70f_row9_col0, #T_fd70f_row9_col1, #T_fd70f_row9_col2, #T_fd70f_row9_col3 {
#   background-color: lightgreen;
#   color: black;
#   font-size: 12pt;
# }
# </style>
# <table id="T_fd70f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd70f_level0_col0" class="col_heading level0 col0" >TP</th>
#       <th id="T_fd70f_level0_col1" class="col_heading level0 col1" >TN</th>
#       <th id="T_fd70f_level0_col2" class="col_heading level0 col2" >FP</th>
#       <th id="T_fd70f_level0_col3" class="col_heading level0 col3" >FN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd70f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fd70f_row0_col0" class="data row0 col0" >249</td>
#       <td id="T_fd70f_row0_col1" class="data row0 col1" >3225</td>
#       <td id="T_fd70f_row0_col2" class="data row0 col2" >13</td>
#       <td id="T_fd70f_row0_col3" class="data row0 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_fd70f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fd70f_row1_col0" class="data row1 col0" >637</td>
#       <td id="T_fd70f_row1_col1" class="data row1 col1" >2794</td>
#       <td id="T_fd70f_row1_col2" class="data row1 col2" >52</td>
#       <td id="T_fd70f_row1_col3" class="data row1 col3" >18</td>
#     </tr>
#     <tr>
#       <th id="T_fd70f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fd70f_row2_col0" class="data row2 col0" >500</td>
#       <td id="T_fd70f_row2_col1" class="data row2 col1" >2964</td>
#       <td id="T_fd70f_row2_col2" class="data row2 col2" >16</td>
#       <td id="T_fd70f_row2_col3" class="data row2 col3" >21</td>
#     </tr>
#     <tr>
#       <th id="T_fd70f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fd70f_row3_col0" class="data row3 col0" >388</td>
#       <td id="T_fd70f_row3_col1" class="data row3 col1" >3049</td>
#       <td id="T_fd70f_row3_col2" class="data row3 col2" >38</td>
#       <td id="T_fd70f_row3_col3" class="data row3 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_fd70f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fd70f_row4_col0" class="data row4 col0" >324</td>
#       <td id="T_fd70f_row4_col1" class="data row4 col1" >3141</td>
#       <td id="T_fd70f_row4_col2" class="data row4 col2" >21</td>
#       <td id="T_fd70f_row4_col3" class="data row4 col3" >15</td>
#     </tr>
#     <tr>
#       <th id="T_fd70f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fd70f_row5_col0" class="data row5 col0" >286</td>
#       <td id="T_fd70f_row5_col1" class="data row5 col1" >3177</td>
#       <td id="T_fd70f_row5_col2" class="data row5 col2" >8</td>
#       <td id="T_fd70f_row5_col3" class="data row5 col3" >30</td>
#     </tr>
#     <tr>
#       <th id="T_fd70f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fd70f_row6_col0" class="data row6 col0" >258</td>
#       <td id="T_fd70f_row6_col1" class="data row6 col1" >3207</td>
#       <td id="T_fd70f_row6_col2" class="data row6 col2" >25</td>
#       <td id="T_fd70f_row6_col3" class="data row6 col3" >11</td>
#     </tr>
#     <tr>
#       <th id="T_fd70f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fd70f_row7_col0" class="data row7 col0" >257</td>
#       <td id="T_fd70f_row7_col1" class="data row7 col1" >3220</td>
#       <td id="T_fd70f_row7_col2" class="data row7 col2" >10</td>
#       <td id="T_fd70f_row7_col3" class="data row7 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_fd70f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fd70f_row8_col0" class="data row8 col0" >205</td>
#       <td id="T_fd70f_row8_col1" class="data row8 col1" >3256</td>
#       <td id="T_fd70f_row8_col2" class="data row8 col2" >9</td>
#       <td id="T_fd70f_row8_col3" class="data row8 col3" >31</td>
#     </tr>
#     <tr>
#       <th id="T_fd70f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fd70f_row9_col0" class="data row9 col0" >197</td>
#       <td id="T_fd70f_row9_col1" class="data row9 col1" >3276</td>
#       <td id="T_fd70f_row9_col2" class="data row9 col2" >8</td>
#       <td id="T_fd70f_row9_col3" class="data row9 col3" >20</td>
#     </tr>
#   </tbody>
# </table>
# {'accuracy': 0.9428734647243645,
#  'precision': 0.9459747030687018,
#  'recall': 0.9360919073505375,
#  'f1_score': 0.9404624455903041}

# %% [markdown]
# ### Loss чекпоинт

# %%
metrics = MulticlassClassificationMetrics(val_ds_y, ans_val_loss)
print(metrics)
metrics.metrics()
# Out:
# <style type="text/css">
# #T_2aa22 * {
#   background-color: darkgreen;
#   color: white;
#   font-size: 12pt;
# }
# #T_2aa22 td:hover {
#   background-color: green;
#   color: white;
# }
# #T_2aa22_row0_col0, #T_2aa22_row0_col1, #T_2aa22_row0_col2, #T_2aa22_row0_col3, #T_2aa22_row1_col0, #T_2aa22_row1_col1, #T_2aa22_row1_col2, #T_2aa22_row1_col3, #T_2aa22_row2_col0, #T_2aa22_row2_col1, #T_2aa22_row2_col2, #T_2aa22_row2_col3, #T_2aa22_row3_col0, #T_2aa22_row3_col1, #T_2aa22_row3_col2, #T_2aa22_row3_col3, #T_2aa22_row4_col0, #T_2aa22_row4_col1, #T_2aa22_row4_col2, #T_2aa22_row4_col3, #T_2aa22_row5_col0, #T_2aa22_row5_col1, #T_2aa22_row5_col2, #T_2aa22_row5_col3, #T_2aa22_row6_col0, #T_2aa22_row6_col1, #T_2aa22_row6_col2, #T_2aa22_row6_col3, #T_2aa22_row7_col0, #T_2aa22_row7_col1, #T_2aa22_row7_col2, #T_2aa22_row7_col3, #T_2aa22_row8_col0, #T_2aa22_row8_col1, #T_2aa22_row8_col2, #T_2aa22_row8_col3, #T_2aa22_row9_col0, #T_2aa22_row9_col1, #T_2aa22_row9_col2, #T_2aa22_row9_col3 {
#   background-color: lightgreen;
#   color: black;
#   font-size: 12pt;
# }
# </style>
# <table id="T_2aa22">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2aa22_level0_col0" class="col_heading level0 col0" >TP</th>
#       <th id="T_2aa22_level0_col1" class="col_heading level0 col1" >TN</th>
#       <th id="T_2aa22_level0_col2" class="col_heading level0 col2" >FP</th>
#       <th id="T_2aa22_level0_col3" class="col_heading level0 col3" >FN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2aa22_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2aa22_row0_col0" class="data row0 col0" >246</td>
#       <td id="T_2aa22_row0_col1" class="data row0 col1" >3227</td>
#       <td id="T_2aa22_row0_col2" class="data row0 col2" >11</td>
#       <td id="T_2aa22_row0_col3" class="data row0 col3" >17</td>
#     </tr>
#     <tr>
#       <th id="T_2aa22_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2aa22_row1_col0" class="data row1 col0" >635</td>
#       <td id="T_2aa22_row1_col1" class="data row1 col1" >2807</td>
#       <td id="T_2aa22_row1_col2" class="data row1 col2" >39</td>
#       <td id="T_2aa22_row1_col3" class="data row1 col3" >20</td>
#     </tr>
#     <tr>
#       <th id="T_2aa22_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2aa22_row2_col0" class="data row2 col0" >512</td>
#       <td id="T_2aa22_row2_col1" class="data row2 col1" >2942</td>
#       <td id="T_2aa22_row2_col2" class="data row2 col2" >38</td>
#       <td id="T_2aa22_row2_col3" class="data row2 col3" >9</td>
#     </tr>
#     <tr>
#       <th id="T_2aa22_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2aa22_row3_col0" class="data row3 col0" >391</td>
#       <td id="T_2aa22_row3_col1" class="data row3 col1" >3057</td>
#       <td id="T_2aa22_row3_col2" class="data row3 col2" >30</td>
#       <td id="T_2aa22_row3_col3" class="data row3 col3" >23</td>
#     </tr>
#     <tr>
#       <th id="T_2aa22_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2aa22_row4_col0" class="data row4 col0" >327</td>
#       <td id="T_2aa22_row4_col1" class="data row4 col1" >3131</td>
#       <td id="T_2aa22_row4_col2" class="data row4 col2" >31</td>
#       <td id="T_2aa22_row4_col3" class="data row4 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_2aa22_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2aa22_row5_col0" class="data row5 col0" >292</td>
#       <td id="T_2aa22_row5_col1" class="data row5 col1" >3177</td>
#       <td id="T_2aa22_row5_col2" class="data row5 col2" >8</td>
#       <td id="T_2aa22_row5_col3" class="data row5 col3" >24</td>
#     </tr>
#     <tr>
#       <th id="T_2aa22_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2aa22_row6_col0" class="data row6 col0" >255</td>
#       <td id="T_2aa22_row6_col1" class="data row6 col1" >3216</td>
#       <td id="T_2aa22_row6_col2" class="data row6 col2" >16</td>
#       <td id="T_2aa22_row6_col3" class="data row6 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_2aa22_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2aa22_row7_col0" class="data row7 col0" >243</td>
#       <td id="T_2aa22_row7_col1" class="data row7 col1" >3228</td>
#       <td id="T_2aa22_row7_col2" class="data row7 col2" >2</td>
#       <td id="T_2aa22_row7_col3" class="data row7 col3" >28</td>
#     </tr>
#     <tr>
#       <th id="T_2aa22_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2aa22_row8_col0" class="data row8 col0" >198</td>
#       <td id="T_2aa22_row8_col1" class="data row8 col1" >3258</td>
#       <td id="T_2aa22_row8_col2" class="data row8 col2" >7</td>
#       <td id="T_2aa22_row8_col3" class="data row8 col3" >38</td>
#     </tr>
#     <tr>
#       <th id="T_2aa22_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2aa22_row9_col0" class="data row9 col0" >204</td>
#       <td id="T_2aa22_row9_col1" class="data row9 col1" >3268</td>
#       <td id="T_2aa22_row9_col2" class="data row9 col2" >16</td>
#       <td id="T_2aa22_row9_col3" class="data row9 col3" >13</td>
#     </tr>
#   </tbody>
# </table>
# {'accuracy': 0.9434447300771208,
#  'precision': 0.9471648810301427,
#  'recall': 0.9344358814553753,
#  'f1_score': 0.9398663805843416}

# %% [markdown]
# ## Скользящее среднее по accuracy чекпоинт

# %%
metrics = MulticlassClassificationMetrics(val_ds_y, ans_val_avg_categorical_accuracy)
print(metrics)
metrics.metrics()
# Out:
# <style type="text/css">
# #T_d6243 * {
#   background-color: darkgreen;
#   color: white;
#   font-size: 12pt;
# }
# #T_d6243 td:hover {
#   background-color: green;
#   color: white;
# }
# #T_d6243_row0_col0, #T_d6243_row0_col1, #T_d6243_row0_col2, #T_d6243_row0_col3, #T_d6243_row1_col0, #T_d6243_row1_col1, #T_d6243_row1_col2, #T_d6243_row1_col3, #T_d6243_row2_col0, #T_d6243_row2_col1, #T_d6243_row2_col2, #T_d6243_row2_col3, #T_d6243_row3_col0, #T_d6243_row3_col1, #T_d6243_row3_col2, #T_d6243_row3_col3, #T_d6243_row4_col0, #T_d6243_row4_col1, #T_d6243_row4_col2, #T_d6243_row4_col3, #T_d6243_row5_col0, #T_d6243_row5_col1, #T_d6243_row5_col2, #T_d6243_row5_col3, #T_d6243_row6_col0, #T_d6243_row6_col1, #T_d6243_row6_col2, #T_d6243_row6_col3, #T_d6243_row7_col0, #T_d6243_row7_col1, #T_d6243_row7_col2, #T_d6243_row7_col3, #T_d6243_row8_col0, #T_d6243_row8_col1, #T_d6243_row8_col2, #T_d6243_row8_col3, #T_d6243_row9_col0, #T_d6243_row9_col1, #T_d6243_row9_col2, #T_d6243_row9_col3 {
#   background-color: lightgreen;
#   color: black;
#   font-size: 12pt;
# }
# </style>
# <table id="T_d6243">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6243_level0_col0" class="col_heading level0 col0" >TP</th>
#       <th id="T_d6243_level0_col1" class="col_heading level0 col1" >TN</th>
#       <th id="T_d6243_level0_col2" class="col_heading level0 col2" >FP</th>
#       <th id="T_d6243_level0_col3" class="col_heading level0 col3" >FN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6243_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d6243_row0_col0" class="data row0 col0" >255</td>
#       <td id="T_d6243_row0_col1" class="data row0 col1" >3225</td>
#       <td id="T_d6243_row0_col2" class="data row0 col2" >13</td>
#       <td id="T_d6243_row0_col3" class="data row0 col3" >8</td>
#     </tr>
#     <tr>
#       <th id="T_d6243_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d6243_row1_col0" class="data row1 col0" >640</td>
#       <td id="T_d6243_row1_col1" class="data row1 col1" >2820</td>
#       <td id="T_d6243_row1_col2" class="data row1 col2" >26</td>
#       <td id="T_d6243_row1_col3" class="data row1 col3" >15</td>
#     </tr>
#     <tr>
#       <th id="T_d6243_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d6243_row2_col0" class="data row2 col0" >516</td>
#       <td id="T_d6243_row2_col1" class="data row2 col1" >2966</td>
#       <td id="T_d6243_row2_col2" class="data row2 col2" >14</td>
#       <td id="T_d6243_row2_col3" class="data row2 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_d6243_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d6243_row3_col0" class="data row3 col0" >391</td>
#       <td id="T_d6243_row3_col1" class="data row3 col1" >3075</td>
#       <td id="T_d6243_row3_col2" class="data row3 col2" >12</td>
#       <td id="T_d6243_row3_col3" class="data row3 col3" >23</td>
#     </tr>
#     <tr>
#       <th id="T_d6243_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d6243_row4_col0" class="data row4 col0" >325</td>
#       <td id="T_d6243_row4_col1" class="data row4 col1" >3152</td>
#       <td id="T_d6243_row4_col2" class="data row4 col2" >10</td>
#       <td id="T_d6243_row4_col3" class="data row4 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_d6243_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d6243_row5_col0" class="data row5 col0" >299</td>
#       <td id="T_d6243_row5_col1" class="data row5 col1" >3173</td>
#       <td id="T_d6243_row5_col2" class="data row5 col2" >12</td>
#       <td id="T_d6243_row5_col3" class="data row5 col3" >17</td>
#     </tr>
#     <tr>
#       <th id="T_d6243_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d6243_row6_col0" class="data row6 col0" >259</td>
#       <td id="T_d6243_row6_col1" class="data row6 col1" >3216</td>
#       <td id="T_d6243_row6_col2" class="data row6 col2" >16</td>
#       <td id="T_d6243_row6_col3" class="data row6 col3" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d6243_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d6243_row7_col0" class="data row7 col0" >262</td>
#       <td id="T_d6243_row7_col1" class="data row7 col1" >3220</td>
#       <td id="T_d6243_row7_col2" class="data row7 col2" >10</td>
#       <td id="T_d6243_row7_col3" class="data row7 col3" >9</td>
#     </tr>
#     <tr>
#       <th id="T_d6243_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d6243_row8_col0" class="data row8 col0" >217</td>
#       <td id="T_d6243_row8_col1" class="data row8 col1" >3255</td>
#       <td id="T_d6243_row8_col2" class="data row8 col2" >10</td>
#       <td id="T_d6243_row8_col3" class="data row8 col3" >19</td>
#     </tr>
#     <tr>
#       <th id="T_d6243_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d6243_row9_col0" class="data row9 col0" >206</td>
#       <td id="T_d6243_row9_col1" class="data row9 col1" >3276</td>
#       <td id="T_d6243_row9_col2" class="data row9 col2" >8</td>
#       <td id="T_d6243_row9_col3" class="data row9 col3" >11</td>
#     </tr>
#   </tbody>
# </table>
# {'accuracy': 0.9625821193944587,
#  'precision': 0.9611443208654545,
#  'recall': 0.958484832558588,
#  'f1_score': 0.9597133478421981}

# %% [markdown]
# ## Скользящее среднее по loss чекпоинт

# %%
metrics = MulticlassClassificationMetrics(val_ds_y, ans_val_loss)
print(metrics)
metrics.metrics()
# Out:
# <style type="text/css">
# #T_6df2b * {
#   background-color: darkgreen;
#   color: white;
#   font-size: 12pt;
# }
# #T_6df2b td:hover {
#   background-color: green;
#   color: white;
# }
# #T_6df2b_row0_col0, #T_6df2b_row0_col1, #T_6df2b_row0_col2, #T_6df2b_row0_col3, #T_6df2b_row1_col0, #T_6df2b_row1_col1, #T_6df2b_row1_col2, #T_6df2b_row1_col3, #T_6df2b_row2_col0, #T_6df2b_row2_col1, #T_6df2b_row2_col2, #T_6df2b_row2_col3, #T_6df2b_row3_col0, #T_6df2b_row3_col1, #T_6df2b_row3_col2, #T_6df2b_row3_col3, #T_6df2b_row4_col0, #T_6df2b_row4_col1, #T_6df2b_row4_col2, #T_6df2b_row4_col3, #T_6df2b_row5_col0, #T_6df2b_row5_col1, #T_6df2b_row5_col2, #T_6df2b_row5_col3, #T_6df2b_row6_col0, #T_6df2b_row6_col1, #T_6df2b_row6_col2, #T_6df2b_row6_col3, #T_6df2b_row7_col0, #T_6df2b_row7_col1, #T_6df2b_row7_col2, #T_6df2b_row7_col3, #T_6df2b_row8_col0, #T_6df2b_row8_col1, #T_6df2b_row8_col2, #T_6df2b_row8_col3, #T_6df2b_row9_col0, #T_6df2b_row9_col1, #T_6df2b_row9_col2, #T_6df2b_row9_col3 {
#   background-color: lightgreen;
#   color: black;
#   font-size: 12pt;
# }
# </style>
# <table id="T_6df2b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6df2b_level0_col0" class="col_heading level0 col0" >TP</th>
#       <th id="T_6df2b_level0_col1" class="col_heading level0 col1" >TN</th>
#       <th id="T_6df2b_level0_col2" class="col_heading level0 col2" >FP</th>
#       <th id="T_6df2b_level0_col3" class="col_heading level0 col3" >FN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6df2b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6df2b_row0_col0" class="data row0 col0" >246</td>
#       <td id="T_6df2b_row0_col1" class="data row0 col1" >3227</td>
#       <td id="T_6df2b_row0_col2" class="data row0 col2" >11</td>
#       <td id="T_6df2b_row0_col3" class="data row0 col3" >17</td>
#     </tr>
#     <tr>
#       <th id="T_6df2b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6df2b_row1_col0" class="data row1 col0" >635</td>
#       <td id="T_6df2b_row1_col1" class="data row1 col1" >2807</td>
#       <td id="T_6df2b_row1_col2" class="data row1 col2" >39</td>
#       <td id="T_6df2b_row1_col3" class="data row1 col3" >20</td>
#     </tr>
#     <tr>
#       <th id="T_6df2b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6df2b_row2_col0" class="data row2 col0" >512</td>
#       <td id="T_6df2b_row2_col1" class="data row2 col1" >2942</td>
#       <td id="T_6df2b_row2_col2" class="data row2 col2" >38</td>
#       <td id="T_6df2b_row2_col3" class="data row2 col3" >9</td>
#     </tr>
#     <tr>
#       <th id="T_6df2b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6df2b_row3_col0" class="data row3 col0" >391</td>
#       <td id="T_6df2b_row3_col1" class="data row3 col1" >3057</td>
#       <td id="T_6df2b_row3_col2" class="data row3 col2" >30</td>
#       <td id="T_6df2b_row3_col3" class="data row3 col3" >23</td>
#     </tr>
#     <tr>
#       <th id="T_6df2b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6df2b_row4_col0" class="data row4 col0" >327</td>
#       <td id="T_6df2b_row4_col1" class="data row4 col1" >3131</td>
#       <td id="T_6df2b_row4_col2" class="data row4 col2" >31</td>
#       <td id="T_6df2b_row4_col3" class="data row4 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_6df2b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6df2b_row5_col0" class="data row5 col0" >292</td>
#       <td id="T_6df2b_row5_col1" class="data row5 col1" >3177</td>
#       <td id="T_6df2b_row5_col2" class="data row5 col2" >8</td>
#       <td id="T_6df2b_row5_col3" class="data row5 col3" >24</td>
#     </tr>
#     <tr>
#       <th id="T_6df2b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6df2b_row6_col0" class="data row6 col0" >255</td>
#       <td id="T_6df2b_row6_col1" class="data row6 col1" >3216</td>
#       <td id="T_6df2b_row6_col2" class="data row6 col2" >16</td>
#       <td id="T_6df2b_row6_col3" class="data row6 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_6df2b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6df2b_row7_col0" class="data row7 col0" >243</td>
#       <td id="T_6df2b_row7_col1" class="data row7 col1" >3228</td>
#       <td id="T_6df2b_row7_col2" class="data row7 col2" >2</td>
#       <td id="T_6df2b_row7_col3" class="data row7 col3" >28</td>
#     </tr>
#     <tr>
#       <th id="T_6df2b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6df2b_row8_col0" class="data row8 col0" >198</td>
#       <td id="T_6df2b_row8_col1" class="data row8 col1" >3258</td>
#       <td id="T_6df2b_row8_col2" class="data row8 col2" >7</td>
#       <td id="T_6df2b_row8_col3" class="data row8 col3" >38</td>
#     </tr>
#     <tr>
#       <th id="T_6df2b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6df2b_row9_col0" class="data row9 col0" >204</td>
#       <td id="T_6df2b_row9_col1" class="data row9 col1" >3268</td>
#       <td id="T_6df2b_row9_col2" class="data row9 col2" >16</td>
#       <td id="T_6df2b_row9_col3" class="data row9 col3" >13</td>
#     </tr>
#   </tbody>
# </table>
# {'accuracy': 0.9434447300771208,
#  'precision': 0.9471648810301427,
#  'recall': 0.9344358814553753,
#  'f1_score': 0.9398663805843416}
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Метрики плохие.
