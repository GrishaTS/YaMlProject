# %% [markdown]
# # Модель-пример с обновлённым датасетом(OverSampling)

# %% [markdown]
# #### Импорт необходимых библиотек

# %%
import sys

import numpy as np
import pandas as pd
from PIL import Image
import tensorflow as tf
import torchvision as tv
import matplotlib.pyplot as plt
import tensorflow_addons as tfa
from livelossplot import PlotLossesKeras

sys.path.append('../../')

from core.datasets import get_ds
from core.make_answer import make_ans_file

# %% [markdown]
# #### Формируем аугментацию.

# %% [markdown]
# ##### Вариант 1.
#
# - Пишите аугментацию. Объект класса tv.transforms.Compose или tv.transforms.{аугментация}

# %%
transformer = tv.transforms.Compose([
    tv.transforms.RandomPosterize(bits=6, p=0.4),
    tv.transforms.ColorJitter(brightness=.2, hue=0.2, contrast=0.5),
    tv.transforms.RandomAffine(degrees=(-15, 15), translate=(0, 0.1), scale=(0.85, 1)),
])

# %% [markdown]
# ##### Вариант 2. (Лиза добавила крутую возможность)
# - Пишите несколько агументаций как из варианта два
# - Все их записываете в список
#
# Получается так, что для каждого изображения применяется рандомный вариант аугментации, из вами написанных.
#
# Зачем это сделано: Есть некоторые варианты агументации, в которых нет параметра вероятности. Получается так, что Grayscale делает весь трейновый датасет черно-белым, а валидационный и тестовый все такие же разноцветные. То есть в этом случае мы модель не знает, что картинки разноцветные.
#
# `Про варианты агументации и подбор параметров написано в notebooks/skewbek/Augmentation. Всем ознакомиться. (Можно просто делать копипаст комбинаций оттуда)`

# %%
# transformer1 = tv.transforms.Compose([
#     tv.transforms.RandomInvert(p=0.4),
#     tv.transforms.RandomPerspective(distortion_scale=0.2, p=0.4),
# ])
# transformer2 = tv.transforms.Compose([
#     tv.transforms.RandomPosterize(bits=6, p=0.4),
#     tv.transforms.ColorJitter(brightness=.2, hue=0.2, contrast=0.5),
#     tv.transforms.RandomAffine(degrees=(-15, 15), translate=(0, 0.1), scale=(0.85, 1)),
# ])
# transformer3 = tv.transforms.Compose([
#     tv.transforms.ColorJitter(brightness=.2, hue=0.2, contrast=0.5),
#     tv.transforms.RandomAffine(degrees=(-15, 15), translate=(0, 0.1), scale=(0.85, 1)),
#     tv.transforms.RandomPerspective(distortion_scale=0.2, p=0.4),
# ])
# transformer = [transformer1, transformer2, transformer3]

# %% [markdown]
# #### Создаем датасеты
# ```python
# get_ds(
#     file_train, `Путь к трейновому датасету`
#     file_test, `Путь к тестовому датасету`
#     transform=None,  `Аугументация`
#     batch_size=512,  `Размер батча`
#     one_hot=False,  `Формат ответов one_hot_encoding или нет`
#     val_size=0.03,  `Размер валидационного датасета, относительно data_train`
#     back=1,  `На сколько уровней в директории надо подняться наверх, чтобы дойти до корневой`
# )
# ```

# %% [markdown]
# Позже мы будем делать ансамбли и похожие эвристики, поэтому всегда делайте `one_hot=True`

# %%
train_ds, val_ds, test_ds = get_ds('smote_data_train_9650', 'repaired_data_test', transform=transformer, one_hot=True, back=2)

# %% [markdown]
# Для дальнейшей проверки метрик разделяем валидационный датасет на x и y

# %%
val_ds_x = np.array([i[0] for i in val_ds.unbatch().as_numpy_iterator()])
val_ds_y = np.array([i[1] for i in val_ds.unbatch().as_numpy_iterator()])

# %% [markdown]
# Смотрим на получившуюся агументацию.

# %%
plt.figure(figsize=(12, 15))
train_ds_visualization = train_ds[0]
for i in range(20):
    plt.subplot(5, 4, i + 1)
    img = np.array(Image.fromarray((train_ds_visualization[0][i] * 255).astype(np.uint8), 'RGB'))
    plt.imshow(img / 255, cmap=plt.cm.binary)
    plt.title(np.argmax(train_ds_visualization[1][i]))
    plt.axis('off')
plt.show()

# %% [markdown]
# #### Пишем модель
#
# Про свертки и пуллинги написано у Гриши, про skip-connection написано у Миши
#
# Для правильного использования ансамблирования, в финальном слое не пишем функцию активации. Подробнее написано у Дениса.

# %%
model = tf.keras.Sequential([
    tf.keras.Input(shape=(32, 32, 3), batch_size=512),
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0,2),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10),
])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (512, 30, 30, 32)         896
#
#  conv2d_11 (Conv2D)          (512, 28, 28, 64)         18496
#
#  batch_normalization_3 (Batc  (512, 28, 28, 64)        256
#  hNormalization)
#
#  average_pooling2d_5 (Averag  (512, 14, 14, 64)        0
#  ePooling2D)
#
#  conv2d_12 (Conv2D)          (512, 12, 12, 128)        73856
#
#  max_pooling2d_1 (MaxPooling  (512, 6, 6, 128)         0
#  2D)
#
#  flatten_3 (Flatten)         (512, 4608)               0
#
#  dense_9 (Dense)             (512, 256)                1179904
#
#  dropout_3 (Dropout)         (512, 256)                0
#
#  dense_10 (Dense)            (512, 128)                32896
#
#  dense_11 (Dense)            (512, 10)                 1290
#
# =================================================================
# Total params: 1,307,594
# Trainable params: 1,307,466
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# #### Создаем чекпоинты (всем уже рассказал)
# - Если лень, то просто копипаст того, что я написал ниже. НЕ ЗАБЫВАЕМ МЕНЯТЬ ПЕРЕМЕННУЮ `num_model`!!!

# %%
metrics = ['categorical_accuracy',
           tfa.metrics.F1Score(num_classes=10, average='macro', name='f1_score')]
num_model = '_s_2'
callbacks = [
    PlotLossesKeras(),
    tf.keras.callbacks.ModelCheckpoint(
        filepath=f'../checkpoints/model{num_model}_categorical_accuracy.h5',
        monitor='val_categorical_accuracy',
        mode='max',
        save_best_only=True,
    ),
    tf.keras.callbacks.ModelCheckpoint(
        filepath=f'../checkpoints/model{num_model}_loss.h5',
        monitor='val_loss',
        mode='min',
        save_best_only=True,
    ),
    tf.keras.callbacks.ModelCheckpoint(
        filepath=f'../checkpoints/model{num_model}_f1_score.h5',
        monitor='val_f1_score',
        mode='max',
        save_best_only=True,
    ),

    tfa.callbacks.AverageModelCheckpoint(
        update_weights=False,
        filepath=f'../checkpoints/model{num_model}_avg_categorical_accuracy.h5',
        monitor='val_categorical_accuracy',
        mode='max',
        save_best_only=True,
    ),
    tfa.callbacks.AverageModelCheckpoint(
        update_weights=False,
        filepath=f'../checkpoints/model{num_model}_avg_loss.h5',
        monitor='val_loss',
        mode='min',
        save_best_only=True,
    ),
    tfa.callbacks.AverageModelCheckpoint(
        update_weights=False,
        filepath=f'../checkpoints/model{num_model}_avg_f1_score.h5',
        monitor='val_f1_score',
        mode='max',
        save_best_only=True,
    )
]

# %% [markdown]
# #### Компиляция модели
# - Если будете что то менять, то только оптимизатор. Про оптимизаторы написано у Лизы.

# %%
model.compile(
    optimizer=tfa.optimizers.MovingAverage(tf.keras.optimizers.legacy.Adam()),
    metrics=metrics,
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
)

# %% [markdown]
# #### Обучаем модель

# %%
model.fit(train_ds, validation_data=val_ds,
            epochs=100, callbacks=callbacks, verbose=1)
# Out:
# categorical_accuracy
# 	training         	 (min:    0.561, max:    0.984, cur:    0.984)
# 	validation       	 (min:    0.674, max:    0.973, cur:    0.966)
# f1_score
# 	training         	 (min:    0.561, max:    0.984, cur:    0.984)
# 	validation       	 (min:    0.653, max:    0.973, cur:    0.966)
# Loss
# 	training         	 (min:    0.049, max:    1.309, cur:    0.049)
# 	validation       	 (min:    0.132, max:    2.154, cur:    0.165)
# 176/176 [==============================] - 202s 1s/step - loss: 0.0488 - categorical_accuracy: 0.9842 - f1_score: 0.9842 - val_loss: 0.1645 - val_categorical_accuracy: 0.9655 - val_f1_score: 0.9656

# %% [markdown]
# Подгружаем все чекпоинты

# %%
model_categorical_acc = tf.keras.models.load_model(f'../checkpoints/model{num_model}_categorical_accuracy.h5')
model_f1_score = tf.keras.models.load_model(f'../checkpoints/model{num_model}_f1_score.h5')
model_loss = tf.keras.models.load_model(f'../checkpoints/model{num_model}_loss.h5')
model_avg_categorical_acc = tf.keras.models.load_model(f'../checkpoints/model{num_model}_avg_categorical_accuracy.h5')
model_avg_f1_score = tf.keras.models.load_model(f'../checkpoints/model{num_model}_avg_f1_score.h5')
model_avg_loss = tf.keras.models.load_model(f'../checkpoints/model{num_model}_avg_loss.h5')

# %% [markdown]
# У нас поличилось три чекпоинта (три модели). Ниже указан код для получения ответов для всех чекпоинтов по валидационному датасету.

# %%
ans_val_categorical_accuracy = make_ans_file(model_categorical_acc, val_ds_x)
ans_val_f1_score = make_ans_file(model_f1_score, val_ds_x)
ans_val_loss = make_ans_file(model_loss, val_ds_x)
ans_val_avg_categorical_accuracy = make_ans_file(model_avg_categorical_acc, val_ds_x)
ans_val_avg_f1_score = make_ans_file(model_avg_f1_score, val_ds_x)
ans_val_avg_loss = make_ans_file(model_avg_loss, val_ds_x)
anss = [ans_val_categorical_accuracy, ans_val_f1_score, ans_val_loss, ans_val_avg_categorical_accuracy, ans_val_avg_f1_score, ans_val_avg_loss]

# %% [markdown]
# Формируем валидационные ответы.

# %%
val_ds_y = np.argmax(val_ds_y, axis=1)

# %% [markdown]
# Сравниваем валидационные предикты каждого чекпоинта

# %%
for i in range(len(anss) - 1):
    for j in range(i + 1, len(anss)):
        if np.all(anss[i] == anss[j]):
            print(f'чекпоинты {i + 1} и {j + 1} одинаковые')
# Out:
# чекпоинты 1 и 2 одинаковые
# чекпоинты 4 и 5 одинаковые

# %% [markdown]
# `Все ответы разные, значит чекпоинты сохранили модель на разных эпохах. Если ответы будут одинковые, то вывод о чекпоинте делать не надо.`

# %% [markdown]
# - Денис пишет ансамблинг моделей. Когда он допишет, мы применим это для формирования ответа по трем получившимся моделям. То есть, если все чекпоинты разные, то мы будем делать средний ответ по трем предиктам.

# %% [markdown]
# В конце смотрим на метрики и делаем выводы о том, чем хороша эта модель. Какие классы она угадывает лучше/худше всего. Дописываем какую метрику показал kaggle.

# %%
class MulticlassClassificationMetrics:
    def __init__(self, y_true, y_pred):
        self.y_true = np.array(y_true)
        self.y_pred = np.array(y_pred)
        self.matrix_error = self.get_matrix_error()

    def get_matrix_error(self):
        self.class_types = np.unique([self.y_true, self.y_pred])
        TP, FN, FP, TN = [], [], [], []
        for class_type in self.class_types:
            TP.append(np.sum(np.logical_and(self.y_true == self.y_pred, self.y_true == class_type)))
            FN.append(np.sum(np.logical_and(self.y_true == class_type, self.y_pred != class_type)))
            FP.append(np.sum(np.logical_and(self.y_pred == class_type, self.y_true != class_type)))
            TN.append(np.sum(np.logical_and(self.y_pred != class_type, self.y_true != class_type)))
        return pd.DataFrame({
            'class_type': self.class_types,
            'TP': TP, 'TN': TN, 'FP': FP, 'FN': FN,
        }).set_index('class_type')

    def accuracy(self):
        return np.sum(self.y_true == self.y_pred) / self.y_true.shape[0]

    def precision(self, averaging='macro'):
        if averaging == 'macro':
            precisions = self.matrix_error['TP'] / (self.matrix_error['TP'] + self.matrix_error['FP'])
            return np.mean(precisions.replace(np.nan, 0))
        elif averaging == 'micro':
            mean_val = self.matrix_error.mean()
            return mean_val['TP'] / (mean_val['TP'] + mean_val['FP'])

    def recall(self, averaging='macro'):
        if averaging == 'macro':
            recalls = self.matrix_error['TP'] / (self.matrix_error['TP'] + self.matrix_error['FN'])
            return np.mean(recalls.replace(np.nan, 0))
        elif averaging == 'micro':
            mean_val = self.matrix_error.mean()
            return mean_val['TP'] / (mean_val['TP'] + mean_val['FN'])

    def f1_score(self, averaging='macro'):
        if averaging == 'macro':
            reverse_r = (self.matrix_error['TP'] + self.matrix_error['FN']) / self.matrix_error['TP']
            reverse_p = (self.matrix_error['TP'] + self.matrix_error['FP']) / self.matrix_error['TP']
            f1_scores = 2 / (reverse_r + reverse_p)
            return np.mean(f1_scores.replace(np.nan, 0))
        elif averaging == 'micro':
            p = self.precision(averaging)
            r = self.recall(averaging)
            return 2 * p * r / (p + r)

    def metrics(self, averaging='macro'):
        return {
            'accuracy': self.accuracy(),
            'precision': self.precision(averaging),
            'recall': self.recall(averaging),
            'f1_score': self.f1_score(averaging),
        }

    def __str__(self):
        headers = {
            'selector': '*',
            'props': 'background-color: darkgreen; color: white; font-size: 12pt;',
        }
        che_super_mega_puper_visualization_of_cell = { 
            'selector': 'td:hover',
            'props': 'background-color: green; color: white;',
        }
        display(
            self.matrix_error
            .style
            .set_table_styles([
                headers,
                che_super_mega_puper_visualization_of_cell,
            ])
            .set_properties(**{'background-color': 'lightgreen',
                           'color': 'black', 'font-size': '12pt'})
        )
        return ''

    def __repr__(self):
        return (
            f'MulticlassClassificationMetrics(class_types={self.class_types})'
            .replace("'", '').replace(',', ';'))

# %%
plt.hist(val_ds)
# Out:
# C:\Users\Mihail\PycharmProjects\YaMlProject\venv\lib\site-packages\matplotlib\cbook\__init__.py:1399: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   xi = np.asanyarray(xi)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 plt.hist(val_ds)
#
# File ~\PycharmProjects\YaMlProject\venv\lib\site-packages\matplotlib\pyplot.py:2645, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2639 @_copy_docstring_and_deprecators(Axes.hist)
#    2640 def hist(
#    2641         x, bins=None, range=None, density=False, weights=None,
#    2642         cumulative=False, bottom=None, histtype='bar', align='mid',
#    2643         orientation='vertical', rwidth=None, log=False, color=None,
#    2644         label=None, stacked=False, *, data=None, **kwargs):
# -> 2645     return gca().hist(
#    2646         x, bins=bins, range=range, density=density, weights=weights,
#    2647         cumulative=cumulative, bottom=bottom, histtype=histtype,
#    2648         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2649         color=color, label=label, stacked=stacked,
#    2650         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\PycharmProjects\YaMlProject\venv\lib\site-packages\matplotlib\__init__.py:1459, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1456 @functools.wraps(func)
#    1457 def inner(ax, *args, data=None, **kwargs):
#    1458     if data is None:
# -> 1459         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1461     bound = new_sig.bind(ax, *args, **kwargs)
#    1462     auto_label = (bound.arguments.get(label_namer)
#    1463                   or bound.kwargs.get(label_namer))
#
# File ~\PycharmProjects\YaMlProject\venv\lib\site-packages\matplotlib\axes\_axes.py:6703, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6700     stacked = True
#    6702 # Massage 'x' for processing.
# -> 6703 x = cbook._reshape_2D(x, 'x')
#    6704 nx = len(x)  # number of datasets
#    6706 # Process unit information.  _process_unit_info sets the unit and
#    6707 # converts the first dataset; then we convert each following dataset
#    6708 # one at a time.
#
# File ~\PycharmProjects\YaMlProject\venv\lib\site-packages\matplotlib\cbook\__init__.py:1399, in _reshape_2D(X, name)
#    1397     else:
#    1398         is_1d = False
# -> 1399 xi = np.asanyarray(xi)
#    1400 nd = np.ndim(xi)
#    1401 if nd > 1:
#
# ValueError: could not broadcast input array from shape (512,32,32,3) into shape (512,)

# %% [markdown]
# ### Accuracy чекпоинт

# %%
metrics = MulticlassClassificationMetrics(val_ds_y, ans_val_categorical_accuracy)
print(metrics)
metrics.metrics()
# Out:
# <style type="text/css">
# #T_ff603 * {
#   background-color: darkgreen;
#   color: white;
#   font-size: 12pt;
# }
# #T_ff603 td:hover {
#   background-color: green;
#   color: white;
# }
# #T_ff603_row0_col0, #T_ff603_row0_col1, #T_ff603_row0_col2, #T_ff603_row0_col3, #T_ff603_row1_col0, #T_ff603_row1_col1, #T_ff603_row1_col2, #T_ff603_row1_col3, #T_ff603_row2_col0, #T_ff603_row2_col1, #T_ff603_row2_col2, #T_ff603_row2_col3, #T_ff603_row3_col0, #T_ff603_row3_col1, #T_ff603_row3_col2, #T_ff603_row3_col3, #T_ff603_row4_col0, #T_ff603_row4_col1, #T_ff603_row4_col2, #T_ff603_row4_col3, #T_ff603_row5_col0, #T_ff603_row5_col1, #T_ff603_row5_col2, #T_ff603_row5_col3, #T_ff603_row6_col0, #T_ff603_row6_col1, #T_ff603_row6_col2, #T_ff603_row6_col3, #T_ff603_row7_col0, #T_ff603_row7_col1, #T_ff603_row7_col2, #T_ff603_row7_col3, #T_ff603_row8_col0, #T_ff603_row8_col1, #T_ff603_row8_col2, #T_ff603_row8_col3, #T_ff603_row9_col0, #T_ff603_row9_col1, #T_ff603_row9_col2, #T_ff603_row9_col3 {
#   background-color: lightgreen;
#   color: black;
#   font-size: 12pt;
# }
# </style>
# <table id="T_ff603">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff603_level0_col0" class="col_heading level0 col0" >TP</th>
#       <th id="T_ff603_level0_col1" class="col_heading level0 col1" >TN</th>
#       <th id="T_ff603_level0_col2" class="col_heading level0 col2" >FP</th>
#       <th id="T_ff603_level0_col3" class="col_heading level0 col3" >FN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff603_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff603_row0_col0" class="data row0 col0" >669</td>
#       <td id="T_ff603_row0_col1" class="data row0 col1" >6065</td>
#       <td id="T_ff603_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_ff603_row0_col3" class="data row0 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_ff603_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ff603_row1_col0" class="data row1 col0" >680</td>
#       <td id="T_ff603_row1_col1" class="data row1 col1" >6012</td>
#       <td id="T_ff603_row1_col2" class="data row1 col2" >29</td>
#       <td id="T_ff603_row1_col3" class="data row1 col3" >35</td>
#     </tr>
#     <tr>
#       <th id="T_ff603_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ff603_row2_col0" class="data row2 col0" >663</td>
#       <td id="T_ff603_row2_col1" class="data row2 col1" >6041</td>
#       <td id="T_ff603_row2_col2" class="data row2 col2" >25</td>
#       <td id="T_ff603_row2_col3" class="data row2 col3" >27</td>
#     </tr>
#     <tr>
#       <th id="T_ff603_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ff603_row3_col0" class="data row3 col0" >618</td>
#       <td id="T_ff603_row3_col1" class="data row3 col1" >6086</td>
#       <td id="T_ff603_row3_col2" class="data row3 col2" >30</td>
#       <td id="T_ff603_row3_col3" class="data row3 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_ff603_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ff603_row4_col0" class="data row4 col0" >646</td>
#       <td id="T_ff603_row4_col1" class="data row4 col1" >6083</td>
#       <td id="T_ff603_row4_col2" class="data row4 col2" >13</td>
#       <td id="T_ff603_row4_col3" class="data row4 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_ff603_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ff603_row5_col0" class="data row5 col0" >663</td>
#       <td id="T_ff603_row5_col1" class="data row5 col1" >6053</td>
#       <td id="T_ff603_row5_col2" class="data row5 col2" >16</td>
#       <td id="T_ff603_row5_col3" class="data row5 col3" >24</td>
#     </tr>
#     <tr>
#       <th id="T_ff603_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ff603_row6_col0" class="data row6 col0" >652</td>
#       <td id="T_ff603_row6_col1" class="data row6 col1" >6074</td>
#       <td id="T_ff603_row6_col2" class="data row6 col2" >17</td>
#       <td id="T_ff603_row6_col3" class="data row6 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_ff603_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ff603_row7_col0" class="data row7 col0" >671</td>
#       <td id="T_ff603_row7_col1" class="data row7 col1" >6063</td>
#       <td id="T_ff603_row7_col2" class="data row7 col2" >10</td>
#       <td id="T_ff603_row7_col3" class="data row7 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_ff603_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ff603_row8_col0" class="data row8 col0" >628</td>
#       <td id="T_ff603_row8_col1" class="data row8 col1" >6100</td>
#       <td id="T_ff603_row8_col2" class="data row8 col2" >14</td>
#       <td id="T_ff603_row8_col3" class="data row8 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_ff603_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ff603_row9_col0" class="data row9 col0" >682</td>
#       <td id="T_ff603_row9_col1" class="data row9 col1" >6043</td>
#       <td id="T_ff603_row9_col2" class="data row9 col2" >20</td>
#       <td id="T_ff603_row9_col3" class="data row9 col3" >11</td>
#     </tr>
#   </tbody>
# </table>
# {'accuracy': 0.9727649496743636,
#  'precision': 0.9728053119221507,
#  'recall': 0.9728977464107098,
#  'f1_score': 0.9728371695700687}

# %% [markdown]
# - $FP_1=15$. То есть, модель предсказала 15 раз 1, когда на самом деле там была не 1. Наверное модель плохо различает 1 и 7.
# - $FN_1=15$. То есть, модель 15 раз ошиблась, когда угадывала 1.
#
# Метрики более менее хоршие. Переобучения нет. Ставить модель на больше эпох нет смысла, потому что последние 50 эпох модель практически не меняла веса.
#
# `Это не шаблон!!! Писать надо как сами посчитаете`

# %% [markdown]
# ### Loss чекпоинт

# %%
metrics = MulticlassClassificationMetrics(val_ds_y, ans_val_loss)
print(metrics)
metrics.metrics()
# Out:
# <style type="text/css">
# #T_90a27 * {
#   background-color: darkgreen;
#   color: white;
#   font-size: 12pt;
# }
# #T_90a27 td:hover {
#   background-color: green;
#   color: white;
# }
# #T_90a27_row0_col0, #T_90a27_row0_col1, #T_90a27_row0_col2, #T_90a27_row0_col3, #T_90a27_row1_col0, #T_90a27_row1_col1, #T_90a27_row1_col2, #T_90a27_row1_col3, #T_90a27_row2_col0, #T_90a27_row2_col1, #T_90a27_row2_col2, #T_90a27_row2_col3, #T_90a27_row3_col0, #T_90a27_row3_col1, #T_90a27_row3_col2, #T_90a27_row3_col3, #T_90a27_row4_col0, #T_90a27_row4_col1, #T_90a27_row4_col2, #T_90a27_row4_col3, #T_90a27_row5_col0, #T_90a27_row5_col1, #T_90a27_row5_col2, #T_90a27_row5_col3, #T_90a27_row6_col0, #T_90a27_row6_col1, #T_90a27_row6_col2, #T_90a27_row6_col3, #T_90a27_row7_col0, #T_90a27_row7_col1, #T_90a27_row7_col2, #T_90a27_row7_col3, #T_90a27_row8_col0, #T_90a27_row8_col1, #T_90a27_row8_col2, #T_90a27_row8_col3, #T_90a27_row9_col0, #T_90a27_row9_col1, #T_90a27_row9_col2, #T_90a27_row9_col3 {
#   background-color: lightgreen;
#   color: black;
#   font-size: 12pt;
# }
# </style>
# <table id="T_90a27">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90a27_level0_col0" class="col_heading level0 col0" >TP</th>
#       <th id="T_90a27_level0_col1" class="col_heading level0 col1" >TN</th>
#       <th id="T_90a27_level0_col2" class="col_heading level0 col2" >FP</th>
#       <th id="T_90a27_level0_col3" class="col_heading level0 col3" >FN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90a27_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_90a27_row0_col0" class="data row0 col0" >669</td>
#       <td id="T_90a27_row0_col1" class="data row0 col1" >6061</td>
#       <td id="T_90a27_row0_col2" class="data row0 col2" >14</td>
#       <td id="T_90a27_row0_col3" class="data row0 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_90a27_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_90a27_row1_col0" class="data row1 col0" >677</td>
#       <td id="T_90a27_row1_col1" class="data row1 col1" >6009</td>
#       <td id="T_90a27_row1_col2" class="data row1 col2" >32</td>
#       <td id="T_90a27_row1_col3" class="data row1 col3" >38</td>
#     </tr>
#     <tr>
#       <th id="T_90a27_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_90a27_row2_col0" class="data row2 col0" >664</td>
#       <td id="T_90a27_row2_col1" class="data row2 col1" >6040</td>
#       <td id="T_90a27_row2_col2" class="data row2 col2" >26</td>
#       <td id="T_90a27_row2_col3" class="data row2 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_90a27_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_90a27_row3_col0" class="data row3 col0" >603</td>
#       <td id="T_90a27_row3_col1" class="data row3 col1" >6096</td>
#       <td id="T_90a27_row3_col2" class="data row3 col2" >20</td>
#       <td id="T_90a27_row3_col3" class="data row3 col3" >37</td>
#     </tr>
#     <tr>
#       <th id="T_90a27_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_90a27_row4_col0" class="data row4 col0" >639</td>
#       <td id="T_90a27_row4_col1" class="data row4 col1" >6088</td>
#       <td id="T_90a27_row4_col2" class="data row4 col2" >8</td>
#       <td id="T_90a27_row4_col3" class="data row4 col3" >21</td>
#     </tr>
#     <tr>
#       <th id="T_90a27_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_90a27_row5_col0" class="data row5 col0" >667</td>
#       <td id="T_90a27_row5_col1" class="data row5 col1" >6046</td>
#       <td id="T_90a27_row5_col2" class="data row5 col2" >23</td>
#       <td id="T_90a27_row5_col3" class="data row5 col3" >20</td>
#     </tr>
#     <tr>
#       <th id="T_90a27_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_90a27_row6_col0" class="data row6 col0" >644</td>
#       <td id="T_90a27_row6_col1" class="data row6 col1" >6076</td>
#       <td id="T_90a27_row6_col2" class="data row6 col2" >15</td>
#       <td id="T_90a27_row6_col3" class="data row6 col3" >21</td>
#     </tr>
#     <tr>
#       <th id="T_90a27_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_90a27_row7_col0" class="data row7 col0" >676</td>
#       <td id="T_90a27_row7_col1" class="data row7 col1" >6056</td>
#       <td id="T_90a27_row7_col2" class="data row7 col2" >17</td>
#       <td id="T_90a27_row7_col3" class="data row7 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_90a27_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_90a27_row8_col0" class="data row8 col0" >633</td>
#       <td id="T_90a27_row8_col1" class="data row8 col1" >6081</td>
#       <td id="T_90a27_row8_col2" class="data row8 col2" >33</td>
#       <td id="T_90a27_row8_col3" class="data row8 col3" >9</td>
#     </tr>
#     <tr>
#       <th id="T_90a27_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_90a27_row9_col0" class="data row9 col0" >677</td>
#       <td id="T_90a27_row9_col1" class="data row9 col1" >6044</td>
#       <td id="T_90a27_row9_col2" class="data row9 col2" >19</td>
#       <td id="T_90a27_row9_col3" class="data row9 col3" >16</td>
#     </tr>
#   </tbody>
# </table>
# {'accuracy': 0.9693605683836589,
#  'precision': 0.9694745037839476,
#  'recall': 0.9693873514777801,
#  'f1_score': 0.9693613520576643}

# %% [markdown]
# - $FN_1=28$.
# - $FP_1=19$.
# - $FP_2=18$.
# - $FP_3=18$.
# - $FN_3=16$.
# - $FN_8=15$.
#
# Модель очень плохо справляется с единицами. Так же можно сказать что 2 и 3 модель часто угадывает ложно.
#
# Метрики хуже, чем у accuracy чекпоинта. Но все равно посмотрим, что скажут метрики kaggle.

# %% [markdown]
# ### F1-score чекпоинт

# %%
metrics = MulticlassClassificationMetrics(val_ds_y, ans_val_f1_score)
print(metrics)
metrics.metrics()
# Out:
# <style type="text/css">
# #T_e4ed0 * {
#   background-color: darkgreen;
#   color: white;
#   font-size: 12pt;
# }
# #T_e4ed0 td:hover {
#   background-color: green;
#   color: white;
# }
# #T_e4ed0_row0_col0, #T_e4ed0_row0_col1, #T_e4ed0_row0_col2, #T_e4ed0_row0_col3, #T_e4ed0_row1_col0, #T_e4ed0_row1_col1, #T_e4ed0_row1_col2, #T_e4ed0_row1_col3, #T_e4ed0_row2_col0, #T_e4ed0_row2_col1, #T_e4ed0_row2_col2, #T_e4ed0_row2_col3, #T_e4ed0_row3_col0, #T_e4ed0_row3_col1, #T_e4ed0_row3_col2, #T_e4ed0_row3_col3, #T_e4ed0_row4_col0, #T_e4ed0_row4_col1, #T_e4ed0_row4_col2, #T_e4ed0_row4_col3, #T_e4ed0_row5_col0, #T_e4ed0_row5_col1, #T_e4ed0_row5_col2, #T_e4ed0_row5_col3, #T_e4ed0_row6_col0, #T_e4ed0_row6_col1, #T_e4ed0_row6_col2, #T_e4ed0_row6_col3, #T_e4ed0_row7_col0, #T_e4ed0_row7_col1, #T_e4ed0_row7_col2, #T_e4ed0_row7_col3, #T_e4ed0_row8_col0, #T_e4ed0_row8_col1, #T_e4ed0_row8_col2, #T_e4ed0_row8_col3, #T_e4ed0_row9_col0, #T_e4ed0_row9_col1, #T_e4ed0_row9_col2, #T_e4ed0_row9_col3 {
#   background-color: lightgreen;
#   color: black;
#   font-size: 12pt;
# }
# </style>
# <table id="T_e4ed0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4ed0_level0_col0" class="col_heading level0 col0" >TP</th>
#       <th id="T_e4ed0_level0_col1" class="col_heading level0 col1" >TN</th>
#       <th id="T_e4ed0_level0_col2" class="col_heading level0 col2" >FP</th>
#       <th id="T_e4ed0_level0_col3" class="col_heading level0 col3" >FN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4ed0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e4ed0_row0_col0" class="data row0 col0" >669</td>
#       <td id="T_e4ed0_row0_col1" class="data row0 col1" >6065</td>
#       <td id="T_e4ed0_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_e4ed0_row0_col3" class="data row0 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_e4ed0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e4ed0_row1_col0" class="data row1 col0" >680</td>
#       <td id="T_e4ed0_row1_col1" class="data row1 col1" >6012</td>
#       <td id="T_e4ed0_row1_col2" class="data row1 col2" >29</td>
#       <td id="T_e4ed0_row1_col3" class="data row1 col3" >35</td>
#     </tr>
#     <tr>
#       <th id="T_e4ed0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e4ed0_row2_col0" class="data row2 col0" >663</td>
#       <td id="T_e4ed0_row2_col1" class="data row2 col1" >6041</td>
#       <td id="T_e4ed0_row2_col2" class="data row2 col2" >25</td>
#       <td id="T_e4ed0_row2_col3" class="data row2 col3" >27</td>
#     </tr>
#     <tr>
#       <th id="T_e4ed0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e4ed0_row3_col0" class="data row3 col0" >618</td>
#       <td id="T_e4ed0_row3_col1" class="data row3 col1" >6086</td>
#       <td id="T_e4ed0_row3_col2" class="data row3 col2" >30</td>
#       <td id="T_e4ed0_row3_col3" class="data row3 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_e4ed0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e4ed0_row4_col0" class="data row4 col0" >646</td>
#       <td id="T_e4ed0_row4_col1" class="data row4 col1" >6083</td>
#       <td id="T_e4ed0_row4_col2" class="data row4 col2" >13</td>
#       <td id="T_e4ed0_row4_col3" class="data row4 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_e4ed0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e4ed0_row5_col0" class="data row5 col0" >663</td>
#       <td id="T_e4ed0_row5_col1" class="data row5 col1" >6053</td>
#       <td id="T_e4ed0_row5_col2" class="data row5 col2" >16</td>
#       <td id="T_e4ed0_row5_col3" class="data row5 col3" >24</td>
#     </tr>
#     <tr>
#       <th id="T_e4ed0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e4ed0_row6_col0" class="data row6 col0" >652</td>
#       <td id="T_e4ed0_row6_col1" class="data row6 col1" >6074</td>
#       <td id="T_e4ed0_row6_col2" class="data row6 col2" >17</td>
#       <td id="T_e4ed0_row6_col3" class="data row6 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_e4ed0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e4ed0_row7_col0" class="data row7 col0" >671</td>
#       <td id="T_e4ed0_row7_col1" class="data row7 col1" >6063</td>
#       <td id="T_e4ed0_row7_col2" class="data row7 col2" >10</td>
#       <td id="T_e4ed0_row7_col3" class="data row7 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_e4ed0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e4ed0_row8_col0" class="data row8 col0" >628</td>
#       <td id="T_e4ed0_row8_col1" class="data row8 col1" >6100</td>
#       <td id="T_e4ed0_row8_col2" class="data row8 col2" >14</td>
#       <td id="T_e4ed0_row8_col3" class="data row8 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_e4ed0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e4ed0_row9_col0" class="data row9 col0" >682</td>
#       <td id="T_e4ed0_row9_col1" class="data row9 col1" >6043</td>
#       <td id="T_e4ed0_row9_col2" class="data row9 col2" >20</td>
#       <td id="T_e4ed0_row9_col3" class="data row9 col3" >11</td>
#     </tr>
#   </tbody>
# </table>
# {'accuracy': 0.9727649496743636,
#  'precision': 0.9728053119221507,
#  'recall': 0.9728977464107098,
#  'f1_score': 0.9728371695700687}

# %% [markdown]
# - $FN_1=19$.
# - $FP_2=19$.
#
# Модель плохо справляется с единицами и двойками.
#
# Метрики неплохие.

# %% [markdown]
# ### Среднее скользящее по accuracy чекпоинт

# %%
metrics = MulticlassClassificationMetrics(val_ds_y, ans_val_avg_categorical_accuracy)
print(metrics)
metrics.metrics()
# Out:
# <style type="text/css">
# #T_289eb * {
#   background-color: darkgreen;
#   color: white;
#   font-size: 12pt;
# }
# #T_289eb td:hover {
#   background-color: green;
#   color: white;
# }
# #T_289eb_row0_col0, #T_289eb_row0_col1, #T_289eb_row0_col2, #T_289eb_row0_col3, #T_289eb_row1_col0, #T_289eb_row1_col1, #T_289eb_row1_col2, #T_289eb_row1_col3, #T_289eb_row2_col0, #T_289eb_row2_col1, #T_289eb_row2_col2, #T_289eb_row2_col3, #T_289eb_row3_col0, #T_289eb_row3_col1, #T_289eb_row3_col2, #T_289eb_row3_col3, #T_289eb_row4_col0, #T_289eb_row4_col1, #T_289eb_row4_col2, #T_289eb_row4_col3, #T_289eb_row5_col0, #T_289eb_row5_col1, #T_289eb_row5_col2, #T_289eb_row5_col3, #T_289eb_row6_col0, #T_289eb_row6_col1, #T_289eb_row6_col2, #T_289eb_row6_col3, #T_289eb_row7_col0, #T_289eb_row7_col1, #T_289eb_row7_col2, #T_289eb_row7_col3, #T_289eb_row8_col0, #T_289eb_row8_col1, #T_289eb_row8_col2, #T_289eb_row8_col3, #T_289eb_row9_col0, #T_289eb_row9_col1, #T_289eb_row9_col2, #T_289eb_row9_col3 {
#   background-color: lightgreen;
#   color: black;
#   font-size: 12pt;
# }
# </style>
# <table id="T_289eb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_289eb_level0_col0" class="col_heading level0 col0" >TP</th>
#       <th id="T_289eb_level0_col1" class="col_heading level0 col1" >TN</th>
#       <th id="T_289eb_level0_col2" class="col_heading level0 col2" >FP</th>
#       <th id="T_289eb_level0_col3" class="col_heading level0 col3" >FN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_289eb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_289eb_row0_col0" class="data row0 col0" >674</td>
#       <td id="T_289eb_row0_col1" class="data row0 col1" >6063</td>
#       <td id="T_289eb_row0_col2" class="data row0 col2" >12</td>
#       <td id="T_289eb_row0_col3" class="data row0 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_289eb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_289eb_row1_col0" class="data row1 col0" >682</td>
#       <td id="T_289eb_row1_col1" class="data row1 col1" >6014</td>
#       <td id="T_289eb_row1_col2" class="data row1 col2" >27</td>
#       <td id="T_289eb_row1_col3" class="data row1 col3" >33</td>
#     </tr>
#     <tr>
#       <th id="T_289eb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_289eb_row2_col0" class="data row2 col0" >670</td>
#       <td id="T_289eb_row2_col1" class="data row2 col1" >6045</td>
#       <td id="T_289eb_row2_col2" class="data row2 col2" >21</td>
#       <td id="T_289eb_row2_col3" class="data row2 col3" >20</td>
#     </tr>
#     <tr>
#       <th id="T_289eb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_289eb_row3_col0" class="data row3 col0" >615</td>
#       <td id="T_289eb_row3_col1" class="data row3 col1" >6098</td>
#       <td id="T_289eb_row3_col2" class="data row3 col2" >18</td>
#       <td id="T_289eb_row3_col3" class="data row3 col3" >25</td>
#     </tr>
#     <tr>
#       <th id="T_289eb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_289eb_row4_col0" class="data row4 col0" >645</td>
#       <td id="T_289eb_row4_col1" class="data row4 col1" >6085</td>
#       <td id="T_289eb_row4_col2" class="data row4 col2" >11</td>
#       <td id="T_289eb_row4_col3" class="data row4 col3" >15</td>
#     </tr>
#     <tr>
#       <th id="T_289eb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_289eb_row5_col0" class="data row5 col0" >665</td>
#       <td id="T_289eb_row5_col1" class="data row5 col1" >6049</td>
#       <td id="T_289eb_row5_col2" class="data row5 col2" >20</td>
#       <td id="T_289eb_row5_col3" class="data row5 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_289eb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_289eb_row6_col0" class="data row6 col0" >652</td>
#       <td id="T_289eb_row6_col1" class="data row6 col1" >6077</td>
#       <td id="T_289eb_row6_col2" class="data row6 col2" >14</td>
#       <td id="T_289eb_row6_col3" class="data row6 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_289eb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_289eb_row7_col0" class="data row7 col0" >675</td>
#       <td id="T_289eb_row7_col1" class="data row7 col1" >6063</td>
#       <td id="T_289eb_row7_col2" class="data row7 col2" >10</td>
#       <td id="T_289eb_row7_col3" class="data row7 col3" >8</td>
#     </tr>
#     <tr>
#       <th id="T_289eb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_289eb_row8_col0" class="data row8 col0" >632</td>
#       <td id="T_289eb_row8_col1" class="data row8 col1" >6098</td>
#       <td id="T_289eb_row8_col2" class="data row8 col2" >16</td>
#       <td id="T_289eb_row8_col3" class="data row8 col3" >10</td>
#     </tr>
#     <tr>
#       <th id="T_289eb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_289eb_row9_col0" class="data row9 col0" >681</td>
#       <td id="T_289eb_row9_col1" class="data row9 col1" >6047</td>
#       <td id="T_289eb_row9_col2" class="data row9 col2" >16</td>
#       <td id="T_289eb_row9_col3" class="data row9 col3" >12</td>
#     </tr>
#   </tbody>
# </table>
# {'accuracy': 0.9755772646536413,
#  'precision': 0.9756366910412468,
#  'recall': 0.975661433850815,
#  'f1_score': 0.9756387610242843}

# %% [markdown]
# ### Среднее скользящее по f1-score чекпоинт

# %%
metrics = MulticlassClassificationMetrics(val_ds_y, ans_val_avg_f1_score)
print(metrics)
metrics.metrics()
# Out:
# <style type="text/css">
# #T_baeeb * {
#   background-color: darkgreen;
#   color: white;
#   font-size: 12pt;
# }
# #T_baeeb td:hover {
#   background-color: green;
#   color: white;
# }
# #T_baeeb_row0_col0, #T_baeeb_row0_col1, #T_baeeb_row0_col2, #T_baeeb_row0_col3, #T_baeeb_row1_col0, #T_baeeb_row1_col1, #T_baeeb_row1_col2, #T_baeeb_row1_col3, #T_baeeb_row2_col0, #T_baeeb_row2_col1, #T_baeeb_row2_col2, #T_baeeb_row2_col3, #T_baeeb_row3_col0, #T_baeeb_row3_col1, #T_baeeb_row3_col2, #T_baeeb_row3_col3, #T_baeeb_row4_col0, #T_baeeb_row4_col1, #T_baeeb_row4_col2, #T_baeeb_row4_col3, #T_baeeb_row5_col0, #T_baeeb_row5_col1, #T_baeeb_row5_col2, #T_baeeb_row5_col3, #T_baeeb_row6_col0, #T_baeeb_row6_col1, #T_baeeb_row6_col2, #T_baeeb_row6_col3, #T_baeeb_row7_col0, #T_baeeb_row7_col1, #T_baeeb_row7_col2, #T_baeeb_row7_col3, #T_baeeb_row8_col0, #T_baeeb_row8_col1, #T_baeeb_row8_col2, #T_baeeb_row8_col3, #T_baeeb_row9_col0, #T_baeeb_row9_col1, #T_baeeb_row9_col2, #T_baeeb_row9_col3 {
#   background-color: lightgreen;
#   color: black;
#   font-size: 12pt;
# }
# </style>
# <table id="T_baeeb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_baeeb_level0_col0" class="col_heading level0 col0" >TP</th>
#       <th id="T_baeeb_level0_col1" class="col_heading level0 col1" >TN</th>
#       <th id="T_baeeb_level0_col2" class="col_heading level0 col2" >FP</th>
#       <th id="T_baeeb_level0_col3" class="col_heading level0 col3" >FN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_baeeb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_baeeb_row0_col0" class="data row0 col0" >674</td>
#       <td id="T_baeeb_row0_col1" class="data row0 col1" >6063</td>
#       <td id="T_baeeb_row0_col2" class="data row0 col2" >12</td>
#       <td id="T_baeeb_row0_col3" class="data row0 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_baeeb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_baeeb_row1_col0" class="data row1 col0" >682</td>
#       <td id="T_baeeb_row1_col1" class="data row1 col1" >6014</td>
#       <td id="T_baeeb_row1_col2" class="data row1 col2" >27</td>
#       <td id="T_baeeb_row1_col3" class="data row1 col3" >33</td>
#     </tr>
#     <tr>
#       <th id="T_baeeb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_baeeb_row2_col0" class="data row2 col0" >670</td>
#       <td id="T_baeeb_row2_col1" class="data row2 col1" >6045</td>
#       <td id="T_baeeb_row2_col2" class="data row2 col2" >21</td>
#       <td id="T_baeeb_row2_col3" class="data row2 col3" >20</td>
#     </tr>
#     <tr>
#       <th id="T_baeeb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_baeeb_row3_col0" class="data row3 col0" >615</td>
#       <td id="T_baeeb_row3_col1" class="data row3 col1" >6098</td>
#       <td id="T_baeeb_row3_col2" class="data row3 col2" >18</td>
#       <td id="T_baeeb_row3_col3" class="data row3 col3" >25</td>
#     </tr>
#     <tr>
#       <th id="T_baeeb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_baeeb_row4_col0" class="data row4 col0" >645</td>
#       <td id="T_baeeb_row4_col1" class="data row4 col1" >6085</td>
#       <td id="T_baeeb_row4_col2" class="data row4 col2" >11</td>
#       <td id="T_baeeb_row4_col3" class="data row4 col3" >15</td>
#     </tr>
#     <tr>
#       <th id="T_baeeb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_baeeb_row5_col0" class="data row5 col0" >665</td>
#       <td id="T_baeeb_row5_col1" class="data row5 col1" >6049</td>
#       <td id="T_baeeb_row5_col2" class="data row5 col2" >20</td>
#       <td id="T_baeeb_row5_col3" class="data row5 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_baeeb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_baeeb_row6_col0" class="data row6 col0" >652</td>
#       <td id="T_baeeb_row6_col1" class="data row6 col1" >6077</td>
#       <td id="T_baeeb_row6_col2" class="data row6 col2" >14</td>
#       <td id="T_baeeb_row6_col3" class="data row6 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_baeeb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_baeeb_row7_col0" class="data row7 col0" >675</td>
#       <td id="T_baeeb_row7_col1" class="data row7 col1" >6063</td>
#       <td id="T_baeeb_row7_col2" class="data row7 col2" >10</td>
#       <td id="T_baeeb_row7_col3" class="data row7 col3" >8</td>
#     </tr>
#     <tr>
#       <th id="T_baeeb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_baeeb_row8_col0" class="data row8 col0" >632</td>
#       <td id="T_baeeb_row8_col1" class="data row8 col1" >6098</td>
#       <td id="T_baeeb_row8_col2" class="data row8 col2" >16</td>
#       <td id="T_baeeb_row8_col3" class="data row8 col3" >10</td>
#     </tr>
#     <tr>
#       <th id="T_baeeb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_baeeb_row9_col0" class="data row9 col0" >681</td>
#       <td id="T_baeeb_row9_col1" class="data row9 col1" >6047</td>
#       <td id="T_baeeb_row9_col2" class="data row9 col2" >16</td>
#       <td id="T_baeeb_row9_col3" class="data row9 col3" >12</td>
#     </tr>
#   </tbody>
# </table>
# {'accuracy': 0.9755772646536413,
#  'precision': 0.9756366910412468,
#  'recall': 0.975661433850815,
#  'f1_score': 0.9756387610242843}

# %% [markdown]
# ### Среднее скользящее по loss чекпоинт

# %%
metrics = MulticlassClassificationMetrics(val_ds_y, ans_val_avg_loss)
print(metrics)
metrics.metrics()
# Out:
# <style type="text/css">
# #T_547a7 * {
#   background-color: darkgreen;
#   color: white;
#   font-size: 12pt;
# }
# #T_547a7 td:hover {
#   background-color: green;
#   color: white;
# }
# #T_547a7_row0_col0, #T_547a7_row0_col1, #T_547a7_row0_col2, #T_547a7_row0_col3, #T_547a7_row1_col0, #T_547a7_row1_col1, #T_547a7_row1_col2, #T_547a7_row1_col3, #T_547a7_row2_col0, #T_547a7_row2_col1, #T_547a7_row2_col2, #T_547a7_row2_col3, #T_547a7_row3_col0, #T_547a7_row3_col1, #T_547a7_row3_col2, #T_547a7_row3_col3, #T_547a7_row4_col0, #T_547a7_row4_col1, #T_547a7_row4_col2, #T_547a7_row4_col3, #T_547a7_row5_col0, #T_547a7_row5_col1, #T_547a7_row5_col2, #T_547a7_row5_col3, #T_547a7_row6_col0, #T_547a7_row6_col1, #T_547a7_row6_col2, #T_547a7_row6_col3, #T_547a7_row7_col0, #T_547a7_row7_col1, #T_547a7_row7_col2, #T_547a7_row7_col3, #T_547a7_row8_col0, #T_547a7_row8_col1, #T_547a7_row8_col2, #T_547a7_row8_col3, #T_547a7_row9_col0, #T_547a7_row9_col1, #T_547a7_row9_col2, #T_547a7_row9_col3 {
#   background-color: lightgreen;
#   color: black;
#   font-size: 12pt;
# }
# </style>
# <table id="T_547a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_547a7_level0_col0" class="col_heading level0 col0" >TP</th>
#       <th id="T_547a7_level0_col1" class="col_heading level0 col1" >TN</th>
#       <th id="T_547a7_level0_col2" class="col_heading level0 col2" >FP</th>
#       <th id="T_547a7_level0_col3" class="col_heading level0 col3" >FN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_547a7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_547a7_row0_col0" class="data row0 col0" >673</td>
#       <td id="T_547a7_row0_col1" class="data row0 col1" >6063</td>
#       <td id="T_547a7_row0_col2" class="data row0 col2" >12</td>
#       <td id="T_547a7_row0_col3" class="data row0 col3" >8</td>
#     </tr>
#     <tr>
#       <th id="T_547a7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_547a7_row1_col0" class="data row1 col0" >684</td>
#       <td id="T_547a7_row1_col1" class="data row1 col1" >6005</td>
#       <td id="T_547a7_row1_col2" class="data row1 col2" >36</td>
#       <td id="T_547a7_row1_col3" class="data row1 col3" >31</td>
#     </tr>
#     <tr>
#       <th id="T_547a7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_547a7_row2_col0" class="data row2 col0" >665</td>
#       <td id="T_547a7_row2_col1" class="data row2 col1" >6043</td>
#       <td id="T_547a7_row2_col2" class="data row2 col2" >23</td>
#       <td id="T_547a7_row2_col3" class="data row2 col3" >25</td>
#     </tr>
#     <tr>
#       <th id="T_547a7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_547a7_row3_col0" class="data row3 col0" >609</td>
#       <td id="T_547a7_row3_col1" class="data row3 col1" >6095</td>
#       <td id="T_547a7_row3_col2" class="data row3 col2" >21</td>
#       <td id="T_547a7_row3_col3" class="data row3 col3" >31</td>
#     </tr>
#     <tr>
#       <th id="T_547a7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_547a7_row4_col0" class="data row4 col0" >644</td>
#       <td id="T_547a7_row4_col1" class="data row4 col1" >6088</td>
#       <td id="T_547a7_row4_col2" class="data row4 col2" >8</td>
#       <td id="T_547a7_row4_col3" class="data row4 col3" >16</td>
#     </tr>
#     <tr>
#       <th id="T_547a7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_547a7_row5_col0" class="data row5 col0" >668</td>
#       <td id="T_547a7_row5_col1" class="data row5 col1" >6054</td>
#       <td id="T_547a7_row5_col2" class="data row5 col2" >15</td>
#       <td id="T_547a7_row5_col3" class="data row5 col3" >19</td>
#     </tr>
#     <tr>
#       <th id="T_547a7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_547a7_row6_col0" class="data row6 col0" >646</td>
#       <td id="T_547a7_row6_col1" class="data row6 col1" >6077</td>
#       <td id="T_547a7_row6_col2" class="data row6 col2" >14</td>
#       <td id="T_547a7_row6_col3" class="data row6 col3" >19</td>
#     </tr>
#     <tr>
#       <th id="T_547a7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_547a7_row7_col0" class="data row7 col0" >672</td>
#       <td id="T_547a7_row7_col1" class="data row7 col1" >6059</td>
#       <td id="T_547a7_row7_col2" class="data row7 col2" >14</td>
#       <td id="T_547a7_row7_col3" class="data row7 col3" >11</td>
#     </tr>
#     <tr>
#       <th id="T_547a7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_547a7_row8_col0" class="data row8 col0" >634</td>
#       <td id="T_547a7_row8_col1" class="data row8 col1" >6097</td>
#       <td id="T_547a7_row8_col2" class="data row8 col2" >17</td>
#       <td id="T_547a7_row8_col3" class="data row8 col3" >8</td>
#     </tr>
#     <tr>
#       <th id="T_547a7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_547a7_row9_col0" class="data row9 col0" >681</td>
#       <td id="T_547a7_row9_col1" class="data row9 col1" >6043</td>
#       <td id="T_547a7_row9_col2" class="data row9 col2" >20</td>
#       <td id="T_547a7_row9_col3" class="data row9 col3" >12</td>
#     </tr>
#   </tbody>
# </table>
# {'accuracy': 0.9733570159857904,
#  'precision': 0.9735221688409819,
#  'recall': 0.9733873718300995,
#  'f1_score': 0.9734323072672624}

# %% [markdown]
# - Сохраняем ответы.

# %%
transformer = tv.transforms.Compose([
    tv.transforms.RandomPosterize(bits=6, p=0.4),
    tv.transforms.ColorJitter(brightness=.2, hue=0.2, contrast=0.5)
])

# %%
img = lambda x: np.array(transformer(Image.fromarray((x * 255).astype(np.uint8), 'RGB')))
test_ds_tr = np.array([img(x) for x in test_ds])
test_ds_tr.shape
# Out:
# (25000, 32, 32, 3)

# %%
def draw_aug_ds(transformer):
    plt.figure(figsize=(10, 10))
    for i in range(20):
        plt.subplot(4, 10, 2 * i + 1)
        if transformer:
            img = np.array(transformer(Image.fromarray((test_ds[i] * 255).astype(np.uint8), 'RGB')))
            img2 = np.array(transformer(Image.fromarray((test_ds_tr[i] * 255).astype(np.uint8), 'RGB')))
        else:
            img = test_ds[i] * 255
            img2 = test_ds_tr[i] * 255
        plt.imshow(img / 255, cmap=plt.cm.binary)
        plt.subplot(4, 10, 2 * i + 2)
        plt.imshow(img2 / 255, cmap=plt.cm.binary)
        # plt.title(train_ds[i][1][0])
        plt.axis('off')
    plt.show()

draw_aug_ds(None)

# %%
ans_test_categorical_accuracy = make_ans_file(model_categorical_acc, test_ds, f'../answers/model{num_model}_categorical_accuracy.csv')
ans_test_loss = make_ans_file(model_loss, test_ds, f'../answers/model{num_model}_loss.csv')
ans_test_avg_categorical_accuracy = make_ans_file(model_avg_categorical_acc, test_ds, f'../answers/model{num_model}_avg_categorical_accuracy.csv')
ans_test_avg_loss = make_ans_file(model_avg_loss, test_ds, f'../answers/model{num_model}_avg_loss.csv')

# %% [markdown]
# Проверяем ответы (одинаковые они или нет), чтоб не терять кол-во отправок ответов на kaggle в день.

# %%
for i in range(len(anss) - 1):
    for j in range(i + 1, len(anss)):
        if np.all(anss[i] == anss[j]):
            print(f'чекпоинты {i + 1} и {j + 1} одинаковые')
# Out:
# чекпоинты 1 и 2 одинаковые
# чекпоинты 4 и 5 одинаковые

# %% [markdown]
# Все ответы разные, поэтому отправляем все на kaggle

# %% [markdown]
# - Accuracy чекпоинт: 0.93493
# - Loss чекпоинт: 0.92866
