# %% [markdown]
# # Модель 9 (Модель 1 + сбалансированный датасет 5000)

# %% [markdown]
# #### Импорт необходимых библиотек

# %%
import sys

import numpy as np
import pandas as pd
from PIL import Image
import tensorflow as tf
import torchvision as tv
import matplotlib.pyplot as plt
import tensorflow_addons as tfa
from livelossplot import PlotLossesKeras

sys.path.append('../../')

from core.datasets import get_ds
from core.make_answer import make_ans_file
# Out:
# c:\Users\Mi\Desktop\ML\.conda\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %% [markdown]
# #### Аугментация (4)

# %%
transformer = tv.transforms.Compose([
    tv.transforms.ColorJitter(brightness=.2, hue=0.2, contrast=0.5),
    tv.transforms.RandomAffine(degrees=(-10, 10), translate=(0, 0.1), scale=(0.85, 1)),
    tv.transforms.RandomPerspective(distortion_scale=0.2, p=0.7),
])

# %% [markdown]
# #### Скачиваем датасеты

# %%
train_ds, val_ds, test_ds = get_ds(
    'smote_data_train_5000', 'repaired_data_test',
    transform=transformer, one_hot=True, back=2
)

# %% [markdown]
# Для дальнейшей проверки метрик разделяем валидационный датасет на x и y

# %%
val_ds_x = np.array([i[0] for i in val_ds.unbatch().as_numpy_iterator()])
val_ds_y = np.array([i[1] for i in val_ds.unbatch().as_numpy_iterator()])

# %% [markdown]
# Смотрим на получившуюся агументацию.

# %%
plt.figure(figsize=(12, 15))
train_ds_visualization = train_ds[0]
for i in range(20):
    plt.subplot(5, 4, i + 1)
    img = np.array(Image.fromarray((train_ds_visualization[0][i] * 255).astype(np.uint8), 'RGB'))
    plt.imshow(img / 255, cmap=plt.cm.binary)
    plt.title(np.argmax(train_ds_visualization[1][i]))
    plt.axis('off')
plt.show()

# %% [markdown]
# #### Пишем модель

# %%
model = tf.keras.Sequential([
    tf.keras.Input(shape=(32, 32, 3), batch_size=512),
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling2D((2, 2)),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.AveragePooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0,2),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(10),
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (512, 30, 30, 32)         896
#
#  conv2d_1 (Conv2D)           (512, 28, 28, 64)         18496
#
#  batch_normalization (BatchN  (512, 28, 28, 64)        256
#  ormalization)
#
#  average_pooling2d (AverageP  (512, 14, 14, 64)        0
#  ooling2D)
#
#  conv2d_2 (Conv2D)           (512, 12, 12, 128)        73856
#
#  average_pooling2d_1 (Averag  (512, 6, 6, 128)         0
#  ePooling2D)
#
#  flatten (Flatten)           (512, 4608)               0
#
#  dense (Dense)               (512, 128)                589952
#
#  dropout (Dropout)           (512, 128)                0
#
#  dense_1 (Dense)             (512, 64)                 8256
#
#  dense_2 (Dense)             (512, 10)                 650
#
# =================================================================
# Total params: 692,362
# Trainable params: 692,234
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# #### Создаем чекпоинты

# %%
metrics = ['categorical_accuracy',
           tfa.metrics.F1Score(num_classes=10, average='macro', name='f1_score')]
num_model = '_g_9'
callbacks = [
    PlotLossesKeras(),
    tf.keras.callbacks.ModelCheckpoint(
        filepath=f'../checkpoints/model{num_model}_categorical_accuracy.h5',
        monitor='val_categorical_accuracy',
        mode='max',
        save_best_only=True,
    ),
    tf.keras.callbacks.ModelCheckpoint(
        filepath=f'../checkpoints/model{num_model}_loss.h5',
        monitor='val_loss',
        mode='min',
        save_best_only=True,
    ),
    tf.keras.callbacks.ModelCheckpoint(
        filepath=f'../checkpoints/model{num_model}_f1_score.h5',
        monitor='val_f1_score',
        mode='max',
        save_best_only=True,
    ),

    tfa.callbacks.AverageModelCheckpoint(
        update_weights=False,
        filepath=f'../checkpoints/model{num_model}_avg_categorical_accuracy.h5',
        monitor='val_categorical_accuracy',
        mode='max',
        save_best_only=True,
    ),
    tfa.callbacks.AverageModelCheckpoint(
        update_weights=False,
        filepath=f'../checkpoints/model{num_model}_avg_loss.h5',
        monitor='val_loss',
        mode='min',
        save_best_only=True,
    ),
    tfa.callbacks.AverageModelCheckpoint(
        update_weights=False,
        filepath=f'../checkpoints/model{num_model}_avg_f1_score.h5',
        monitor='val_f1_score',
        mode='max',
        save_best_only=True,
    )
]

# %% [markdown]
# #### Компиляция модели

# %%
model.compile(
    optimizer=tfa.optimizers.MovingAverage(tf.keras.optimizers.legacy.Adam()),
    metrics=metrics,
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
)

# %% [markdown]
# #### Обучаем модель

# %%
model.fit(train_ds, validation_data=val_ds,
          epochs=100, callbacks=callbacks, verbose=1)
# Out:
# categorical_accuracy
# 	training         	 (min:    0.343, max:    0.967, cur:    0.967)
# 	validation       	 (min:    0.633, max:    0.953, cur:    0.952)
# f1_score
# 	training         	 (min:    0.337, max:    0.967, cur:    0.967)
# 	validation       	 (min:    0.634, max:    0.954, cur:    0.952)
# Loss
# 	training         	 (min:    0.105, max:    1.853, cur:    0.105)
# 	validation       	 (min:    0.194, max:    2.040, cur:    0.213)
# 91/91 [==============================] - 268s 3s/step - loss: 0.1049 - categorical_accuracy: 0.9669 - f1_score: 0.9669 - val_loss: 0.2133 - val_categorical_accuracy: 0.9520 - val_f1_score: 0.9518

# %% [markdown]
# Подгружаем все чекпоинты

# %%
model_categorical_acc = tf.keras.models.load_model(f'../checkpoints/model{num_model}_categorical_accuracy.h5')
model_f1_score = tf.keras.models.load_model(f'../checkpoints/model{num_model}_f1_score.h5')
model_loss = tf.keras.models.load_model(f'../checkpoints/model{num_model}_loss.h5')
model_avg_categorical_acc = tf.keras.models.load_model(f'../checkpoints/model{num_model}_avg_categorical_accuracy.h5')
model_avg_f1_score = tf.keras.models.load_model(f'../checkpoints/model{num_model}_avg_f1_score.h5')
model_avg_loss = tf.keras.models.load_model(f'../checkpoints/model{num_model}_avg_loss.h5')

# %% [markdown]
# У нас поличилось шесть чекпоинта (шесть моделей). Ниже указан код для получения ответов для всех чекпоинтов по валидационному датасету.

# %%
ans_val_categorical_accuracy = make_ans_file(model_categorical_acc, val_ds_x)
ans_val_f1_score = make_ans_file(model_f1_score, val_ds_x)
ans_val_loss = make_ans_file(model_loss, val_ds_x)
ans_val_avg_categorical_accuracy = make_ans_file(model_avg_categorical_acc, val_ds_x)
ans_val_avg_f1_score = make_ans_file(model_avg_f1_score, val_ds_x)
ans_val_avg_loss = make_ans_file(model_avg_loss, val_ds_x)
anss = [ans_val_categorical_accuracy, ans_val_f1_score, ans_val_loss, ans_val_avg_categorical_accuracy, ans_val_avg_f1_score, ans_val_avg_loss]

# %% [markdown]
# Формируем валидационные ответы.

# %%
val_ds_y = np.argmax(val_ds_y, axis=1)

# %% [markdown]
# Сравниваем валидационные предикты каждого чекпоинта

# %%
for i in range(len(anss) - 1):
    for j in range(i + 1, len(anss)):
        if np.all(anss[i] == anss[j]):
            print(f'чекпоинты {i + 1} и {j + 1} одинаковые')
# Out:
# чекпоинты 1 и 2 одинаковые
# чекпоинты 4 и 5 одинаковые

# %% [markdown]
# Рассмотрим только 1, 3, 4, 6

# %% [markdown]
# ## ВЫВОД:

# %%
class MulticlassClassificationMetrics:
    def __init__(self, y_true, y_pred):
        self.y_true = np.array(y_true)
        self.y_pred = np.array(y_pred)
        self.matrix_error = self.get_matrix_error()

    def get_matrix_error(self):
        self.class_types = np.unique([self.y_true, self.y_pred])
        TP, FN, FP, TN = [], [], [], []
        for class_type in self.class_types:
            TP.append(np.sum(np.logical_and(self.y_true == self.y_pred, self.y_true == class_type)))
            FN.append(np.sum(np.logical_and(self.y_true == class_type, self.y_pred != class_type)))
            FP.append(np.sum(np.logical_and(self.y_pred == class_type, self.y_true != class_type)))
            TN.append(np.sum(np.logical_and(self.y_pred != class_type, self.y_true != class_type)))
        return pd.DataFrame({
            'class_type': self.class_types,
            'TP': TP, 'TN': TN, 'FP': FP, 'FN': FN,
        }).set_index('class_type')

    def accuracy(self):
        return np.sum(self.y_true == self.y_pred) / self.y_true.shape[0]

    def precision(self, averaging='macro'):
        if averaging == 'macro':
            precisions = self.matrix_error['TP'] / (self.matrix_error['TP'] + self.matrix_error['FP'])
            return np.mean(precisions.replace(np.nan, 0))
        elif averaging == 'micro':
            mean_val = self.matrix_error.mean()
            return mean_val['TP'] / (mean_val['TP'] + mean_val['FP'])

    def recall(self, averaging='macro'):
        if averaging == 'macro':
            recalls = self.matrix_error['TP'] / (self.matrix_error['TP'] + self.matrix_error['FN'])
            return np.mean(recalls.replace(np.nan, 0))
        elif averaging == 'micro':
            mean_val = self.matrix_error.mean()
            return mean_val['TP'] / (mean_val['TP'] + mean_val['FN'])

    def f1_score(self, averaging='macro'):
        if averaging == 'macro':
            reverse_r = (self.matrix_error['TP'] + self.matrix_error['FN']) / self.matrix_error['TP']
            reverse_p = (self.matrix_error['TP'] + self.matrix_error['FP']) / self.matrix_error['TP']
            f1_scores = 2 / (reverse_r + reverse_p)
            return np.mean(f1_scores.replace(np.nan, 0))
        elif averaging == 'micro':
            p = self.precision(averaging)
            r = self.recall(averaging)
            return 2 * p * r / (p + r)

    def metrics(self, averaging='macro'):
        return {
            'accuracy': self.accuracy(),
            'precision': self.precision(averaging),
            'recall': self.recall(averaging),
            'f1_score': self.f1_score(averaging),
        }

    def __str__(self):
        headers = {
            'selector': '*',
            'props': 'background-color: darkgreen; color: white; font-size: 12pt;',
        }
        che_super_mega_puper_visualization_of_cell = { 
            'selector': 'td:hover',
            'props': 'background-color: green; color: white;',
        }
        display(
            self.matrix_error
            .style
            .set_table_styles([
                headers,
                che_super_mega_puper_visualization_of_cell,
            ])
            .set_properties(**{'background-color': 'lightgreen',
                           'color': 'black', 'font-size': '12pt'})
        )
        return ''

    def __repr__(self):
        return (
            f'MulticlassClassificationMetrics(class_types={self.class_types})'
            .replace("'", '').replace(',', ';'))

# %% [markdown]
# ### Accuracy чекпоинт

# %%
metrics = MulticlassClassificationMetrics(val_ds_y, ans_val_categorical_accuracy)
print(metrics)
metrics.metrics()
# Out:
# <style type="text/css">
# #T_b2fd7 * {
#   background-color: darkgreen;
#   color: white;
#   font-size: 12pt;
# }
# #T_b2fd7 td:hover {
#   background-color: green;
#   color: white;
# }
# #T_b2fd7_row0_col0, #T_b2fd7_row0_col1, #T_b2fd7_row0_col2, #T_b2fd7_row0_col3, #T_b2fd7_row1_col0, #T_b2fd7_row1_col1, #T_b2fd7_row1_col2, #T_b2fd7_row1_col3, #T_b2fd7_row2_col0, #T_b2fd7_row2_col1, #T_b2fd7_row2_col2, #T_b2fd7_row2_col3, #T_b2fd7_row3_col0, #T_b2fd7_row3_col1, #T_b2fd7_row3_col2, #T_b2fd7_row3_col3, #T_b2fd7_row4_col0, #T_b2fd7_row4_col1, #T_b2fd7_row4_col2, #T_b2fd7_row4_col3, #T_b2fd7_row5_col0, #T_b2fd7_row5_col1, #T_b2fd7_row5_col2, #T_b2fd7_row5_col3, #T_b2fd7_row6_col0, #T_b2fd7_row6_col1, #T_b2fd7_row6_col2, #T_b2fd7_row6_col3, #T_b2fd7_row7_col0, #T_b2fd7_row7_col1, #T_b2fd7_row7_col2, #T_b2fd7_row7_col3, #T_b2fd7_row8_col0, #T_b2fd7_row8_col1, #T_b2fd7_row8_col2, #T_b2fd7_row8_col3, #T_b2fd7_row9_col0, #T_b2fd7_row9_col1, #T_b2fd7_row9_col2, #T_b2fd7_row9_col3 {
#   background-color: lightgreen;
#   color: black;
#   font-size: 12pt;
# }
# </style>
# <table id="T_b2fd7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2fd7_level0_col0" class="col_heading level0 col0" >TP</th>
#       <th id="T_b2fd7_level0_col1" class="col_heading level0 col1" >TN</th>
#       <th id="T_b2fd7_level0_col2" class="col_heading level0 col2" >FP</th>
#       <th id="T_b2fd7_level0_col3" class="col_heading level0 col3" >FN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2fd7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b2fd7_row0_col0" class="data row0 col0" >341</td>
#       <td id="T_b2fd7_row0_col1" class="data row0 col1" >3134</td>
#       <td id="T_b2fd7_row0_col2" class="data row0 col2" >14</td>
#       <td id="T_b2fd7_row0_col3" class="data row0 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_b2fd7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b2fd7_row1_col0" class="data row1 col0" >319</td>
#       <td id="T_b2fd7_row1_col1" class="data row1 col1" >3148</td>
#       <td id="T_b2fd7_row1_col2" class="data row1 col2" >16</td>
#       <td id="T_b2fd7_row1_col3" class="data row1 col3" >18</td>
#     </tr>
#     <tr>
#       <th id="T_b2fd7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b2fd7_row2_col0" class="data row2 col0" >336</td>
#       <td id="T_b2fd7_row2_col1" class="data row2 col1" >3131</td>
#       <td id="T_b2fd7_row2_col2" class="data row2 col2" >12</td>
#       <td id="T_b2fd7_row2_col3" class="data row2 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_b2fd7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b2fd7_row3_col0" class="data row3 col0" >331</td>
#       <td id="T_b2fd7_row3_col1" class="data row3 col1" >3124</td>
#       <td id="T_b2fd7_row3_col2" class="data row3 col2" >25</td>
#       <td id="T_b2fd7_row3_col3" class="data row3 col3" >21</td>
#     </tr>
#     <tr>
#       <th id="T_b2fd7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b2fd7_row4_col0" class="data row4 col0" >347</td>
#       <td id="T_b2fd7_row4_col1" class="data row4 col1" >3129</td>
#       <td id="T_b2fd7_row4_col2" class="data row4 col2" >11</td>
#       <td id="T_b2fd7_row4_col3" class="data row4 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_b2fd7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b2fd7_row5_col0" class="data row5 col0" >328</td>
#       <td id="T_b2fd7_row5_col1" class="data row5 col1" >3133</td>
#       <td id="T_b2fd7_row5_col2" class="data row5 col2" >18</td>
#       <td id="T_b2fd7_row5_col3" class="data row5 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_b2fd7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b2fd7_row6_col0" class="data row6 col0" >343</td>
#       <td id="T_b2fd7_row6_col1" class="data row6 col1" >3112</td>
#       <td id="T_b2fd7_row6_col2" class="data row6 col2" >33</td>
#       <td id="T_b2fd7_row6_col3" class="data row6 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_b2fd7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b2fd7_row7_col0" class="data row7 col0" >346</td>
#       <td id="T_b2fd7_row7_col1" class="data row7 col1" >3131</td>
#       <td id="T_b2fd7_row7_col2" class="data row7 col2" >10</td>
#       <td id="T_b2fd7_row7_col3" class="data row7 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_b2fd7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b2fd7_row8_col0" class="data row8 col0" >328</td>
#       <td id="T_b2fd7_row8_col1" class="data row8 col1" >3140</td>
#       <td id="T_b2fd7_row8_col2" class="data row8 col2" >12</td>
#       <td id="T_b2fd7_row8_col3" class="data row8 col3" >21</td>
#     </tr>
#     <tr>
#       <th id="T_b2fd7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b2fd7_row9_col0" class="data row9 col0" >319</td>
#       <td id="T_b2fd7_row9_col1" class="data row9 col1" >3164</td>
#       <td id="T_b2fd7_row9_col2" class="data row9 col2" >12</td>
#       <td id="T_b2fd7_row9_col3" class="data row9 col3" >6</td>
#     </tr>
#   </tbody>
# </table>
# {'accuracy': 0.953441873750357,
#  'precision': 0.9537941590990142,
#  'recall': 0.9535804090592965,
#  'f1_score': 0.953561381920926}

# %% [markdown]
# ## F1-score чекпоинт

# %%
metrics = MulticlassClassificationMetrics(val_ds_y, ans_val_loss)
print(metrics)
metrics.metrics()
# Out:
# <style type="text/css">
# #T_66089 * {
#   background-color: darkgreen;
#   color: white;
#   font-size: 12pt;
# }
# #T_66089 td:hover {
#   background-color: green;
#   color: white;
# }
# #T_66089_row0_col0, #T_66089_row0_col1, #T_66089_row0_col2, #T_66089_row0_col3, #T_66089_row1_col0, #T_66089_row1_col1, #T_66089_row1_col2, #T_66089_row1_col3, #T_66089_row2_col0, #T_66089_row2_col1, #T_66089_row2_col2, #T_66089_row2_col3, #T_66089_row3_col0, #T_66089_row3_col1, #T_66089_row3_col2, #T_66089_row3_col3, #T_66089_row4_col0, #T_66089_row4_col1, #T_66089_row4_col2, #T_66089_row4_col3, #T_66089_row5_col0, #T_66089_row5_col1, #T_66089_row5_col2, #T_66089_row5_col3, #T_66089_row6_col0, #T_66089_row6_col1, #T_66089_row6_col2, #T_66089_row6_col3, #T_66089_row7_col0, #T_66089_row7_col1, #T_66089_row7_col2, #T_66089_row7_col3, #T_66089_row8_col0, #T_66089_row8_col1, #T_66089_row8_col2, #T_66089_row8_col3, #T_66089_row9_col0, #T_66089_row9_col1, #T_66089_row9_col2, #T_66089_row9_col3 {
#   background-color: lightgreen;
#   color: black;
#   font-size: 12pt;
# }
# </style>
# <table id="T_66089">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66089_level0_col0" class="col_heading level0 col0" >TP</th>
#       <th id="T_66089_level0_col1" class="col_heading level0 col1" >TN</th>
#       <th id="T_66089_level0_col2" class="col_heading level0 col2" >FP</th>
#       <th id="T_66089_level0_col3" class="col_heading level0 col3" >FN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66089_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_66089_row0_col0" class="data row0 col0" >339</td>
#       <td id="T_66089_row0_col1" class="data row0 col1" >3135</td>
#       <td id="T_66089_row0_col2" class="data row0 col2" >13</td>
#       <td id="T_66089_row0_col3" class="data row0 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_66089_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_66089_row1_col0" class="data row1 col0" >318</td>
#       <td id="T_66089_row1_col1" class="data row1 col1" >3143</td>
#       <td id="T_66089_row1_col2" class="data row1 col2" >21</td>
#       <td id="T_66089_row1_col3" class="data row1 col3" >19</td>
#     </tr>
#     <tr>
#       <th id="T_66089_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_66089_row2_col0" class="data row2 col0" >340</td>
#       <td id="T_66089_row2_col1" class="data row2 col1" >3127</td>
#       <td id="T_66089_row2_col2" class="data row2 col2" >16</td>
#       <td id="T_66089_row2_col3" class="data row2 col3" >18</td>
#     </tr>
#     <tr>
#       <th id="T_66089_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_66089_row3_col0" class="data row3 col0" >325</td>
#       <td id="T_66089_row3_col1" class="data row3 col1" >3131</td>
#       <td id="T_66089_row3_col2" class="data row3 col2" >18</td>
#       <td id="T_66089_row3_col3" class="data row3 col3" >27</td>
#     </tr>
#     <tr>
#       <th id="T_66089_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_66089_row4_col0" class="data row4 col0" >347</td>
#       <td id="T_66089_row4_col1" class="data row4 col1" >3128</td>
#       <td id="T_66089_row4_col2" class="data row4 col2" >12</td>
#       <td id="T_66089_row4_col3" class="data row4 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_66089_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_66089_row5_col0" class="data row5 col0" >327</td>
#       <td id="T_66089_row5_col1" class="data row5 col1" >3131</td>
#       <td id="T_66089_row5_col2" class="data row5 col2" >20</td>
#       <td id="T_66089_row5_col3" class="data row5 col3" >23</td>
#     </tr>
#     <tr>
#       <th id="T_66089_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_66089_row6_col0" class="data row6 col0" >331</td>
#       <td id="T_66089_row6_col1" class="data row6 col1" >3125</td>
#       <td id="T_66089_row6_col2" class="data row6 col2" >20</td>
#       <td id="T_66089_row6_col3" class="data row6 col3" >25</td>
#     </tr>
#     <tr>
#       <th id="T_66089_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_66089_row7_col0" class="data row7 col0" >346</td>
#       <td id="T_66089_row7_col1" class="data row7 col1" >3118</td>
#       <td id="T_66089_row7_col2" class="data row7 col2" >23</td>
#       <td id="T_66089_row7_col3" class="data row7 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_66089_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_66089_row8_col0" class="data row8 col0" >333</td>
#       <td id="T_66089_row8_col1" class="data row8 col1" >3125</td>
#       <td id="T_66089_row8_col2" class="data row8 col2" >27</td>
#       <td id="T_66089_row8_col3" class="data row8 col3" >16</td>
#     </tr>
#     <tr>
#       <th id="T_66089_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_66089_row9_col0" class="data row9 col0" >313</td>
#       <td id="T_66089_row9_col1" class="data row9 col1" >3164</td>
#       <td id="T_66089_row9_col2" class="data row9 col2" >12</td>
#       <td id="T_66089_row9_col3" class="data row9 col3" >12</td>
#     </tr>
#   </tbody>
# </table>
# {'accuracy': 0.9480148528991716,
#  'precision': 0.948140249616636,
#  'recall': 0.9480598840052252,
#  'f1_score': 0.9480383641708199}

# %% [markdown]
# ## Скользящее среднее по accuracy чекпоинт

# %%
metrics = MulticlassClassificationMetrics(val_ds_y, ans_val_avg_categorical_accuracy)
print(metrics)
metrics.metrics()
# Out:
# <style type="text/css">
# #T_39c7a * {
#   background-color: darkgreen;
#   color: white;
#   font-size: 12pt;
# }
# #T_39c7a td:hover {
#   background-color: green;
#   color: white;
# }
# #T_39c7a_row0_col0, #T_39c7a_row0_col1, #T_39c7a_row0_col2, #T_39c7a_row0_col3, #T_39c7a_row1_col0, #T_39c7a_row1_col1, #T_39c7a_row1_col2, #T_39c7a_row1_col3, #T_39c7a_row2_col0, #T_39c7a_row2_col1, #T_39c7a_row2_col2, #T_39c7a_row2_col3, #T_39c7a_row3_col0, #T_39c7a_row3_col1, #T_39c7a_row3_col2, #T_39c7a_row3_col3, #T_39c7a_row4_col0, #T_39c7a_row4_col1, #T_39c7a_row4_col2, #T_39c7a_row4_col3, #T_39c7a_row5_col0, #T_39c7a_row5_col1, #T_39c7a_row5_col2, #T_39c7a_row5_col3, #T_39c7a_row6_col0, #T_39c7a_row6_col1, #T_39c7a_row6_col2, #T_39c7a_row6_col3, #T_39c7a_row7_col0, #T_39c7a_row7_col1, #T_39c7a_row7_col2, #T_39c7a_row7_col3, #T_39c7a_row8_col0, #T_39c7a_row8_col1, #T_39c7a_row8_col2, #T_39c7a_row8_col3, #T_39c7a_row9_col0, #T_39c7a_row9_col1, #T_39c7a_row9_col2, #T_39c7a_row9_col3 {
#   background-color: lightgreen;
#   color: black;
#   font-size: 12pt;
# }
# </style>
# <table id="T_39c7a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39c7a_level0_col0" class="col_heading level0 col0" >TP</th>
#       <th id="T_39c7a_level0_col1" class="col_heading level0 col1" >TN</th>
#       <th id="T_39c7a_level0_col2" class="col_heading level0 col2" >FP</th>
#       <th id="T_39c7a_level0_col3" class="col_heading level0 col3" >FN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39c7a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_39c7a_row0_col0" class="data row0 col0" >339</td>
#       <td id="T_39c7a_row0_col1" class="data row0 col1" >3134</td>
#       <td id="T_39c7a_row0_col2" class="data row0 col2" >14</td>
#       <td id="T_39c7a_row0_col3" class="data row0 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_39c7a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_39c7a_row1_col0" class="data row1 col0" >318</td>
#       <td id="T_39c7a_row1_col1" class="data row1 col1" >3149</td>
#       <td id="T_39c7a_row1_col2" class="data row1 col2" >15</td>
#       <td id="T_39c7a_row1_col3" class="data row1 col3" >19</td>
#     </tr>
#     <tr>
#       <th id="T_39c7a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_39c7a_row2_col0" class="data row2 col0" >337</td>
#       <td id="T_39c7a_row2_col1" class="data row2 col1" >3135</td>
#       <td id="T_39c7a_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_39c7a_row2_col3" class="data row2 col3" >21</td>
#     </tr>
#     <tr>
#       <th id="T_39c7a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_39c7a_row3_col0" class="data row3 col0" >329</td>
#       <td id="T_39c7a_row3_col1" class="data row3 col1" >3136</td>
#       <td id="T_39c7a_row3_col2" class="data row3 col2" >13</td>
#       <td id="T_39c7a_row3_col3" class="data row3 col3" >23</td>
#     </tr>
#     <tr>
#       <th id="T_39c7a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_39c7a_row4_col0" class="data row4 col0" >345</td>
#       <td id="T_39c7a_row4_col1" class="data row4 col1" >3125</td>
#       <td id="T_39c7a_row4_col2" class="data row4 col2" >15</td>
#       <td id="T_39c7a_row4_col3" class="data row4 col3" >16</td>
#     </tr>
#     <tr>
#       <th id="T_39c7a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_39c7a_row5_col0" class="data row5 col0" >332</td>
#       <td id="T_39c7a_row5_col1" class="data row5 col1" >3133</td>
#       <td id="T_39c7a_row5_col2" class="data row5 col2" >18</td>
#       <td id="T_39c7a_row5_col3" class="data row5 col3" >18</td>
#     </tr>
#     <tr>
#       <th id="T_39c7a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_39c7a_row6_col0" class="data row6 col0" >339</td>
#       <td id="T_39c7a_row6_col1" class="data row6 col1" >3117</td>
#       <td id="T_39c7a_row6_col2" class="data row6 col2" >28</td>
#       <td id="T_39c7a_row6_col3" class="data row6 col3" >17</td>
#     </tr>
#     <tr>
#       <th id="T_39c7a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_39c7a_row7_col0" class="data row7 col0" >351</td>
#       <td id="T_39c7a_row7_col1" class="data row7 col1" >3127</td>
#       <td id="T_39c7a_row7_col2" class="data row7 col2" >14</td>
#       <td id="T_39c7a_row7_col3" class="data row7 col3" >9</td>
#     </tr>
#     <tr>
#       <th id="T_39c7a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_39c7a_row8_col0" class="data row8 col0" >333</td>
#       <td id="T_39c7a_row8_col1" class="data row8 col1" >3132</td>
#       <td id="T_39c7a_row8_col2" class="data row8 col2" >20</td>
#       <td id="T_39c7a_row8_col3" class="data row8 col3" >16</td>
#     </tr>
#     <tr>
#       <th id="T_39c7a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_39c7a_row9_col0" class="data row9 col0" >322</td>
#       <td id="T_39c7a_row9_col1" class="data row9 col1" >3165</td>
#       <td id="T_39c7a_row9_col2" class="data row9 col2" >11</td>
#       <td id="T_39c7a_row9_col3" class="data row9 col3" >3</td>
#     </tr>
#   </tbody>
# </table>
# {'accuracy': 0.9554413024850043,
#  'precision': 0.9556658859357174,
#  'recall': 0.9556381242922019,
#  'f1_score': 0.9555520838345817}

# %% [markdown]
# ### Скользящее среднее по F1-score чекпоинт.

# %%
metrics = MulticlassClassificationMetrics(val_ds_y, ans_val_avg_loss)
print(metrics)
metrics.metrics()
# Out:
# <style type="text/css">
# #T_27dae * {
#   background-color: darkgreen;
#   color: white;
#   font-size: 12pt;
# }
# #T_27dae td:hover {
#   background-color: green;
#   color: white;
# }
# #T_27dae_row0_col0, #T_27dae_row0_col1, #T_27dae_row0_col2, #T_27dae_row0_col3, #T_27dae_row1_col0, #T_27dae_row1_col1, #T_27dae_row1_col2, #T_27dae_row1_col3, #T_27dae_row2_col0, #T_27dae_row2_col1, #T_27dae_row2_col2, #T_27dae_row2_col3, #T_27dae_row3_col0, #T_27dae_row3_col1, #T_27dae_row3_col2, #T_27dae_row3_col3, #T_27dae_row4_col0, #T_27dae_row4_col1, #T_27dae_row4_col2, #T_27dae_row4_col3, #T_27dae_row5_col0, #T_27dae_row5_col1, #T_27dae_row5_col2, #T_27dae_row5_col3, #T_27dae_row6_col0, #T_27dae_row6_col1, #T_27dae_row6_col2, #T_27dae_row6_col3, #T_27dae_row7_col0, #T_27dae_row7_col1, #T_27dae_row7_col2, #T_27dae_row7_col3, #T_27dae_row8_col0, #T_27dae_row8_col1, #T_27dae_row8_col2, #T_27dae_row8_col3, #T_27dae_row9_col0, #T_27dae_row9_col1, #T_27dae_row9_col2, #T_27dae_row9_col3 {
#   background-color: lightgreen;
#   color: black;
#   font-size: 12pt;
# }
# </style>
# <table id="T_27dae">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27dae_level0_col0" class="col_heading level0 col0" >TP</th>
#       <th id="T_27dae_level0_col1" class="col_heading level0 col1" >TN</th>
#       <th id="T_27dae_level0_col2" class="col_heading level0 col2" >FP</th>
#       <th id="T_27dae_level0_col3" class="col_heading level0 col3" >FN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27dae_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_27dae_row0_col0" class="data row0 col0" >343</td>
#       <td id="T_27dae_row0_col1" class="data row0 col1" >3132</td>
#       <td id="T_27dae_row0_col2" class="data row0 col2" >16</td>
#       <td id="T_27dae_row0_col3" class="data row0 col3" >10</td>
#     </tr>
#     <tr>
#       <th id="T_27dae_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_27dae_row1_col0" class="data row1 col0" >316</td>
#       <td id="T_27dae_row1_col1" class="data row1 col1" >3148</td>
#       <td id="T_27dae_row1_col2" class="data row1 col2" >16</td>
#       <td id="T_27dae_row1_col3" class="data row1 col3" >21</td>
#     </tr>
#     <tr>
#       <th id="T_27dae_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_27dae_row2_col0" class="data row2 col0" >338</td>
#       <td id="T_27dae_row2_col1" class="data row2 col1" >3136</td>
#       <td id="T_27dae_row2_col2" class="data row2 col2" >7</td>
#       <td id="T_27dae_row2_col3" class="data row2 col3" >20</td>
#     </tr>
#     <tr>
#       <th id="T_27dae_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_27dae_row3_col0" class="data row3 col0" >325</td>
#       <td id="T_27dae_row3_col1" class="data row3 col1" >3141</td>
#       <td id="T_27dae_row3_col2" class="data row3 col2" >8</td>
#       <td id="T_27dae_row3_col3" class="data row3 col3" >27</td>
#     </tr>
#     <tr>
#       <th id="T_27dae_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_27dae_row4_col0" class="data row4 col0" >348</td>
#       <td id="T_27dae_row4_col1" class="data row4 col1" >3128</td>
#       <td id="T_27dae_row4_col2" class="data row4 col2" >12</td>
#       <td id="T_27dae_row4_col3" class="data row4 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_27dae_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_27dae_row5_col0" class="data row5 col0" >341</td>
#       <td id="T_27dae_row5_col1" class="data row5 col1" >3124</td>
#       <td id="T_27dae_row5_col2" class="data row5 col2" >27</td>
#       <td id="T_27dae_row5_col3" class="data row5 col3" >9</td>
#     </tr>
#     <tr>
#       <th id="T_27dae_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_27dae_row6_col0" class="data row6 col0" >339</td>
#       <td id="T_27dae_row6_col1" class="data row6 col1" >3122</td>
#       <td id="T_27dae_row6_col2" class="data row6 col2" >23</td>
#       <td id="T_27dae_row6_col3" class="data row6 col3" >17</td>
#     </tr>
#     <tr>
#       <th id="T_27dae_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_27dae_row7_col0" class="data row7 col0" >347</td>
#       <td id="T_27dae_row7_col1" class="data row7 col1" >3126</td>
#       <td id="T_27dae_row7_col2" class="data row7 col2" >15</td>
#       <td id="T_27dae_row7_col3" class="data row7 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_27dae_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_27dae_row8_col0" class="data row8 col0" >332</td>
#       <td id="T_27dae_row8_col1" class="data row8 col1" >3136</td>
#       <td id="T_27dae_row8_col2" class="data row8 col2" >16</td>
#       <td id="T_27dae_row8_col3" class="data row8 col3" >17</td>
#     </tr>
#     <tr>
#       <th id="T_27dae_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_27dae_row9_col0" class="data row9 col0" >320</td>
#       <td id="T_27dae_row9_col1" class="data row9 col1" >3164</td>
#       <td id="T_27dae_row9_col2" class="data row9 col2" >12</td>
#       <td id="T_27dae_row9_col3" class="data row9 col3" >5</td>
#     </tr>
#   </tbody>
# </table>
# {'accuracy': 0.956583833190517,
#  'precision': 0.9569128240644987,
#  'recall': 0.9567101877549998,
#  'f1_score': 0.9566149232930261}

# %% [markdown]
# Метрики неплохие

# %% [markdown]
# - Сохраняем ответы.

# %%
ans_test_categorical_accuracy = make_ans_file(model_categorical_acc, test_ds, f'../answers/model{num_model}_categorical_accuracy.csv')
ans_test_f1_score = make_ans_file(model_f1_score, test_ds, f'../answers/model{num_model}_f1_score.csv')
ans_test_loss = make_ans_file(model_loss, test_ds, f'../answers/model{num_model}_loss.csv')
ans_test_avg_categorical_accuracy = make_ans_file(model_avg_categorical_acc, test_ds, f'../answers/model{num_model}_avg_categorical_accuracy.csv')
ans_test_avg_f1_score = make_ans_file(model_avg_f1_score, test_ds, f'../answers/model{num_model}_avg_f1_score.csv')
ans_test_avg_loss = make_ans_file(model_avg_loss, test_ds, f'../answers/model{num_model}_avg_loss.csv')
anss = [ans_test_categorical_accuracy, ans_test_loss, ans_test_avg_categorical_accuracy, ans_test_avg_loss]

# %% [markdown]
# Проверяем ответы (одинаковые они или нет), чтоб не терять кол-во отправок ответов на kaggle в день.

# %%
for i in range(len(anss) - 1):
    for j in range(i + 1, len(anss)):
        if np.all(anss[i] == anss[j]):
            print(f'чекпоинты {i + 1} и {j + 1} одинаковые')

# %% [markdown]
# Все ответы разные, поэтому отправляем все на kaggle все

# %% [markdown]
# - 'categorical_accuracy': 0.9296
# - 'f1_score': 0.9296
# - 'loss': 0.9144
#
# метрики плохие, поэтому решил дальше не отправлять
