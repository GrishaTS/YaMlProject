# %% [markdown]
# # Модель 19

# %% [markdown]
# #### Импорт необходимых библиотек

# %%
import sys

import numpy as np
import pandas as pd
from PIL import Image
import tensorflow as tf
import torchvision as tv
import matplotlib.pyplot as plt
import tensorflow_addons as tfa
from livelossplot import PlotLossesKeras

sys.path.append('../../')

from core.datasets import get_ds
from core.make_answer import make_ans_file
# Out:
# c:\Users\Mi\Desktop\ML\.conda\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
num_model = '_g_20'

# %% [markdown]
# #### Аугментация (4)

# %%
transformer = tv.transforms.Compose([
    tv.transforms.ColorJitter(brightness=.2, hue=0.2, contrast=0.5),
    tv.transforms.RandomAffine(degrees=(-10, 10), translate=(0, 0.1), scale=(0.85, 1)),
    tv.transforms.RandomPerspective(distortion_scale=0.2, p=0.7),
])

# %% [markdown]
# #### Скачиваем датасеты

# %%
train_ds, val_ds, test_ds = get_ds(
    'smote_data_train_7000', 'repaired_data_test', val_size=0.12,
    transform=transformer, one_hot=True, back=2, batch_size=100
)

# %% [markdown]
# Для дальнейшей проверки метрик разделяем валидационный датасет на x и y

# %%
val_ds_x = np.array([i[0] for i in val_ds.unbatch().as_numpy_iterator()])
val_ds_y = np.array([i[1] for i in val_ds.unbatch().as_numpy_iterator()])

# %% [markdown]
# Смотрим на получившуюся агументацию.

# %%
plt.figure(figsize=(12, 15))
train_ds_visualization = train_ds[0]
for i in range(20):
    plt.subplot(5, 4, i + 1)
    img = np.array(Image.fromarray((train_ds_visualization[0][i] * 255).astype(np.uint8), 'RGB'))
    plt.imshow(img / 255, cmap=plt.cm.binary)
    plt.title(np.argmax(train_ds_visualization[1][i]))
    plt.axis('off')
plt.show()

# %% [markdown]
# #### Пишем модель

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Input((32, 32, 3), 100),
    tf.keras.layers.Conv2D(64, 5),
    tf.keras.layers.MaxPool2D(),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.Conv2D(64, 3, padding='same'),
    tf.keras.layers.Conv2D(64, 3, padding='same'),
    tf.keras.layers.MaxPool2D(),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.Conv2D(128, 3, padding='same'),
    tf.keras.layers.Conv2D(128, 3, padding='same'),
    tf.keras.layers.MaxPool2D(),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.GlobalMaxPool2D(),
    tf.keras.layers.Dense(10),
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (100, 28, 28, 64)         4864
#
#  max_pooling2d (MaxPooling2D  (100, 14, 14, 64)        0
#  )
#
#  batch_normalization (BatchN  (100, 14, 14, 64)        256
#  ormalization)
#
#  activation (Activation)     (100, 14, 14, 64)         0
#
#  conv2d_1 (Conv2D)           (100, 14, 14, 64)         36928
#
#  conv2d_2 (Conv2D)           (100, 14, 14, 64)         36928
#
#  max_pooling2d_1 (MaxPooling  (100, 7, 7, 64)          0
#  2D)
#
#  batch_normalization_1 (Batc  (100, 7, 7, 64)          256
#  hNormalization)
#
#  activation_1 (Activation)   (100, 7, 7, 64)           0
#
#  conv2d_3 (Conv2D)           (100, 7, 7, 128)          73856
#
#  conv2d_4 (Conv2D)           (100, 7, 7, 128)          147584
#
#  max_pooling2d_2 (MaxPooling  (100, 3, 3, 128)         0
#  2D)
#
#  batch_normalization_2 (Batc  (100, 3, 3, 128)         512
#  hNormalization)
#
#  activation_2 (Activation)   (100, 3, 3, 128)          0
#
#  global_max_pooling2d (Globa  (100, 128)               0
#  lMaxPooling2D)
#
#  dense (Dense)               (100, 10)                 1290
#
# =================================================================
# Total params: 302,474
# Trainable params: 301,962
# Non-trainable params: 512
# _________________________________________________________________

# %% [markdown]
# #### Создаем чекпоинты

# %%
metrics = ['categorical_accuracy',
           tfa.metrics.F1Score(num_classes=10, average='macro', name='f1_score')]
callbacks = [
    PlotLossesKeras(),
    tf.keras.callbacks.ModelCheckpoint(
        filepath=f'../checkpoints/model{num_model}_categorical_accuracy.h5',
        monitor='val_categorical_accuracy',
        mode='max',
        save_best_only=True,
    ),
    tf.keras.callbacks.ModelCheckpoint(
        filepath=f'../checkpoints/model{num_model}_loss.h5',
        monitor='val_loss',
        mode='min',
        save_best_only=True,
    ),
    tf.keras.callbacks.ModelCheckpoint(
        filepath=f'../checkpoints/model{num_model}_f1_score.h5',
        monitor='val_f1_score',
        mode='max',
        save_best_only=True,
    ),

    tfa.callbacks.AverageModelCheckpoint(
        update_weights=False,
        filepath=f'../checkpoints/model{num_model}_avg_categorical_accuracy.h5',
        monitor='val_categorical_accuracy',
        mode='max',
        save_best_only=True,
    ),
    tfa.callbacks.AverageModelCheckpoint(
        update_weights=False,
        filepath=f'../checkpoints/model{num_model}_avg_loss.h5',
        monitor='val_loss',
        mode='min',
        save_best_only=True,
    ),
    tfa.callbacks.AverageModelCheckpoint(
        update_weights=False,
        filepath=f'../checkpoints/model{num_model}_avg_f1_score.h5',
        monitor='val_f1_score',
        mode='max',
        save_best_only=True,
    )
]

# %% [markdown]
# #### Компиляция модели

# %%
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    return lr * tf.math.exp(-0.03)


callbacks.append(tf.keras.callbacks.LearningRateScheduler(scheduler))

# %%
model.compile(
    optimizer=tfa.optimizers.MovingAverage(tf.keras.optimizers.legacy.Adam(0.0016, decay=5e-5)),
    metrics=metrics,
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
)

# %% [markdown]
# #### Обучаем модель

# %%
model.fit(train_ds, validation_data=val_ds,
          epochs=100, callbacks=callbacks, verbose=1)
# Out:
# categorical_accuracy
# 	training         	 (min:    0.584, max:    0.977, cur:    0.977)
# 	validation       	 (min:    0.808, max:    0.964, cur:    0.963)
# f1_score
# 	training         	 (min:    0.584, max:    0.977, cur:    0.977)
# 	validation       	 (min:    0.807, max:    0.964, cur:    0.963)
# Loss
# 	training         	 (min:    0.075, max:    1.202, cur:    0.077)
# 	validation       	 (min:    0.144, max:    0.668, cur:    0.147)
# 616/616 [==============================] - 326s 529ms/step - loss: 0.0767 - categorical_accuracy: 0.9766 - f1_score: 0.9766 - val_loss: 0.1471 - val_categorical_accuracy: 0.9629 - val_f1_score: 0.9629 - lr: 1.0753e-04

# %% [markdown]
# Подгружаем все чекпоинты

# %%
model_categorical_acc = tf.keras.models.load_model(f'../checkpoints/model{num_model}_categorical_accuracy.h5')
model_f1_score = tf.keras.models.load_model(f'../checkpoints/model{num_model}_f1_score.h5')
model_loss = tf.keras.models.load_model(f'../checkpoints/model{num_model}_loss.h5')
model_avg_categorical_acc = tf.keras.models.load_model(f'../checkpoints/model{num_model}_avg_categorical_accuracy.h5')
model_avg_f1_score = tf.keras.models.load_model(f'../checkpoints/model{num_model}_avg_f1_score.h5')
model_avg_loss = tf.keras.models.load_model(f'../checkpoints/model{num_model}_avg_loss.h5')

# %% [markdown]
# У нас поличилось шесть чекпоинта (шесть моделей). Ниже указан код для получения ответов для всех чекпоинтов по валидационному датасету.

# %%
ans_val_categorical_accuracy = make_ans_file(model_categorical_acc, val_ds_x)
ans_val_f1_score = make_ans_file(model_f1_score, val_ds_x)
ans_val_loss = make_ans_file(model_loss, val_ds_x)
ans_val_avg_categorical_accuracy = make_ans_file(model_avg_categorical_acc, val_ds_x)
ans_val_avg_f1_score = make_ans_file(model_avg_f1_score, val_ds_x)
ans_val_avg_loss = make_ans_file(model_avg_loss, val_ds_x)
anss = [ans_val_categorical_accuracy, ans_val_f1_score, ans_val_loss, ans_val_avg_categorical_accuracy, ans_val_avg_f1_score, ans_val_avg_loss]
# Out:
# 263/263 [==============================] - 10s 36ms/step
# 263/263 [==============================] - 10s 36ms/step
# 263/263 [==============================] - 10s 35ms/step
# 263/263 [==============================] - 10s 35ms/step
# 263/263 [==============================] - 10s 36ms/step
# 263/263 [==============================] - 10s 36ms/step

# %% [markdown]
# Формируем валидационные ответы.

# %%
val_ds_y = np.argmax(val_ds_y, axis=1)

# %% [markdown]
# Сравниваем валидационные предикты каждого чекпоинта

# %%
for i in range(len(anss) - 1):
    for j in range(i + 1, len(anss)):
        if np.all(anss[i] == anss[j]):
            print(f'чекпоинты {i + 1} и {j + 1} одинаковые')
# Out:
# чекпоинты 1 и 2 одинаковые
# чекпоинты 4 и 5 одинаковые

# %% [markdown]
# Рассмотрим только 1, 3, 4, 6

# %% [markdown]
# ## ВЫВОД:

# %%
class MulticlassClassificationMetrics:
    def __init__(self, y_true, y_pred):
        self.y_true = np.array(y_true)
        self.y_pred = np.array(y_pred)
        self.matrix_error = self.get_matrix_error()

    def get_matrix_error(self):
        self.class_types = np.unique([self.y_true, self.y_pred])
        TP, FN, FP, TN = [], [], [], []
        for class_type in self.class_types:
            TP.append(np.sum(np.logical_and(self.y_true == self.y_pred, self.y_true == class_type)))
            FN.append(np.sum(np.logical_and(self.y_true == class_type, self.y_pred != class_type)))
            FP.append(np.sum(np.logical_and(self.y_pred == class_type, self.y_true != class_type)))
            TN.append(np.sum(np.logical_and(self.y_pred != class_type, self.y_true != class_type)))
        return pd.DataFrame({
            'class_type': self.class_types,
            'TP': TP, 'TN': TN, 'FP': FP, 'FN': FN,
        }).set_index('class_type')

    def accuracy(self):
        return np.sum(self.y_true == self.y_pred) / self.y_true.shape[0]

    def precision(self, averaging='macro'):
        if averaging == 'macro':
            precisions = self.matrix_error['TP'] / (self.matrix_error['TP'] + self.matrix_error['FP'])
            return np.mean(precisions.replace(np.nan, 0))
        elif averaging == 'micro':
            mean_val = self.matrix_error.mean()
            return mean_val['TP'] / (mean_val['TP'] + mean_val['FP'])

    def recall(self, averaging='macro'):
        if averaging == 'macro':
            recalls = self.matrix_error['TP'] / (self.matrix_error['TP'] + self.matrix_error['FN'])
            return np.mean(recalls.replace(np.nan, 0))
        elif averaging == 'micro':
            mean_val = self.matrix_error.mean()
            return mean_val['TP'] / (mean_val['TP'] + mean_val['FN'])

    def f1_score(self, averaging='macro'):
        if averaging == 'macro':
            reverse_r = (self.matrix_error['TP'] + self.matrix_error['FN']) / self.matrix_error['TP']
            reverse_p = (self.matrix_error['TP'] + self.matrix_error['FP']) / self.matrix_error['TP']
            f1_scores = 2 / (reverse_r + reverse_p)
            return np.mean(f1_scores.replace(np.nan, 0))
        elif averaging == 'micro':
            p = self.precision(averaging)
            r = self.recall(averaging)
            return 2 * p * r / (p + r)

    def metrics(self, averaging='macro'):
        return {
            'accuracy': self.accuracy(),
            'precision': self.precision(averaging),
            'recall': self.recall(averaging),
            'f1_score': self.f1_score(averaging),
        }

    def __str__(self):
        headers = {
            'selector': '*',
            'props': 'background-color: darkgreen; color: white; font-size: 12pt;',
        }
        che_super_mega_puper_visualization_of_cell = { 
            'selector': 'td:hover',
            'props': 'background-color: green; color: white;',
        }
        display(
            self.matrix_error
            .style
            .set_table_styles([
                headers,
                che_super_mega_puper_visualization_of_cell,
            ])
            .set_properties(**{'background-color': 'lightgreen',
                           'color': 'black', 'font-size': '12pt'})
        )
        return ''

    def __repr__(self):
        return (
            f'MulticlassClassificationMetrics(class_types={self.class_types})'
            .replace("'", '').replace(',', ';'))

# %% [markdown]
# ### Accuracy чекпоинт

# %%
metrics = MulticlassClassificationMetrics(val_ds_y, ans_val_categorical_accuracy)
print(metrics)
metrics.metrics()
# Out:
# <style type="text/css">
# #T_beb31 * {
#   background-color: darkgreen;
#   color: white;
#   font-size: 12pt;
# }
# #T_beb31 td:hover {
#   background-color: green;
#   color: white;
# }
# #T_beb31_row0_col0, #T_beb31_row0_col1, #T_beb31_row0_col2, #T_beb31_row0_col3, #T_beb31_row1_col0, #T_beb31_row1_col1, #T_beb31_row1_col2, #T_beb31_row1_col3, #T_beb31_row2_col0, #T_beb31_row2_col1, #T_beb31_row2_col2, #T_beb31_row2_col3, #T_beb31_row3_col0, #T_beb31_row3_col1, #T_beb31_row3_col2, #T_beb31_row3_col3, #T_beb31_row4_col0, #T_beb31_row4_col1, #T_beb31_row4_col2, #T_beb31_row4_col3, #T_beb31_row5_col0, #T_beb31_row5_col1, #T_beb31_row5_col2, #T_beb31_row5_col3, #T_beb31_row6_col0, #T_beb31_row6_col1, #T_beb31_row6_col2, #T_beb31_row6_col3, #T_beb31_row7_col0, #T_beb31_row7_col1, #T_beb31_row7_col2, #T_beb31_row7_col3, #T_beb31_row8_col0, #T_beb31_row8_col1, #T_beb31_row8_col2, #T_beb31_row8_col3, #T_beb31_row9_col0, #T_beb31_row9_col1, #T_beb31_row9_col2, #T_beb31_row9_col3 {
#   background-color: lightgreen;
#   color: black;
#   font-size: 12pt;
# }
# </style>
# <table id="T_beb31">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_beb31_level0_col0" class="col_heading level0 col0" >TP</th>
#       <th id="T_beb31_level0_col1" class="col_heading level0 col1" >TN</th>
#       <th id="T_beb31_level0_col2" class="col_heading level0 col2" >FP</th>
#       <th id="T_beb31_level0_col3" class="col_heading level0 col3" >FN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_beb31_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_beb31_row0_col0" class="data row0 col0" >832</td>
#       <td id="T_beb31_row0_col1" class="data row0 col1" >7531</td>
#       <td id="T_beb31_row0_col2" class="data row0 col2" >15</td>
#       <td id="T_beb31_row0_col3" class="data row0 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_beb31_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_beb31_row1_col0" class="data row1 col0" >783</td>
#       <td id="T_beb31_row1_col1" class="data row1 col1" >7525</td>
#       <td id="T_beb31_row1_col2" class="data row1 col2" >58</td>
#       <td id="T_beb31_row1_col3" class="data row1 col3" >34</td>
#     </tr>
#     <tr>
#       <th id="T_beb31_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_beb31_row2_col0" class="data row2 col0" >827</td>
#       <td id="T_beb31_row2_col1" class="data row2 col1" >7530</td>
#       <td id="T_beb31_row2_col2" class="data row2 col2" >20</td>
#       <td id="T_beb31_row2_col3" class="data row2 col3" >23</td>
#     </tr>
#     <tr>
#       <th id="T_beb31_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_beb31_row3_col0" class="data row3 col0" >798</td>
#       <td id="T_beb31_row3_col1" class="data row3 col1" >7517</td>
#       <td id="T_beb31_row3_col2" class="data row3 col2" >38</td>
#       <td id="T_beb31_row3_col3" class="data row3 col3" >47</td>
#     </tr>
#     <tr>
#       <th id="T_beb31_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_beb31_row4_col0" class="data row4 col0" >832</td>
#       <td id="T_beb31_row4_col1" class="data row4 col1" >7508</td>
#       <td id="T_beb31_row4_col2" class="data row4 col2" >29</td>
#       <td id="T_beb31_row4_col3" class="data row4 col3" >31</td>
#     </tr>
#     <tr>
#       <th id="T_beb31_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_beb31_row5_col0" class="data row5 col0" >816</td>
#       <td id="T_beb31_row5_col1" class="data row5 col1" >7516</td>
#       <td id="T_beb31_row5_col2" class="data row5 col2" >29</td>
#       <td id="T_beb31_row5_col3" class="data row5 col3" >39</td>
#     </tr>
#     <tr>
#       <th id="T_beb31_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_beb31_row6_col0" class="data row6 col0" >794</td>
#       <td id="T_beb31_row6_col1" class="data row6 col1" >7549</td>
#       <td id="T_beb31_row6_col2" class="data row6 col2" >26</td>
#       <td id="T_beb31_row6_col3" class="data row6 col3" >31</td>
#     </tr>
#     <tr>
#       <th id="T_beb31_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_beb31_row7_col0" class="data row7 col0" >773</td>
#       <td id="T_beb31_row7_col1" class="data row7 col1" >7580</td>
#       <td id="T_beb31_row7_col2" class="data row7 col2" >25</td>
#       <td id="T_beb31_row7_col3" class="data row7 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_beb31_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_beb31_row8_col0" class="data row8 col0" >847</td>
#       <td id="T_beb31_row8_col1" class="data row8 col1" >7476</td>
#       <td id="T_beb31_row8_col2" class="data row8 col2" >39</td>
#       <td id="T_beb31_row8_col3" class="data row8 col3" >38</td>
#     </tr>
#     <tr>
#       <th id="T_beb31_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_beb31_row9_col0" class="data row9 col0" >796</td>
#       <td id="T_beb31_row9_col1" class="data row9 col1" >7566</td>
#       <td id="T_beb31_row9_col2" class="data row9 col2" >23</td>
#       <td id="T_beb31_row9_col3" class="data row9 col3" >15</td>
#     </tr>
#   </tbody>
# </table>
# {'accuracy': 0.964047619047619,
#  'precision': 0.9641119606589239,
#  'recall': 0.9641725592314518,
#  'f1_score': 0.9641107111109732}

# %% [markdown]
# ## F1-score чекпоинт

# %%
metrics = MulticlassClassificationMetrics(val_ds_y, ans_val_loss)
print(metrics)
metrics.metrics()
# Out:
# <style type="text/css">
# #T_a389e * {
#   background-color: darkgreen;
#   color: white;
#   font-size: 12pt;
# }
# #T_a389e td:hover {
#   background-color: green;
#   color: white;
# }
# #T_a389e_row0_col0, #T_a389e_row0_col1, #T_a389e_row0_col2, #T_a389e_row0_col3, #T_a389e_row1_col0, #T_a389e_row1_col1, #T_a389e_row1_col2, #T_a389e_row1_col3, #T_a389e_row2_col0, #T_a389e_row2_col1, #T_a389e_row2_col2, #T_a389e_row2_col3, #T_a389e_row3_col0, #T_a389e_row3_col1, #T_a389e_row3_col2, #T_a389e_row3_col3, #T_a389e_row4_col0, #T_a389e_row4_col1, #T_a389e_row4_col2, #T_a389e_row4_col3, #T_a389e_row5_col0, #T_a389e_row5_col1, #T_a389e_row5_col2, #T_a389e_row5_col3, #T_a389e_row6_col0, #T_a389e_row6_col1, #T_a389e_row6_col2, #T_a389e_row6_col3, #T_a389e_row7_col0, #T_a389e_row7_col1, #T_a389e_row7_col2, #T_a389e_row7_col3, #T_a389e_row8_col0, #T_a389e_row8_col1, #T_a389e_row8_col2, #T_a389e_row8_col3, #T_a389e_row9_col0, #T_a389e_row9_col1, #T_a389e_row9_col2, #T_a389e_row9_col3 {
#   background-color: lightgreen;
#   color: black;
#   font-size: 12pt;
# }
# </style>
# <table id="T_a389e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a389e_level0_col0" class="col_heading level0 col0" >TP</th>
#       <th id="T_a389e_level0_col1" class="col_heading level0 col1" >TN</th>
#       <th id="T_a389e_level0_col2" class="col_heading level0 col2" >FP</th>
#       <th id="T_a389e_level0_col3" class="col_heading level0 col3" >FN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a389e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a389e_row0_col0" class="data row0 col0" >833</td>
#       <td id="T_a389e_row0_col1" class="data row0 col1" >7529</td>
#       <td id="T_a389e_row0_col2" class="data row0 col2" >17</td>
#       <td id="T_a389e_row0_col3" class="data row0 col3" >21</td>
#     </tr>
#     <tr>
#       <th id="T_a389e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a389e_row1_col0" class="data row1 col0" >777</td>
#       <td id="T_a389e_row1_col1" class="data row1 col1" >7528</td>
#       <td id="T_a389e_row1_col2" class="data row1 col2" >55</td>
#       <td id="T_a389e_row1_col3" class="data row1 col3" >40</td>
#     </tr>
#     <tr>
#       <th id="T_a389e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a389e_row2_col0" class="data row2 col0" >825</td>
#       <td id="T_a389e_row2_col1" class="data row2 col1" >7527</td>
#       <td id="T_a389e_row2_col2" class="data row2 col2" >23</td>
#       <td id="T_a389e_row2_col3" class="data row2 col3" >25</td>
#     </tr>
#     <tr>
#       <th id="T_a389e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a389e_row3_col0" class="data row3 col0" >790</td>
#       <td id="T_a389e_row3_col1" class="data row3 col1" >7525</td>
#       <td id="T_a389e_row3_col2" class="data row3 col2" >30</td>
#       <td id="T_a389e_row3_col3" class="data row3 col3" >55</td>
#     </tr>
#     <tr>
#       <th id="T_a389e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a389e_row4_col0" class="data row4 col0" >834</td>
#       <td id="T_a389e_row4_col1" class="data row4 col1" >7509</td>
#       <td id="T_a389e_row4_col2" class="data row4 col2" >28</td>
#       <td id="T_a389e_row4_col3" class="data row4 col3" >29</td>
#     </tr>
#     <tr>
#       <th id="T_a389e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a389e_row5_col0" class="data row5 col0" >825</td>
#       <td id="T_a389e_row5_col1" class="data row5 col1" >7507</td>
#       <td id="T_a389e_row5_col2" class="data row5 col2" >38</td>
#       <td id="T_a389e_row5_col3" class="data row5 col3" >30</td>
#     </tr>
#     <tr>
#       <th id="T_a389e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a389e_row6_col0" class="data row6 col0" >793</td>
#       <td id="T_a389e_row6_col1" class="data row6 col1" >7552</td>
#       <td id="T_a389e_row6_col2" class="data row6 col2" >23</td>
#       <td id="T_a389e_row6_col3" class="data row6 col3" >32</td>
#     </tr>
#     <tr>
#       <th id="T_a389e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a389e_row7_col0" class="data row7 col0" >773</td>
#       <td id="T_a389e_row7_col1" class="data row7 col1" >7576</td>
#       <td id="T_a389e_row7_col2" class="data row7 col2" >29</td>
#       <td id="T_a389e_row7_col3" class="data row7 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_a389e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a389e_row8_col0" class="data row8 col0" >847</td>
#       <td id="T_a389e_row8_col1" class="data row8 col1" >7472</td>
#       <td id="T_a389e_row8_col2" class="data row8 col2" >43</td>
#       <td id="T_a389e_row8_col3" class="data row8 col3" >38</td>
#     </tr>
#     <tr>
#       <th id="T_a389e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a389e_row9_col0" class="data row9 col0" >797</td>
#       <td id="T_a389e_row9_col1" class="data row9 col1" >7569</td>
#       <td id="T_a389e_row9_col2" class="data row9 col2" >20</td>
#       <td id="T_a389e_row9_col3" class="data row9 col3" >14</td>
#     </tr>
#   </tbody>
# </table>
# {'accuracy': 0.9635714285714285,
#  'precision': 0.9636530893428356,
#  'recall': 0.9636596951758799,
#  'f1_score': 0.9636175518512633}

# %% [markdown]
# ## Скользящее среднее по accuracy чекпоинт

# %%
metrics = MulticlassClassificationMetrics(val_ds_y, ans_val_avg_categorical_accuracy)
print(metrics)
metrics.metrics()
# Out:
# <style type="text/css">
# #T_39995 * {
#   background-color: darkgreen;
#   color: white;
#   font-size: 12pt;
# }
# #T_39995 td:hover {
#   background-color: green;
#   color: white;
# }
# #T_39995_row0_col0, #T_39995_row0_col1, #T_39995_row0_col2, #T_39995_row0_col3, #T_39995_row1_col0, #T_39995_row1_col1, #T_39995_row1_col2, #T_39995_row1_col3, #T_39995_row2_col0, #T_39995_row2_col1, #T_39995_row2_col2, #T_39995_row2_col3, #T_39995_row3_col0, #T_39995_row3_col1, #T_39995_row3_col2, #T_39995_row3_col3, #T_39995_row4_col0, #T_39995_row4_col1, #T_39995_row4_col2, #T_39995_row4_col3, #T_39995_row5_col0, #T_39995_row5_col1, #T_39995_row5_col2, #T_39995_row5_col3, #T_39995_row6_col0, #T_39995_row6_col1, #T_39995_row6_col2, #T_39995_row6_col3, #T_39995_row7_col0, #T_39995_row7_col1, #T_39995_row7_col2, #T_39995_row7_col3, #T_39995_row8_col0, #T_39995_row8_col1, #T_39995_row8_col2, #T_39995_row8_col3, #T_39995_row9_col0, #T_39995_row9_col1, #T_39995_row9_col2, #T_39995_row9_col3 {
#   background-color: lightgreen;
#   color: black;
#   font-size: 12pt;
# }
# </style>
# <table id="T_39995">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39995_level0_col0" class="col_heading level0 col0" >TP</th>
#       <th id="T_39995_level0_col1" class="col_heading level0 col1" >TN</th>
#       <th id="T_39995_level0_col2" class="col_heading level0 col2" >FP</th>
#       <th id="T_39995_level0_col3" class="col_heading level0 col3" >FN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39995_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_39995_row0_col0" class="data row0 col0" >830</td>
#       <td id="T_39995_row0_col1" class="data row0 col1" >7530</td>
#       <td id="T_39995_row0_col2" class="data row0 col2" >16</td>
#       <td id="T_39995_row0_col3" class="data row0 col3" >24</td>
#     </tr>
#     <tr>
#       <th id="T_39995_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_39995_row1_col0" class="data row1 col0" >782</td>
#       <td id="T_39995_row1_col1" class="data row1 col1" >7518</td>
#       <td id="T_39995_row1_col2" class="data row1 col2" >65</td>
#       <td id="T_39995_row1_col3" class="data row1 col3" >35</td>
#     </tr>
#     <tr>
#       <th id="T_39995_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_39995_row2_col0" class="data row2 col0" >826</td>
#       <td id="T_39995_row2_col1" class="data row2 col1" >7523</td>
#       <td id="T_39995_row2_col2" class="data row2 col2" >27</td>
#       <td id="T_39995_row2_col3" class="data row2 col3" >24</td>
#     </tr>
#     <tr>
#       <th id="T_39995_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_39995_row3_col0" class="data row3 col0" >789</td>
#       <td id="T_39995_row3_col1" class="data row3 col1" >7525</td>
#       <td id="T_39995_row3_col2" class="data row3 col2" >30</td>
#       <td id="T_39995_row3_col3" class="data row3 col3" >56</td>
#     </tr>
#     <tr>
#       <th id="T_39995_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_39995_row4_col0" class="data row4 col0" >831</td>
#       <td id="T_39995_row4_col1" class="data row4 col1" >7508</td>
#       <td id="T_39995_row4_col2" class="data row4 col2" >29</td>
#       <td id="T_39995_row4_col3" class="data row4 col3" >32</td>
#     </tr>
#     <tr>
#       <th id="T_39995_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_39995_row5_col0" class="data row5 col0" >821</td>
#       <td id="T_39995_row5_col1" class="data row5 col1" >7512</td>
#       <td id="T_39995_row5_col2" class="data row5 col2" >33</td>
#       <td id="T_39995_row5_col3" class="data row5 col3" >34</td>
#     </tr>
#     <tr>
#       <th id="T_39995_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_39995_row6_col0" class="data row6 col0" >793</td>
#       <td id="T_39995_row6_col1" class="data row6 col1" >7550</td>
#       <td id="T_39995_row6_col2" class="data row6 col2" >25</td>
#       <td id="T_39995_row6_col3" class="data row6 col3" >32</td>
#     </tr>
#     <tr>
#       <th id="T_39995_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_39995_row7_col0" class="data row7 col0" >768</td>
#       <td id="T_39995_row7_col1" class="data row7 col1" >7579</td>
#       <td id="T_39995_row7_col2" class="data row7 col2" >26</td>
#       <td id="T_39995_row7_col3" class="data row7 col3" >27</td>
#     </tr>
#     <tr>
#       <th id="T_39995_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_39995_row8_col0" class="data row8 col0" >847</td>
#       <td id="T_39995_row8_col1" class="data row8 col1" >7473</td>
#       <td id="T_39995_row8_col2" class="data row8 col2" >42</td>
#       <td id="T_39995_row8_col3" class="data row8 col3" >38</td>
#     </tr>
#     <tr>
#       <th id="T_39995_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_39995_row9_col0" class="data row9 col0" >796</td>
#       <td id="T_39995_row9_col1" class="data row9 col1" >7565</td>
#       <td id="T_39995_row9_col2" class="data row9 col2" >24</td>
#       <td id="T_39995_row9_col3" class="data row9 col3" >15</td>
#     </tr>
#   </tbody>
# </table>
# {'accuracy': 0.9622619047619048,
#  'precision': 0.9623880061278174,
#  'recall': 0.9623520098846121,
#  'f1_score': 0.9623082525231933}

# %% [markdown]
# ### Скользящее среднее по F1-score чекпоинт.

# %%
metrics = MulticlassClassificationMetrics(val_ds_y, ans_val_avg_loss)
print(metrics)
metrics.metrics()
# Out:
# <style type="text/css">
# #T_63822 * {
#   background-color: darkgreen;
#   color: white;
#   font-size: 12pt;
# }
# #T_63822 td:hover {
#   background-color: green;
#   color: white;
# }
# #T_63822_row0_col0, #T_63822_row0_col1, #T_63822_row0_col2, #T_63822_row0_col3, #T_63822_row1_col0, #T_63822_row1_col1, #T_63822_row1_col2, #T_63822_row1_col3, #T_63822_row2_col0, #T_63822_row2_col1, #T_63822_row2_col2, #T_63822_row2_col3, #T_63822_row3_col0, #T_63822_row3_col1, #T_63822_row3_col2, #T_63822_row3_col3, #T_63822_row4_col0, #T_63822_row4_col1, #T_63822_row4_col2, #T_63822_row4_col3, #T_63822_row5_col0, #T_63822_row5_col1, #T_63822_row5_col2, #T_63822_row5_col3, #T_63822_row6_col0, #T_63822_row6_col1, #T_63822_row6_col2, #T_63822_row6_col3, #T_63822_row7_col0, #T_63822_row7_col1, #T_63822_row7_col2, #T_63822_row7_col3, #T_63822_row8_col0, #T_63822_row8_col1, #T_63822_row8_col2, #T_63822_row8_col3, #T_63822_row9_col0, #T_63822_row9_col1, #T_63822_row9_col2, #T_63822_row9_col3 {
#   background-color: lightgreen;
#   color: black;
#   font-size: 12pt;
# }
# </style>
# <table id="T_63822">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63822_level0_col0" class="col_heading level0 col0" >TP</th>
#       <th id="T_63822_level0_col1" class="col_heading level0 col1" >TN</th>
#       <th id="T_63822_level0_col2" class="col_heading level0 col2" >FP</th>
#       <th id="T_63822_level0_col3" class="col_heading level0 col3" >FN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63822_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_63822_row0_col0" class="data row0 col0" >834</td>
#       <td id="T_63822_row0_col1" class="data row0 col1" >7528</td>
#       <td id="T_63822_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_63822_row0_col3" class="data row0 col3" >20</td>
#     </tr>
#     <tr>
#       <th id="T_63822_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_63822_row1_col0" class="data row1 col0" >779</td>
#       <td id="T_63822_row1_col1" class="data row1 col1" >7526</td>
#       <td id="T_63822_row1_col2" class="data row1 col2" >57</td>
#       <td id="T_63822_row1_col3" class="data row1 col3" >38</td>
#     </tr>
#     <tr>
#       <th id="T_63822_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_63822_row2_col0" class="data row2 col0" >825</td>
#       <td id="T_63822_row2_col1" class="data row2 col1" >7526</td>
#       <td id="T_63822_row2_col2" class="data row2 col2" >24</td>
#       <td id="T_63822_row2_col3" class="data row2 col3" >25</td>
#     </tr>
#     <tr>
#       <th id="T_63822_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_63822_row3_col0" class="data row3 col0" >791</td>
#       <td id="T_63822_row3_col1" class="data row3 col1" >7525</td>
#       <td id="T_63822_row3_col2" class="data row3 col2" >30</td>
#       <td id="T_63822_row3_col3" class="data row3 col3" >54</td>
#     </tr>
#     <tr>
#       <th id="T_63822_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_63822_row4_col0" class="data row4 col0" >834</td>
#       <td id="T_63822_row4_col1" class="data row4 col1" >7512</td>
#       <td id="T_63822_row4_col2" class="data row4 col2" >25</td>
#       <td id="T_63822_row4_col3" class="data row4 col3" >29</td>
#     </tr>
#     <tr>
#       <th id="T_63822_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_63822_row5_col0" class="data row5 col0" >823</td>
#       <td id="T_63822_row5_col1" class="data row5 col1" >7510</td>
#       <td id="T_63822_row5_col2" class="data row5 col2" >35</td>
#       <td id="T_63822_row5_col3" class="data row5 col3" >32</td>
#     </tr>
#     <tr>
#       <th id="T_63822_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_63822_row6_col0" class="data row6 col0" >795</td>
#       <td id="T_63822_row6_col1" class="data row6 col1" >7552</td>
#       <td id="T_63822_row6_col2" class="data row6 col2" >23</td>
#       <td id="T_63822_row6_col3" class="data row6 col3" >30</td>
#     </tr>
#     <tr>
#       <th id="T_63822_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_63822_row7_col0" class="data row7 col0" >769</td>
#       <td id="T_63822_row7_col1" class="data row7 col1" >7579</td>
#       <td id="T_63822_row7_col2" class="data row7 col2" >26</td>
#       <td id="T_63822_row7_col3" class="data row7 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_63822_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_63822_row8_col0" class="data row8 col0" >850</td>
#       <td id="T_63822_row8_col1" class="data row8 col1" >7470</td>
#       <td id="T_63822_row8_col2" class="data row8 col2" >45</td>
#       <td id="T_63822_row8_col3" class="data row8 col3" >35</td>
#     </tr>
#     <tr>
#       <th id="T_63822_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_63822_row9_col0" class="data row9 col0" >796</td>
#       <td id="T_63822_row9_col1" class="data row9 col1" >7568</td>
#       <td id="T_63822_row9_col2" class="data row9 col2" >21</td>
#       <td id="T_63822_row9_col3" class="data row9 col3" >15</td>
#     </tr>
#   </tbody>
# </table>
# {'accuracy': 0.9638095238095238,
#  'precision': 0.9639181030572818,
#  'recall': 0.963860972379757,
#  'f1_score': 0.96385028850267}

# %% [markdown]
# Метрики неплохие

# %% [markdown]
# - Сохраняем ответы.

# %%
ans_test_categorical_accuracy = make_ans_file(model_categorical_acc, test_ds, f'../answers/model{num_model}_categorical_accuracy.csv')
ans_test_f1_score = make_ans_file(model_f1_score, test_ds, f'../answers/model{num_model}_f1_score.csv')
ans_test_loss = make_ans_file(model_loss, test_ds, f'../answers/model{num_model}_loss.csv')
ans_test_avg_categorical_accuracy = make_ans_file(model_avg_categorical_acc, test_ds, f'../answers/model{num_model}_avg_categorical_accuracy.csv')
ans_test_avg_f1_score = make_ans_file(model_avg_f1_score, test_ds, f'../answers/model{num_model}_avg_f1_score.csv')
ans_test_avg_loss = make_ans_file(model_avg_loss, test_ds, f'../answers/model{num_model}_avg_loss.csv')
anss = [ans_test_categorical_accuracy, ans_test_loss, ans_test_avg_categorical_accuracy, ans_test_avg_loss]
# Out:
# 782/782 [==============================] - 28s 36ms/step
# 782/782 [==============================] - 28s 36ms/step
# 782/782 [==============================] - 28s 36ms/step
# 782/782 [==============================] - 28s 36ms/step
# 782/782 [==============================] - 29s 37ms/step
# 782/782 [==============================] - 28s 36ms/step

# %% [markdown]
# Проверяем ответы (одинаковые они или нет), чтоб не терять кол-во отправок ответов на kaggle в день.

# %%
for i in range(len(anss) - 1):
    for j in range(i + 1, len(anss)):
        if np.all(anss[i] == anss[j]):
            print(f'чекпоинты {i + 1} и {j + 1} одинаковые')

# %% [markdown]
# Все ответы разные, поэтому отправляем все на kaggle `categorical_accuracy`, `loss`, `avg_categorical_accuracy`, `avg_loss` чекпоинты
